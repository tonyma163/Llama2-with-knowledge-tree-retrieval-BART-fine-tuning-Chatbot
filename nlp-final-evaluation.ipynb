# %%
# File: nlp-final-evaluation.ipynb
# Author: Jack Lam
# Date: April 21, 2024
# Purpose: This notebook generates "result.txt" and evaluates models (Llama2 + BART).
# Usage: Please install the require packages. Please modify the loading dataset path.
# Run the required code one by one to generates "result.txt" and and evaluates models (Llama2 + BART). Please ensure to have the loading dataset and the path has modified correctly.

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# Install libraries
# !pip install ctransformers accelerate peft keybert jieba chinese-synonym-word
# Out:
# Requirement already satisfied: ctransformers in /opt/conda/lib/python3.10/site-packages (0.2.27)
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.29.3)
# Requirement already satisfied: peft in /opt/conda/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: keybert in /opt/conda/lib/python3.10/site-packages (0.8.4)
# Requirement already satisfied: jieba in /opt/conda/lib/python3.10/site-packages (0.42.1)
# Requirement already satisfied: chinese-synonym-word in /opt/conda/lib/python3.10/site-packages (0.1.6)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from ctransformers) (0.22.2)
# Requirement already satisfied: py-cpuinfo<10.0.0,>=9.0.0 in /opt/conda/lib/python3.10/site-packages (from ctransformers) (9.0.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.1.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (from peft) (4.39.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from peft) (4.66.1)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /opt/conda/lib/python3.10/site-packages (from keybert) (2.7.0)
# Requirement already satisfied: scikit-learn>=0.22.2 in /opt/conda/lib/python3.10/site-packages (from keybert) (1.2.2)
# Requirement already satisfied: rich>=10.4.0 in /opt/conda/lib/python3.10/site-packages (from keybert) (13.7.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->ctransformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->ctransformers) (2024.2.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->ctransformers) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->ctransformers) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.4.0->keybert) (2.17.2)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22.2->keybert) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22.2->keybert) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22.2->keybert) (3.2.0)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=0.3.8->keybert) (9.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers->peft) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers->peft) (0.15.2)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->ctransformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->ctransformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->ctransformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub->ctransformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)

# %% [markdown]
# **Load Llama2 for RAG**

# %%
from ctransformers import AutoModelForCausalLM
from transformers import AutoTokenizer, pipeline

# Set gpu_layers to the number of layers to offload to GPU. Set to 0 if no GPU acceleration is available on your system.
# Model
model_llama = AutoModelForCausalLM.from_pretrained(
    "SinpxAI/Llama2-Chinese-7B-Chat-GGUF",
    model_file="llama2-chinese-7b-chat.Q4_K_M.gguf",
    model_type="llama",
    gpu_layers=110,
    hf=True
)

# Tokenizer
tokenizer_llama = AutoTokenizer.from_pretrained("meta-llama/Llama-2-7b-chat-hf", use_fast=True)
# Out:
# 2024-04-21 03:24:45.386131: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-21 03:24:45.386186: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-21 03:24:45.387665: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# ggml_cuda_set_main_device: using device 0 (Tesla T4) as main device

# %%
# Pipeline for Llama2
pipe_llama = pipeline(task="text-generation", model=model_llama, tokenizer=tokenizer_llama)

# %% [markdown]
# **Load Fine-tuned Bart Model & Tokenizer**

# %%
## Load Fine-tuned Bart Model & Tokenizer

from transformers import BartForConditionalGeneration, AutoTokenizer, pipeline
from peft import PeftModel
import torch

base_model = "fnlp/bart-base-chinese"
new_model = "tonyma163/bart_v1"

device="cuda:0"

base_model_reload = BartForConditionalGeneration.from_pretrained(
        base_model,
        return_dict=True,
        low_cpu_mem_usage=True,
        torch_dtype=torch.float16,
        device_map=device,
        #trust_remote_code=True,
)
base_model_reload.half()

model_bart = PeftModel.from_pretrained(base_model_reload, new_model)

# %%
## Load Fine-tuned Bart Model & Tokenizer

from transformers import BertTokenizer

tokenizer_bart = BertTokenizer.from_pretrained(base_model, trust_remote_code=True)

tokenizer_bart.pad_token = tokenizer_bart.eos_token
tokenizer_bart.padding_side = "right"

# %%
## Load Fine-tuned Bart Model & Tokenizer

from transformers import Text2TextGenerationPipeline

pipe_bart = Text2TextGenerationPipeline(model=model_bart, tokenizer=tokenizer_bart)
# Out:
# The model 'PeftModelForSeq2SeqLM' is not supported for . Supported models are ['BartForConditionalGeneration', 'BigBirdPegasusForConditionalGeneration', 'BlenderbotForConditionalGeneration', 'BlenderbotSmallForConditionalGeneration', 'EncoderDecoderModel', 'FSMTForConditionalGeneration', 'GPTSanJapaneseForConditionalGeneration', 'LEDForConditionalGeneration', 'LongT5ForConditionalGeneration', 'M2M100ForConditionalGeneration', 'MarianMTModel', 'MBartForConditionalGeneration', 'MT5ForConditionalGeneration', 'MvpForConditionalGeneration', 'NllbMoeForConditionalGeneration', 'PegasusForConditionalGeneration', 'PegasusXForConditionalGeneration', 'PLBartForConditionalGeneration', 'ProphetNetForConditionalGeneration', 'SeamlessM4TForTextToText', 'SeamlessM4Tv2ForTextToText', 'SwitchTransformersForConditionalGeneration', 'T5ForConditionalGeneration', 'UMT5ForConditionalGeneration', 'XLMProphetNetForConditionalGeneration'].

# %% [markdown]
# **Load Knowledge Set**

# %%
## Load Knowledge Set

import pandas as pd
import ast

file_path = "/kaggle/input/nlp-knowledgeset/knowledge_set.txt"

data = []

# Open the file and parse each line from string to tuple
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        if line.strip():  # Ensure the line is not empty
            try:
                # Convert string representation of tuple to actual tuple
                tuple_data = ast.literal_eval(line.strip())
                data.append(tuple_data)
            except SyntaxError:
                print(f"Skipping malformed line: {line.strip()}")

# Load the data into a DataFrame
df = pd.DataFrame(data, columns=['Entity', 'Category', 'Answer'])

# %% [markdown]
# **Clean Knowledge Set**

# %%
## Check Category Data
distinct_categories = df['Category'].unique()
distinct_categories
# Out:
# array(['2018-11-14', '喜好', '评论', '特色菜', '简介', '适合听', '评分', '人均价格', '喜欢',
#        '适合吃', '2018-10-13', '主演', '2018-10-16', '演唱', '2018-10-15',
#        '2018-12-25', '2018-12-27', '类型', '获奖', '成就', '嘿玛口碑', '(live)评论',
#        '身高', '2018-11-12', '无持续风向,最高气温:12℃,最低气温:-4℃适合吃', '2018-12-24',
#        '2018-11-19', '订单量', '导演', '2018-11-2', '喜欢的新闻',
#        '东风,最高气温:13℃,最低气温:6℃适合吃', '东北风,最高气温:6℃,最低气温:0℃适合吃',
#        '西南风,最高气温:4℃,最低气温:-5℃适合吃', '人间道评论', '2018-10-26', '新闻', '口碑',
#        '东南风,最高气温:5℃,最低气温:-3℃适合吃', '星座', '2018-11-11', '2018-12-21',
#        '2018-10-11', '国家地区', '2018-12-12', '2018-10-23', '2018-11-8',
#        '东南风,最高气温:11℃,最低气温:1℃适合吃', '2018-10-1', '情绪零碎评论', '成分', '我的姓氏评论',
#        '3040评论', '地址', '2018-12-26', '嘿玛导演', '无持续风向,最高气温:19℃,最低气温:4℃适合吃',
#        '东南风,最高气温:16℃,最低气温:11℃适合吃', '西北风,最高气温:8℃,最低气温:0℃适合吃', '2018-10-12',
#        '2018-12-17', '时间', '2018-10-4', '道道道评论', '(00Live)(live版)评论',
#        '无持续风向,最高气温:15℃,最低气温:11℃适合吃', '2018-11-1',
#        '无持续风向,最高气温:13℃,最低气温:5℃适合吃', '2018-12-16', '2018-12-7',
#        '东南风,最高气温:22℃,最低气温:16℃适合吃', '2018-12-3', '东北风,最高气温:8℃,最低气温:-2℃适合吃',
#        'Garden评论', '2018-12-13', '血型', '2018-12-6', '我幸福评论', '2018-11-25',
#        '2018-11-26', '2018-12-14', '西风,最高气温:21℃,最低气温:13℃适合吃',
#        '东风,最高气温:22℃,最低气温:13℃适合吃', '无持续风向,最高气温:21℃,最低气温:8℃适合吃',
#        'ofFaith评论', '2018-12-9', '2018-12-19', '2018-10-8', '2018-10-27',
#        '2018-10-24', '2018-12-8', '东北风,最高气温:16℃,最低气温:7℃适合吃', '2018-12-2',
#        '2018-11-5', '2018-10-19', '东南风,最高气温:8℃,最低气温:3℃适合吃',
#        '北风,最高气温:14℃,最低气温:9℃适合吃', '东南风,最高气温:-1℃,最低气温:-8℃适合吃', '体重',
#        '东北风,最高气温:23℃,最低气温:17℃适合吃', '西北风,最高气温:13℃,最低气温:6℃适合吃',
#        '2018-12-15', '2018-10-25', '2018-10-21', '2018-10-5',
#        '2018-11-18', '东南风,最高气温:0℃,最低气温:-13℃适合吃',
#        '东风,最高气温:20℃,最低气温:12℃适合吃', '西南风,最高气温:14℃,最低气温:3℃适合吃',
#        '西北风,最高气温:19℃,最低气温:8℃适合吃', '2018-10-20', '东北风,最高气温:18℃,最低气温:7℃适合吃',
#        '西北风,最高气温:11℃,最低气温:-3℃适合吃', '南风,最高气温:18℃,最低气温:12℃适合吃',
#        '东风,最高气温:15℃,最低气温:3℃适合吃', '2018-10-18', '2018-12-23', '2018-10-3',
#        'Rain评论', '(Live)评论', '(LidoRemix)评论', '嘿玛主演',
#        '西北风,最高气温:24℃,最低气温:11℃适合吃', '2018-10-9', '2018-10-6',
#        '西风,最高气温:17℃,最低气温:5℃适合吃', '极速传说评论', '南风,最高气温:13℃,最低气温:-1℃适合吃',
#        '2018-11-23', '2018-11-3', '道道道国家地区', '2018-11-21', '2018-12-5',
#        '东北风,最高气温:9℃,最低气温:-1℃适合吃', '东南风,最高气温:17℃,最低气温:11℃适合吃',
#        '无持续风向,最高气温:26℃,最低气温:18℃适合吃', '生日', '西风,最高气温:13℃,最低气温:-1℃适合吃',
#        '东风,最高气温:20℃,最低气温:14℃适合吃', '东北风,最高气温:22℃,最低气温:13℃适合吃',
#        '西北风,最高气温:2℃,最低气温:-8℃适合吃', '北风,最高气温:27℃,最低气温:13℃适合吃', '2018-11-6',
#        '西北风,最高气温:17℃,最低气温:7℃适合吃', '东南风,最高气温:8℃,最低气温:-8℃适合吃',
#        '东南风,最高气温:12℃,最低气温:6℃适合吃', '无持续风向,最高气温:26℃,最低气温:19℃适合吃',
#        '2018-12-22', '西南风,最高气温:18℃,最低气温:3℃适合吃', '2018-12-20', 'Pill评论',
#        '2018-11-4', '西北风,最高气温:5℃,最低气温:-5℃适合吃', '2018-12-4',
#        '无持续风向,最高气温:-1℃,最低气温:-13℃适合吃', '东北风,最高气温:22℃,最低气温:15℃适合吃',
#        '无持续风向,最高气温:26℃,最低气温:21℃适合吃', 'MeDown(中文版)评论',
#        '西北风,最高气温:9℃,最低气温:-4℃适合吃', '嘿玛评论', '无持续风向,最高气温:29℃,最低气温:20℃适合吃',
#        '日期', '2018-12-18', '北风,最高气温:15℃,最低气温:4℃适合吃', '2018-10-14',
#        '2018-12-10', '2018-10-7', '东北风,最高气温:-13℃,最低气温:-18℃适合吃',
#        '2018-10-22', '2018-11-13', '2018-11-16',
#        '东北风,最高气温:10℃,最低气温:4℃适合吃', '东北风,最高气温:18℃,最低气温:13℃适合吃', '2018-10-2',
#        '北风,最高气温:23℃,最低气温:18℃适合吃', '无持续风向,最高气温:22℃,最低气温:14℃适合吃',
#        '东北风,最高气温:8℃,最低气温:4℃适合吃', '西北风,最高气温:13℃,最低气温:2℃适合吃',
#        '无持续风向,最高气温:22℃,最低气温:12℃适合吃', '东风,最高气温:25℃,最低气温:17℃适合吃', '道道道口碑',
#        '2018-11-15', '东北风,最高气温:22℃,最低气温:19℃适合吃',
#        '东北风,最高气温:0℃,最低气温:-9℃适合吃', '东北风,最高气温:9℃,最低气温:0℃适合吃',
#        '东南风,最高气温:27℃,最低气温:17℃适合吃', '西北风,最高气温:-13℃,最低气温:-19℃适合吃',
#        '西北风,最高气温:11℃,最低气温:2℃适合吃', 'OfMe(Live)评论',
#        '东风,最高气温:23℃,最低气温:17℃适合吃', 'theBorder评论',
#        '北风,最高气温:27℃,最低气温:15℃适合吃', '西北风,最高气温:17℃,最低气温:6℃适合吃',
#        '东北风,最高气温:13℃,最低气温:5℃适合吃', 'Alive评论', '北风,最高气温:13℃,最低气温:3℃适合吃',
#        '西南风,最高气温:15℃,最低气温:5℃适合吃', '东北风,最高气温:17℃,最低气温:13℃适合吃', '2018-12-1',
#        '西南风,最高气温:27℃,最低气温:18℃适合吃', '东南风,最高气温:28℃,最低气温:21℃适合吃', '嘿玛评分',
#        '2018-10-17', '2018-11-7', '东北风,最高气温:20℃,最低气温:13℃适合吃',
#        '2018-11-22', '道道道导演', '北风,最高气温:20℃,最低气温:7℃适合吃', '属相', '出生地',
#        '东北风,最高气温:20℃,最低气温:11℃适合吃', '东北风,最高气温:1℃,最低气温:-7℃适合吃',
#        '2018-11-17', '2018-11-20', '东北风,最高气温:3℃,最低气温:-1℃适合吃',
#        '西北风,最高气温:6℃,最低气温:0℃适合吃', '无持续风向,最高气温:24℃,最低气温:16℃适合吃',
#        '西北风,最高气温:19℃,最低气温:10℃适合吃', '北风,最高气温:19℃,最低气温:15℃适合吃',
#        '西北风,最高气温:-10℃,最低气温:-18℃适合吃', '2018-11-9',
#        '东南风,最高气温:24℃,最低气温:19℃适合吃', '2018-11-24',
#        '东南风,最高气温:15℃,最低气温:10℃适合吃', '东风,最高气温:17℃,最低气温:9℃适合吃',
#        '东北风,最高气温:13℃,最低气温:6℃适合吃', '西南风,最高气温:17℃,最低气温:2℃适合吃',
#        '东北风,最高气温:24℃,最低气温:16℃适合吃', '2018-12-11',
#        '无持续风向,最高气温:15℃,最低气温:4℃适合吃', '2018-10-10',
#        '西南风,最高气温:11℃,最低气温:-4℃适合吃', '无持续风向,最高气温:16℃,最低气温:3℃适合吃',
#        '西南风,最高气温:27℃,最低气温:16℃适合吃', '南风,最高气温:24℃,最低气温:11℃适合吃',
#        '西南风,最高气温:10℃,最低气温:2℃适合吃', 'Mine评论', '东北风,最高气温:15℃,最低气温:10℃适合吃',
#        '3040评分', '东南风,最高气温:26℃,最低气温:20℃适合吃', '西南风,最高气温:13℃,最低气温:-2℃适合吃',
#        '东风,最高气温:23℃,最低气温:15℃适合吃', '西南风,最高气温:18℃,最低气温:8℃适合吃', '2018-11-27',
#        '西北风,最高气温:2℃,最低气温:-7℃适合吃', '无持续风向,最高气温:31℃,最低气温:24℃适合吃', '(1)评论',
#        'That评论', '2018-11-10', '西南风,最高气温:17℃,最低气温:8℃适合吃',
#        '西北风,最高气温:8℃,最低气温:1℃适合吃', '无持续风向,最高气温:15℃,最低气温:12℃适合吃',
#        '南风,最高气温:13℃,最低气温:4℃适合吃', '西风,最高气温:16℃,最低气温:3℃适合吃',
#        '东北风,最高气温:13℃,最低气温:9℃适合吃', '东北风,最高气温:21℃,最低气温:12℃适合吃',
#        '东南风,最高气温:16℃,最低气温:13℃适合吃', '东北风,最高气温:23℃,最低气温:14℃适合吃',
#        '东风,最高气温:18℃,最低气温:11℃适合吃', '+心中的日月(Live)评论', '嘿玛类型',
#        '东风,最高气温:21℃,最低气温:14℃适合吃', '东南风,最高气温:10℃,最低气温:0℃适合吃',
#        '东风,最高气温:22℃,最低气温:12℃适合吃', 'Town店）特色菜', '东北风,最高气温:4℃,最低气温:-7℃适合吃',
#        '东北风,最高气温:7℃,最低气温:0℃适合吃', '东北风,最高气温:4℃,最低气温:-11℃适合吃',
#        '北风,最高气温:15℃,最低气温:8℃适合吃', '无持续风向,最高气温:3℃,最低气温:-4℃适合吃',
#        '西南风,最高气温:14℃,最低气温:2℃适合吃', '东北风,最高气温:26℃,最低气温:17℃适合吃', '3040类型',
#        '东北风,最高气温:14℃,最低气温:9℃适合吃', '西北风,最高气温:16℃,最低气温:7℃适合吃',
#        '东北风,最高气温:17℃,最低气温:9℃适合吃', '无持续风向,最高气温:29℃,最低气温:23℃适合吃',
#        '东南风,最高气温:17℃,最低气温:6℃适合吃', '北风,最高气温:15℃,最低气温:10℃适合吃',
#        '南风,最高气温:8℃,最低气温:-5℃适合吃', '3040导演', '东北风,最高气温:21℃,最低气温:9℃适合吃',
#        '西南风,最高气温:23℃,最低气温:10℃适合吃', '东北风,最高气温:17℃,最低气温:10℃适合吃',
#        '北风,最高气温:20℃,最低气温:10℃适合吃', '东北风,最高气温:10℃,最低气温:1℃适合吃',
#        '北风,最高气温:21℃,最低气温:14℃适合吃', '东北风,最高气温:13℃,最低气温:7℃适合吃',
#        'Dream(Live)评论', '无持续风向,最高气温:7℃,最低气温:3℃适合吃',
#        '西北风,最高气温:16℃,最低气温:10℃适合吃', '西南风,最高气温:-6℃,最低气温:-14℃适合吃',
#        'GOODBYE(Live)评论', '东风,最高气温:17℃,最低气温:11℃适合吃',
#        '东风,最高气温:20℃,最低气温:15℃适合吃', '东北风,最高气温:20℃,最低气温:15℃适合吃', '道道道主演',
#        '嘿玛国家地区', '3040国家地区', '北风,最高气温:26℃,最低气温:14℃适合吃',
#        '西南风,最高气温:2℃,最低气温:-12℃适合吃', '西北风,最高气温:12℃,最低气温:4℃适合吃',
#        '西北风,最高气温:7℃,最低气温:5℃适合吃', '道道道类型', '无持续风向,最高气温:21℃,最低气温:15℃适合吃',
#        '东风,最高气温:22℃,最低气温:14℃适合吃', '西北风,最高气温:7℃,最低气温:4℃适合吃',
#        '南风,最高气温:20℃,最低气温:11℃适合吃', '北风,最高气温:15℃,最低气温:2℃适合吃',
#        '西北风,最高气温:-3℃,最低气温:-10℃适合吃', '西南风,最高气温:9℃,最低气温:0℃适合吃',
#        '东北风,最高气温:2℃,最低气温:-12℃适合吃', '西风,最高气温:10℃,最低气温:-3℃适合吃',
#        '西风,最高气温:21℃,最低气温:11℃适合吃', '无持续风向,最高气温:22℃,最低气温:19℃适合吃',
#        '北风,最高气温:19℃,最低气温:11℃适合吃', '东风,最高气温:16℃,最低气温:3℃适合吃',
#        '无持续风向,最高气温:8℃,最低气温:-1℃适合吃', '西北风,最高气温:8℃,最低气温:5℃适合吃',
#        '东南风,最高气温:16℃,最低气温:7℃适合吃', '北风,最高气温:17℃,最低气温:8℃适合吃',
#        '西北风,最高气温:-7℃,最低气温:-20℃适合吃', '北风,最高气温:17℃,最低气温:4℃适合吃',
#        '无持续风向,最高气温:24℃,最低气温:20℃适合吃', '西风,最高气温:15℃,最低气温:5℃适合吃', '3040主演',
#        '无持续风向,最高气温:21℃,最低气温:13℃适合吃', '西南风,最高气温:3℃,最低气温:-13℃适合吃',
#        '南风,最高气温:21℃,最低气温:12℃适合吃', '西北风,最高气温:15℃,最低气温:10℃适合吃',
#        '东南风,最高气温:6℃,最低气温:-1℃适合吃', '西北风,最高气温:13℃,最低气温:1℃适合吃',
#        '东北风,最高气温:12℃,最低气温:6℃适合吃', '西南风,最高气温:8℃,最低气温:-2℃适合吃',
#        '东南风,最高气温:20℃,最低气温:15℃适合吃', '东风,最高气温:26℃,最低气温:13℃适合吃',
#        '南风,最高气温:20℃,最低气温:9℃适合吃', '东北风,最高气温:3℃,最低气温:-5℃适合吃',
#        '西南风,最高气温:7℃,最低气温:4℃适合吃', '南风,最高气温:14℃,最低气温:5℃适合吃',
#        '西南风,最高气温:-10℃,最低气温:-19℃适合吃', '东北风,最高气温:21℃,最低气温:15℃适合吃',
#        '东南风,最高气温:28℃,最低气温:23℃适合吃', '无持续风向,最高气温:31℃,最低气温:21℃适合吃',
#        '北风,最高气温:13℃,最低气温:6℃适合吃', '东北风,最高气温:27℃,最低气温:16℃适合吃',
#        '东南风,最高气温:25℃,最低气温:15℃适合吃', '南风,最高气温:18℃,最低气温:8℃适合吃',
#        '无持续风向,最高气温:29℃,最低气温:19℃适合吃', '北风,最高气温:25℃,最低气温:16℃适合吃',
#        '北风,最高气温:9℃,最低气温:5℃适合吃', 'Town店）人均价格', '3040口碑',
#        '东北风,最高气温:21℃,最低气温:14℃适合吃', '东北风,最高气温:12℃,最低气温:-1℃适合吃',
#        '无持续风向,最高气温:27℃,最低气温:22℃适合吃', '西北风,最高气温:11℃,最低气温:3℃适合吃',
#        '西南风,最高气温:20℃,最低气温:3℃适合吃', '东北风,最高气温:11℃,最低气温:5℃适合吃',
#        '西北风,最高气温:16℃,最低气温:5℃适合吃', '东南风,最高气温:21℃,最低气温:12℃适合吃',
#        '西南风,最高气温:8℃,最低气温:0℃适合吃', '东北风,最高气温:22℃,最低气温:17℃适合吃',
#        '东北风,最高气温:-2℃,最低气温:-11℃适合吃', '东北风,最高气温:13℃,最低气温:10℃适合吃',
#        '西北风,最高气温:21℃,最低气温:7℃适合吃', '北风,最高气温:26℃,最低气温:15℃适合吃',
#        '东南风,最高气温:7℃,最低气温:-1℃适合吃', '东北风,最高气温:9℃,最低气温:2℃适合吃',
#        '东北风,最高气温:0℃,最低气温:-11℃适合吃', 'Town店）订单量', '西北风,最高气温:8℃,最低气温:-4℃适合吃',
#        '西南风,最高气温:20℃,最低气温:4℃适合吃', '东北风,最高气温:5℃,最低气温:-8℃适合吃',
#        '南风,最高气温:15℃,最低气温:3℃适合吃', '北风,最高气温:23℃,最低气温:8℃适合吃',
#        '东北风,最高气温:25℃,最低气温:15℃适合吃', '西北风,最高气温:16℃,最低气温:6℃适合吃',
#        '东北风,最高气温:17℃,最低气温:12℃适合吃', '西风,最高气温:15℃,最低气温:1℃适合吃',
#        '西南风,最高气温:6℃,最低气温:-3℃适合吃', '东南风,最高气温:-1℃,最低气温:-10℃适合吃',
#        '西南风,最高气温:0℃,最低气温:-12℃适合吃', '南风,最高气温:15℃,最低气温:7℃适合吃',
#        '无持续风向,最高气温:18℃,最低气温:15℃适合吃', '东北风,最高气温:14℃,最低气温:11℃适合吃',
#        '西北风,最高气温:12℃,最低气温:2℃适合吃', '东北风,最高气温:19℃,最低气温:14℃适合吃',
#        '东北风,最高气温:21℃,最低气温:19℃适合吃', '东北风,最高气温:20℃,最低气温:17℃适合吃',
#        '东北风,最高气温:11℃,最低气温:-2℃适合吃', '西南风,最高气温:10℃,最低气温:-1℃适合吃',
#        '东南风,最高气温:25℃,最低气温:20℃适合吃', '西南风,最高气温:17℃,最低气温:7℃适合吃',
#        '无持续风向,最高气温:18℃,最低气温:7℃适合吃', '东南风,最高气温:18℃,最低气温:7℃适合吃',
#        '南风,最高气温:22℃,最低气温:10℃适合吃', '西南风,最高气温:20℃,最低气温:7℃适合吃',
#        '无持续风向,最高气温:26℃,最低气温:20℃适合吃', '东风,最高气温:20℃,最低气温:17℃适合吃',
#        '北风,最高气温:16℃,最低气温:-1℃适合吃', '东北风,最高气温:8℃,最低气温:2℃适合吃',
#        '东北风,最高气温:23℃,最低气温:13℃适合吃', '无持续风向,最高气温:26℃,最低气温:12℃适合吃',
#        '东北风,最高气温:3℃,最低气温:-7℃适合吃', '东南风,最高气温:11℃,最低气温:5℃适合吃',
#        '无持续风向,最高气温:15℃,最低气温:13℃适合吃', '东北风,最高气温:8℃,最低气温:0℃适合吃',
#        '东北风,最高气温:5℃,最低气温:-3℃适合吃', '南风,最高气温:19℃,最低气温:12℃适合吃',
#        '西南风,最高气温:18℃,最低气温:4℃适合吃', '东北风,最高气温:18℃,最低气温:15℃适合吃',
#        '东南风,最高气温:20℃,最低气温:12℃适合吃', '北风,最高气温:10℃,最低气温:3℃适合吃',
#        '西北风,最高气温:26℃,最低气温:13℃适合吃', '西北风,最高气温:7℃,最低气温:-4℃适合吃',
#        '东风,最高气温:17℃,最低气温:15℃适合吃', '北风,最高气温:21℃,最低气温:13℃适合吃',
#        '南风,最高气温:17℃,最低气温:10℃适合吃', '东北风,最高气温:24℃,最低气温:19℃适合吃',
#        '西南风,最高气温:13℃,最低气温:0℃适合吃', '东北风,最高气温:21℃,最低气温:13℃适合吃',
#        '西南风,最高气温:8℃,最低气温:-1℃适合吃', '北风,最高气温:13℃,最低气温:0℃适合吃', 'Town店）评分',
#        '西北风,最高气温:-5℃,最低气温:-10℃适合吃', '东北风,最高气温:23℃,最低气温:15℃适合吃',
#        '西北风,最高气温:-1℃,最低气温:-4℃适合吃', '东南风,最高气温:-1℃,最低气温:-9℃适合吃',
#        '东北风,最高气温:22℃,最低气温:12℃适合吃', '东南风,最高气温:0℃,最低气温:-7℃适合吃',
#        '西南风,最高气温:-3℃,最低气温:-13℃适合吃', '无持续风向,最高气温:19℃,最低气温:3℃适合吃',
#        '无持续风向,最高气温:29℃,最低气温:24℃适合吃', '南风,最高气温:19℃,最低气温:2℃适合吃',
#        '西南风,最高气温:12℃,最低气温:0℃适合吃', '东北风,最高气温:2℃,最低气温:-6℃适合吃',
#        '东北风,最高气温:21℃,最低气温:8℃适合吃', '无持续风向,最高气温:3℃,最低气温:-5℃适合吃', 'Town店）地址',
#        '西南风,最高气温:17℃,最低气温:5℃适合吃', '东北风,最高气温:13℃,最低气温:8℃适合吃',
#        '西北风,最高气温:12℃,最低气温:7℃适合吃', '道道道评分', '西北风,最高气温:3℃,最低气温:-6℃适合吃',
#        '无持续风向,最高气温:18℃,最低气温:12℃适合吃', '无持续风向,最高气温:13℃,最低气温:1℃适合吃',
#        '西北风,最高气温:4℃,最低气温:-3℃适合吃', '南风,最高气温:21℃,最低气温:11℃适合吃',
#        '东风,最高气温:23℃,最低气温:13℃适合吃', '无持续风向,最高气温:17℃,最低气温:2℃适合吃',
#        '南风,最高气温:16℃,最低气温:4℃适合吃', '西北风,最高气温:2℃,最低气温:-5℃适合吃',
#        '西北风,最高气温:19℃,最低气温:12℃适合吃'], dtype=object)

# %%
## Data Clean and proprocess on the Entity and Category

def categoryClean(df , targetCategory):
        
        targetCategoryLen = len(targetCategory)
        #print("\n Target Category Length " + targetCategory + " :" , targetCategoryLen)
        #print("------------------------------------------------------------------------------------------------------------------------")
        
        # Count the "Category" value containing "targetCategory"
        comment_count = df[df['Category']== targetCategory].shape[0]
        #print("\nNumber of rows where 'Category' contains " + targetCategory + " :", comment_count)
        
        #print("------------------------------------------------------------------------------------------------------------------------")
        filtered_data = df[df['Category'].str.contains(targetCategory) & (df['Category'].str.len() > targetCategoryLen)]
        #print(filtered_data)
        
        #print("------------------------------------------------------------------------------------------------------------------------")
        targetRow_ids = df[df['Category'].str.contains(targetCategory) & (df['Category'].str.len() > targetCategoryLen)].index
        #print(targetRow_ids)
        
        #print("------------------------------------------------------------------------------------------------------------------------")
        distinct_categories = df[df['Category'].str.contains(targetCategory)]['Category'].unique()
        #print("Distinct categories containing " + targetCategory + " :", distinct_categories)
        
        ## update 
        df.loc[df['Category'].str.contains(targetCategory), 'Entity'] = df['Entity'] + df['Category'].str.split(targetCategory).str[0]
        df['Category'] = df['Category'].apply(lambda x: targetCategory if targetCategory in x else x)
        
        # Count the "Category" value containing "targetCategory"
        comment_count = df[df['Category'] == targetCategory].shape[0]
        #print("\nNumber of rows where 'Category' contains " + targetCategory + " :", comment_count)
        
        #print("------------------------------------------------------------------------------------------------------------------------")
        filtered_data = df[df['Category'].str.contains(targetCategory) & (df['Category'].str.len() > targetCategoryLen)]
        #print(filtered_data)
        
        #print("------------------------------------------------------------------------------------------------------------------------")
        distinct_categories = df[df['Category'].str.contains(targetCategory)]['Category'].unique()
        #print("Distinct categories containing " + targetCategory + " :", distinct_categories)
        
        return df

# %%
## Data Clean and proprocess on the Category

cateList = ['评论', '主演','口碑','导演','类型','评分','国家地区','适合吃','特色菜','人均价格', '订单量','地址',]

for cat in cateList:
    df = categoryClean(df, cat)

# %%
## Check Category is cleaned
distinct_categories = df['Category'].unique()
distinct_categories
# Out:
# array(['2018-11-14', '喜好', '评论', '特色菜', '简介', '适合听', '评分', '人均价格', '喜欢',
#        '适合吃', '2018-10-13', '主演', '2018-10-16', '演唱', '2018-10-15',
#        '2018-12-25', '2018-12-27', '类型', '获奖', '成就', '口碑', '身高',
#        '2018-11-12', '2018-12-24', '2018-11-19', '订单量', '导演', '2018-11-2',
#        '喜欢的新闻', '2018-10-26', '新闻', '星座', '2018-11-11', '2018-12-21',
#        '2018-10-11', '国家地区', '2018-12-12', '2018-10-23', '2018-11-8',
#        '2018-10-1', '成分', '地址', '2018-12-26', '2018-10-12', '2018-12-17',
#        '时间', '2018-10-4', '2018-11-1', '2018-12-16', '2018-12-7',
#        '2018-12-3', '2018-12-13', '血型', '2018-12-6', '2018-11-25',
#        '2018-11-26', '2018-12-14', '2018-12-9', '2018-12-19', '2018-10-8',
#        '2018-10-27', '2018-10-24', '2018-12-8', '2018-12-2', '2018-11-5',
#        '2018-10-19', '体重', '2018-12-15', '2018-10-25', '2018-10-21',
#        '2018-10-5', '2018-11-18', '2018-10-20', '2018-10-18',
#        '2018-12-23', '2018-10-3', '2018-10-9', '2018-10-6', '2018-11-23',
#        '2018-11-3', '2018-11-21', '2018-12-5', '生日', '2018-11-6',
#        '2018-12-22', '2018-12-20', '2018-11-4', '2018-12-4', '日期',
#        '2018-12-18', '2018-10-14', '2018-12-10', '2018-10-7',
#        '2018-10-22', '2018-11-13', '2018-11-16', '2018-10-2',
#        '2018-11-15', '2018-12-1', '2018-10-17', '2018-11-7', '2018-11-22',
#        '属相', '出生地', '2018-11-17', '2018-11-20', '2018-11-9', '2018-11-24',
#        '2018-12-11', '2018-10-10', '2018-11-27', '2018-11-10'],
#       dtype=object)

# %% [markdown]
# **Knowledge Tree**

# %%
## Construct Knowledge Tree Function

import networkx as nx
import pandas as pd

# Assuming 'df' is your DataFrame containing the data
G = nx.DiGraph()  # Directed graph can still function as a tree

# Add nodes and edges based on the DataFrame
for index, row in df.iterrows():
    entity_id = f"Entity: {row['Entity']}"
    category_id = f"Category: {row['Category']} ({row['Entity']})"
    answer_id = f"Answer: {row['Answer']} ({row['Category']})"

    # Ensure that nodes for each level (entity, category) are unique per entity-category pair
    if entity_id not in G:
        G.add_node(entity_id, type='Entity', name=row['Entity'])
    if category_id not in G:
        G.add_node(category_id, type='Category', name=row['Category'])
    
    # Answers can be multiple per category, so they are always added
    G.add_node(answer_id, type='Answer', content=row['Answer'])
    
    # Connect nodes hierarchically
    G.add_edge(entity_id, category_id)
    G.add_edge(category_id, answer_id)

# %% [markdown]
# **Part of Speech Function**

# %%
## Extract the special keyword in brackets, which will not be processed by the extractPOS function.

def checkSentence(sentence):
    separated_sentences = []
    temp_sentence = ""
    in_bracket = False

    for char in sentence:
        if char == "『" or char == "《":
            in_bracket = True
            if temp_sentence:
                separated_sentences.append(temp_sentence)
                temp_sentence = ""
            temp_sentence += char
        elif char == "』" or char == "》":
            in_bracket = False
            temp_sentence += char
            separated_sentences.append(temp_sentence)
            temp_sentence = ""
        elif char == "。" and not in_bracket:
            separated_sentences.append(temp_sentence)
            temp_sentence = ""
        else:
            temp_sentence += char

    if temp_sentence:
        separated_sentences.append(temp_sentence)

    return separated_sentences

# %%
## For knowledge Tree searching, extract part of the speech from the sentence.

import jieba.posseg as pseg

def extractPOS(sentences):

    result = []
    special_words = []

    for sentence in sentences:
        if '『' in sentence or '《' in sentence:
            
            # Remove the brackets
            sentence = sentence.replace('『', '@').replace('』', '@').replace('《', '@').replace('》', '@')
            
            #result.append(sentence)
            special_words.append(sentence)
        else:
            allowSentencePOS = ("a", "ad", "ag", "an", ## 形容词 
                                "b", # 区别词
                                "c", # 连词
                                "f", 
                                "g", 
                                "h",
                                "i", 
                                "j", 
                                "k", 
                                "l", 
                                "m", "mg", "mq", 
                                "n", "ng", "nr", "nrfg", "nrt","ns", "nt", "nz", 
                                "o", 
                                "q", 
                                "s", 
                                "t", "tg",
                                "v", "vd", "vg", "vi", "vn","vq" ## 动词
                                )
            
            """"
            ## This part POS will not be extracted
            exclude = ( "p", ## 介词
                "d", "df", "dg", # 副词
                "e", # 叹词 
                "r", "rg", "rr", "rz",  ## 代词
                "u",  "ud", "ug", "uj", "ul", "uv", "uz",  ## 助词
                "x",  ## 非语素词（包含标点符号
                "y", ## 语气词
                "z","zg" ## 助词
              )
            """
            
            sentence = pseg.lcut(sentence)
            seg_words = [word for word, pos in sentence if pos in allowSentencePOS]
            result.extend(seg_words)
            
    return special_words+result

# %% [markdown]
# **Retrieve Data from Knowledge Tree**

# %%
## Retrieve Data from Knowledge Tree

def has_common_character(keyword, category):
    return any(char in category for char in keyword)

# %%
## Knowledge Tree Search function

import jieba
import random

def retrieve_answers(graph, query):
    segmented_keywords = extractPOS(checkSentence(query))
    special_keywords = [kw.strip('@') for kw in segmented_keywords if kw.startswith('@')]
    regular_keywords = [kw for kw in segmented_keywords if not kw.startswith('@')]

    category_answers = {}  # Store answers grouped by categories
    special_categories = {'新闻', '评论'}

    # Top-Down Search: From entities to categories to answers
    for entity_node in (n for n in graph.nodes if graph.nodes[n]['type'] == 'Entity'):
        entity_keywords = [kw for kw in regular_keywords if kw == graph.nodes[entity_node]['name']]
        if entity_keywords:
            for category_node in graph.successors(entity_node):
                category_keywords = [kw for kw in regular_keywords if has_common_character(kw, graph.nodes[category_node]['name'])]
                if category_keywords:
                    for answer_node in graph.successors(category_node):
                        category_name = graph.nodes[category_node]['name']
                        answer_content = graph.nodes[answer_node]['content']
                        if category_name not in category_answers:
                            category_answers[category_name] = []
                        if category_name not in special_categories:
                            category_answers[category_name].append(category_name+answer_content)
                        else:
                            category_answers[category_name].append(answer_content)

    # Bottom-Up Search: From answers to categories to entities
    for answer_node in (n for n in graph.nodes if graph.nodes[n].get('type') == 'Answer'):
        if any(kw == graph.nodes[answer_node]['content'] for kw in special_keywords):
            for category_node in graph.predecessors(answer_node):
                category_name = graph.nodes[category_node]['name']
                if any(has_common_character(kw, category_name) for kw in regular_keywords):
                    for entity_node in graph.predecessors(category_node):
                        if category_name not in category_answers:
                            category_answers[category_name] = []
                        category_answers[category_name].append(graph.nodes[entity_node]['name'] + category_name)

    final_answers = []
    require_llama = False
    for category, answers in category_answers.items():
        if category in special_categories:
            # Randomly pick one answer if category is special
            final_answers.append(random.choice(answers))
        else:
            # Collect all answers for other categories
            final_answers.extend(answers)
            require_llama = True  # Indicate further processing may be needed for non-special categories

    return final_answers, require_llama

# %%
## Function Testing
input_query = "你知道张柏芝的生日是什么时候吗？"
answers = retrieve_answers(G, input_query)
print(f"Question: {input_query} Response: {answers}")
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.021 seconds.
# Prefix dict has been built successfully.
# Question: 你知道张柏芝的生日是什么时候吗？ Response: (['生日1980-5-24', '出生地中国香港'], True)

# %% [markdown]
# **Llama2(Knowledge Tree) + Fine-tuned Bart**

# %%
## System Prompt for Llama2

system_prompt = """
Please answer the following question based on the provided context.
Provide only the direct answers without any additional explanations or context.
Please only output answers only.
Please ensure that your responses are socially unbiased and positive in nature.
If a question does not make any sense or is not factually coherent, explain why instead of answering something not correct.
If you don't know the answer, please don't share false information.
"""

# %%
## Llama2 Query Function

def query_llama(query, context):
    # Test
    prompt = f"""
    <s>[INST] <<SYS>>
    {system_prompt}
     <</SYS>> [/INST]</s>

    <s>[INST]
    Question: {query}
    Context: {context}
    Answer:
    [/INST]
        """

    output = pipe_llama(
        prompt,
        do_sample=True,
        max_new_tokens=256,
        top_k=40,
        top_p=0.95,
        temperature=0.75,
        return_full_text=False,
        repetition_penalty=1
    )
    return output[0]['generated_text']

# %%
## Enquiry on Llama2 or BART

def query_system(graph, query):
    # Attempt to retrieve answers from the knowledge graph
    answers, require_llama = retrieve_answers(graph, query)
    
    # If answers are found in the graph, return
    if answers and require_llama:
        # pass to llama
        return "Answer from knowledge graph:", query_llama(query, answers)
    elif answers and not require_llama:
        # return directly
        return "Answer from knowledge graph:", answers
    # If no answers are found, -> language model
    else:
        generated_answer = pipe_bart(query)
        return "Answer from language model:", generated_answer[0]['generated_text']

# %%
## Function Testing
query = "帮我点一首《想你》吧"
result = query_system(G, query)
print(result)
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1132: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ('Answer from language model:', '正 在 为 你 播 放 《 想 你 》')

# %%
## Function Testing
query = "张国荣哪里出生的？"
result = query_system(G, query)
print(result)
# Out:
# ('Answer from knowledge graph:', '张国荣出生地是香港九龙。')

# %%
## Function Testing
query = "说说张学友的新闻"
result = query_system(G, query)
print(result)
# Out:
# ('Answer from knowledge graph:', ['7月8日，河南洛阳民警在张学友演唱会现场附近执勤时，发现一车辆存在交通违法，遂上前了解情况。经查，驾车男子提供的个人信息与其本人不符，身份可疑。经进一步核实，原来该男子从563公里远的武汉赶到洛阳，就是为看张学友演唱会。目前，该男子对冒用他人信息，无证驾驶行为供认不讳，案件正在进一步调查中。据悉，洛阳演唱会现场蜀黍还抓了一波黄牛党，正在核实中。'])

# %% [markdown]
# **Import test.txt**

# %%
## import test.txt Dataset
from datasets import Dataset, load_dataset

dataset = load_dataset(
    'json',
    data_files={
        'test':
        '/kaggle/input/durecdial/test.txt',
    }
)

# %% [markdown]
# **Generate result.txt**

# %%
## Preprocess test.txt Dataset

conversation_list = dataset['test']['conversation']
conversation_list

# Format each turn in the context
formatted_context = []

for conversations in conversation_list:
    
    ## Label the last user inquiry for Llama2(Knowledge Tree) inquiry approach
    conversations[-1] = conversations[-1].split(':')[0] + ':' + '##@' + conversations[-1].split(':')[1] + '@##'
    
    ## Formatted the whole data for BART inquiry approach
    formatted_conversation = ''.join(conv.replace('user:', '\nInstruction:\n').replace('bot:','\nResponse:\n').replace(' ','') for conv in conversations)
    
    ## Append into a list 
    formatted_context.append(formatted_conversation.lstrip('\n'))

# %%
## This Function is the backend response API to generate response to use.

import re

def generate_text(user_input):
    # Retrieve the latest user input
    match = re.search(r'##@(.*?)@##', user_input)
    
    if match:
        # Extracts text found between the markers
        query = match.group(1)
        full_input_without_markers = re.sub(r'##@.*?@##', query, user_input)
    else:
        query = user_input
        full_input_without_markers = user_input
    
    # Attempt to retrieve from the knowledge set for Llama2
    answers, require_llama = retrieve_answers(G, query)

    # If answers are found in the graph, and further processing with Llama2 is required
    if answers and require_llama:
        return query_llama(query, answers)
    elif answers and not require_llama:
        return answers
    else:
        # If no answers are found, use BART model to generate an answer from the full context without markers
        inputs = tokenizer_bart.encode(full_input_without_markers, return_tensors="pt")
        outputs = model_bart.generate(input_ids=inputs.to(device), max_new_tokens=126)
        response_text = tokenizer_bart.decode(outputs[0], skip_special_tokens=True)
        return response_text

# %%
## Generate Response on the test.txt dataset
total_result = []

for con in formatted_context:
    con_result = generate_text(con)
    total_result.append(con_result)

# %%
# Create a new list to store the results
# total_result contains list elements, needs to convert into string for Evaluation

modified_total_result = []

# Iterate through candidate_result and convert inner lists to strings
for item in total_result:
    if isinstance(item, list):
        modified_total_result.append(' '.join(item).replace(' ',''))
    else:
        modified_total_result.append(item.replace(' ',''))

# %%
# Create a DataFrame to store prediction results for each record.
df_response = pd.DataFrame(modified_total_result, columns=['Response'])

## Generate result.txt for submission
df_response['Response'].to_csv('result.txt', index=False, header=False)

# %%
"""
## Result Checking
df_formatted_context = pd.DataFrame(formatted_context)
df_total_result = pd.DataFrame(total_result)

merged_df = pd.concat([df_formatted_context, df_total_result], axis=1)
merged_df.to_csv('result_combine.csv', index=False, header=False)
"""

# %% [markdown]
# **Evaluation**

# %%
## Get test
conversation_list = dataset['test']['conversation']
conversation_list
# Out:
# [['user: 周迅的星座是什么？',
#   'bot: 周迅是天秤座。',
#   'user: 你真棒！知道的真多。',
#   'bot: 我还知道周迅可是亚洲电影大奖最佳女主角呢！',
#   'user: 周迅可是我的偶像，她的演技超好。',
#   'bot: 她是真正的为演艺而生，而且还获得过华语电影传媒大奖最佳女演员。',
#   'user: 我非常喜欢她演的电影。'],
#  ['user: 能告我一下黄渤的生日么？',
#   'bot: 好的，1974年8月26日。',
#   'user: 好的，谢谢。',
#   'bot: 看你挺喜欢黄渤的，告诉你哦，他曾经获得过中国电影表演艺术学会金凤凰奖。',
#   'user: 果然是我喜欢的明星。',
#   'bot: 好呀，北京大学生电影节最佳男演员，中国电影导演协会年度男演员。',
#   'user: 你知道的不少呀。',
#   'bot: 那当然，既然说到你的偶像，那为你推荐这部他主演的《疯狂的赛车》，电影对观众情绪的调动，对笑料包袱的运用，对影迷智商和注意力的挑战都是异常出色的，即有趣又高端。',
#   'user: 看来这个电影不错哦，喜剧片吗？',
#   'bot: 对，喜剧动作片。',
#   'user: 好的，那我就看看吧。',
#   'bot: 相信我你不会失望的。',
#   'user: 我还有事。先忙去啦。'],
#  ['user: 你好！今天天气怎么样呢？',
#   'bot: 多云,无持续风向,最高气温:24℃,最低气温:20℃',
#   'user: 好的，谢谢你告诉我',
#   'bot: 不客气呢，今天的天气适合吃酸菜鱼哦',
#   'user: 酸菜鱼是我最喜欢',
#   'bot: 鱼是很有营养的呢，多吃点比较好',
#   'user: 正好呀，可以暖暖身子',
#   'bot: 推荐你去《品蜀国精品川菜（科学城店）》，酸菜鱼可是他们店的特色菜',
#   'user: 好的呀，人均价格是多少呢？',
#   'bot: 58元，不算特别高',
#   'user: 地址在哪？',
#   'bot: 黄埔区科学城科学大道193号高德汇购物中心3楼',
#   'user: 评分怎么样呢？',
#   'bot: 4.2呢',
#   'user: 好的，明天中午12点2个人，帮我预定一下。'],
#  ['user: 今天几号了',
#   'bot: 5月24号。',
#   'user: 谢谢',
#   'bot: 你知道吗，今天是张柏芝的生日哦。',
#   'user: 真的呀~',
#   'bot: 她可是第23届香港电影金像奖最佳女主角哦。',
#   'user: 女神一如既往的优秀',
#   'bot: 喜欢她的话，给你推荐一部张柏芝主演的电影《星愿》，是感动我的唯一一部爱情电影。',
#   'user: 这个电影的导演是谁？',
#   'bot: 导演是马楚成',
#   'user: 口碑怎么样'],
#  ['user: 整个吴亦凡的新闻看看',
#   'bot: 现在就整。最近啊，一夜之间，吴亦凡的一些聊天记录、截图、音频被爆出，吴亦凡突然成了网友八卦的新话题！小g娜还发微博自说吴亦凡女友，质问吴就算分手也要给一句话。后来吴亦凡工作室就发表声明说网传女友之事纯属虚构。',
#   'user: 谢谢哈，挺有意思的，你可太棒了',
#   'bot: 客气啥啊，我还有更多有关他的新闻了，还要看吗？',
#   'user: 必看啊，反正现在还有时间',
#   'bot: 是这样的啊，据Variety报道，吴亦凡新专辑销量被认为是通过欺诈手段取得，将不会计入iTunes销量向尼尔森汇报，因此也不会计入Billboard榜单。有网友发现美国一则新闻也对相关事件进行了报道',
#   'user: 还有这样的事呢，不过谢谢你的推荐',
#   'bot: 是了么，摊上这事儿也是倒霉，可是还是好好做音乐来的强',
#   'user: 一不注意都不早了，那我睡觉去了啊，拜拜'],
#  ['user: 我想点一首『倩女幽魂』.',
#   'bot: 正在为你播放『倩女幽魂』',
#   'user: 好的，谢谢',
#   'bot: 不客气，其实张国荣的『当爱已成往事』也同样很好听，也是他众多歌曲中最让人无法忘记的作品，你也可以听听看',
#   'user: 这首歌我听过很多次啦，换一首'],
#  ['user: 今天的天气好像还可以呢，是吗？',
#   'bot: 是的，今天是晴转多云，东北风，最高气温23℃，最低气温12℃',
#   'user: 我就看着外面的天不错，你还告诉我具体信息，太棒啦',
#   'bot: 这都是举手之劳啦，你说嘿嘿，这样的天气，来一份『剁椒鱼头』，不是美呆了吗？',
#   'user: 可不是么，我三天两头的就想吃哈哈哈',
#   'bot: 是呢？是因为里面加了泡椒，让你非常有食欲吗？',
#   'user: 对啊，除了泡椒，自制剁椒这些东西混合起来简直是完美！',
#   'bot: 是不是又馋啦？悄悄告诉你，在『如家川菜馆』订『剁椒鱼头』的话，保你满意呢',
#   'user: 是吗？人均价格还可以吧？'],
#  ['user: 范冰冰多重啊？',
#   'bot: 56kg哦。',
#   'user: 你真的知道啊，谢谢你告诉我',
#   'bot: 不客气啦，看你挺关注她的，你应该很喜欢她吧。',
#   'user: 是的呢，她可是当红人气女星呢，非常喜欢她',
#   'bot: 是啊，她还获得了华语电影传媒大奖观众票选最受瞩目女演呢。',
#   'user: 确实是，太完美了',
#   'bot: 这么喜欢她，她的电影『爱情呼叫转移』看看呦，很温馨的电影。也被称为都市麻辣爱情贺岁喜剧。',
#   'user: 那电影主演都有谁呢',
#   'bot: 徐峥，范冰冰，伊能静，黄圣依等。',
#   'user: 那不错哦，有时间看看。'],
#  ['bot: 晚上好啊，金立国，最近学习情况怎么样？',
#   'user: 说起学习我很难受，最近学习退步了。',
#   'bot: 没关系，好好努力，下次会进步的。',
#   'user: 谢谢你的安慰。',
#   'bot: 除了学习以外，闲暇时候也可以看看新闻，你最喜欢谁的新闻呢？',
#   'user: 我最喜欢周杰伦的新闻。',
#   'bot: 正好有条关于周杰伦的新闻说给你听：『台湾歌手周杰伦被聘请成为“中国禁毒宣传形象大使”。周杰伦他说，他将以阳光健康的形象向广大青少年发出“拒绝毒品，拥有健康”的倡议，并承诺今后将积极宣传毒品危害，倡导全民珍爱生命，远离毒品。',
#   'user: 谢谢你的推荐，我杰伦果然是很正能量的呢。'],
#  ['bot: 李帅洋，最近可好啊',
#   'user: 最近还不错',
#   'bot: 是不是有什么高兴的事呢',
#   'user: 是啊，最近刚升了职',
#   'bot: 那还挺不错的呢，那你要不要听首《似水流年》来尽兴呢，张国荣的声音很有韵味噢。',
#   'user: 我暂时不想聊歌曲',
#   'bot: 好的吧，那我们来聊聊这首歌的主唱张国荣吧。',
#   'user: 我很喜欢张国荣呢，他是不可多得的人才。',
#   'bot: 他的唱功很厉害哦，获得过台湾电影金马奖最佳原创歌曲奖',
#   'user: 他在电影方面也很有造诣的，曾获得香港电影金像奖最佳男主角',
#   'bot: 是呢，那给你推荐一部他的电影《霸王别姬》给你看看哦，当真是风华绝代啊。',
#   'user: 暂时不想看',
#   'bot: 好的吧，那再给你推荐《星月童话》，哥哥留下的一段美丽童话。',
#   'user: 这个看起来还不错，那你能告我这部电影的导演是谁吗'],
#  ['user: 几点了？',
#   'bot: 现在是下午18点整',
#   'user: 真棒。',
#   'bot: 我还知道银川今天的天气为多云，有东北风，最高气温零下8摄氏度，最低气温零下16摄氏度',
#   'user: 可以啊，连天气情况都有，给你点个赞。'],
#  ['user: 你知道何炅的生日吗？',
#   'bot: 他的生日是1974年4月28日',
#   'user: 你真棒，你知道的可真多！',
#   'bot: 何炅可是家喻户晓的人，是位名嘴哦。',
#   'user: 对啊，我很喜欢他的主持风格！',
#   'bot: 他不仅主持节目好，是中国大学生电视节最受大学生喜爱电视节目男主持人，唱歌也超级棒呢',
#   'user: 他有什么好听的歌吗》',
#   'bot: 他的《另一个自己》非常棒哦，何老师唱歌真的很温暖很好听有种很神奇的抚慰人心的力量',
#   'user: 我还没听过这一首呢',
#   'bot: 那你可以听一下哦，41岁的何炅，把挑战“另一个自己”、完成导演梦的心声融进歌里，传递出“一切都来得及”的青春态度。',
#   'user: 听起来很不错，我很想听一下',
#   'bot: 那要我为你播放这首歌吗？',
#   'user: 好的，播放吧'],
#  ['user: 晚上好，今天天气怎么样呢？',
#   'bot: 你好，天津今日霾,西北风,最高气温:9℃,最低气温:3℃，出门别忘了戴口罩啊。',
#   'user: 好的呢，谢谢。',
#   'bot: 不用客气。今天这个天气适合吃剁椒鱼头哦。',
#   'user: 我最喜欢吃的菜就是剁椒鱼头了',
#   'bot: 香辣口味哦，多放点剁椒觉得很过瘾。',
#   'user: 真的是啥也知道，我明天就去吃去。'],
#  ['bot: ，晚上好呀！',
#   'user: 晚上好，今天真是一个美妙的夜晚。',
#   'bot: 看来发生了让你很开心的事情啊。',
#   'user: 这都被你发现了啊！今天发奖金了。'],
#  ['bot: 姬琪振，晚上好啊，最近在忙什么呢？',
#   'user: 最近哦，说了你可能不信，发奖金了呢哈哈哈哈哈可真开心啊',
#   'bot: 都是你自己努力的成果，恭喜哦！',
#   'user: 谢谢喔，我都感受到你的喜悦了呢',
#   'bot: 不客气，在这愉悦的时刻，我给你推荐一部电影吧，『解救吾先生』怎么样？这可是一部难得的华语犯罪片呢！',
#   'user: 虽然蛮开心的啦，不过我暂时不想聊电影咯',
#   'bot: 那好吧，咱们聊一聊他的主演，双料影帝刘德华怎么样？',
#   'user: 刘德华我还是感兴趣的',
#   'bot: 你知道吗？刘德华获得过很多成就呢，三届香港电影金像奖最佳男主角，两届ChannelV亚洲最受欢迎歌手等等，真的是很多人心目中的偶像了',
#   'user: 知道的啦，是我喜欢的明星呢，还是香港特别行政区荣誉勋章佩戴者，已经不单单是一名演艺工作者这么简单了！',
#   'bot: 这都是多年努力的成果啊，除了影帝他也是歌神，他的歌曲『最好的声音』是一曲难得的佳作，百花齐放百家争鸣，要听一下吗？',
#   'user: 是好听啦，我有听很多遍，但是今天不想听喔'],
#  ['user: 今天是什么天气呀？',
#   'bot: 今天的天气晴~多云,北风,最高气温:25℃,最低气温:16℃，天气不错呢',
#   'user: 谢谢你，你知道的真多呀',
#   'bot: 今天这种天气温适合吃『口水鸡』了呢',
#   'user: 口水鸡可是我最爱的一道凉菜了呢',
#   'bot: 我也觉得不错光是听着就让人垂涎三尺呢！',
#   'user: 是的，真想现在就去吃呢'],
#  ['user: 有没有王力宏的新闻',
#   'bot: 肯定有啊，前两天，钢琴王子李云迪和音乐创作才子王力宏同台了，听说两位在舞台上斗琴演奏了《金蛇狂舞》。',
#   'user: 呀，两大男神同台，大饱眼福啊！你厉害哦',
#   'bot: 我还为你收集了另外一个呢，前两天，水果姐凯蒂·佩里发了新歌《365》，结果被不少网友说，她的MV风格与王力宏《A.I.爱》MV很相似，甚至许多拍摄场景概念都有重合。对此，王力宏回应说，他觉得被模仿是最高的称赞。',
#   'user: 你可真懂我呢，男神果然是男神，就算被模仿，也难以超越哈哈',
#   'bot: 是啊，这种豁达大气的胸怀真是成功的必备啊！',
#   'user: 所以才值得我喜欢了这么多年'],
#  ['user: 你好，请问电影『李小龙：勇士的旅程』的主演是谁?',
#   'bot: 主演是成龙哦。',
#   'user: 好的呢，谢谢啦，你真棒！',
#   'bot: 话说成龙可是老牌影星了，还是香港十大杰出青年之一呢。',
#   'user: 对啊，我可喜欢他了！',
#   'bot: 是很优秀呢，还获得了第89届奥斯卡金像奖终身成就奖哦。',
#   'user: 真的好厉害，说的我更加崇拜他了呢！',
#   'bot: 那他主演的这部很刺激的非常不错的情节以及剧情的『英伦对决』你一定不能错过了。',
#   'user: 这部电影是什么类型的？'],
#  ['user: 你好，请帮我放一首『无形的手』',
#   'bot: 好的，现在就为你放《无形的手》。',
#   'user: 歌曲真好听，不愧是我偶像何炅唱的歌！',
#   'bot: 你还可以听一听何炅演唱的《白天不懂夜的黑(Live)》，很多人都很喜欢何老师的嗓音呢',
#   'user: 这首歌我已经听过啦，也很不错呢，还有其他的吗？'],
#  ['bot: 中午好呀，郭芳洋小美眉。',
#   'user: 中午好。',
#   'bot: 工作顺心吗最近？',
#   'user: 最近压力有点大呢。',
#   'bot: 好的吧，那聊点轻松的话题，你最喜欢谁的新闻呢？',
#   'user: 周杰伦的。',
#   'bot: 刚好有一则关于周杰伦的新闻：台湾歌手周杰伦被聘请成为“中国禁毒宣传形象大使”。周杰伦他说，他将以阳光健康的形象向广大青少年发出“拒绝毒品，拥有健康”的倡议，并承诺今后将积极宣传毒品危害，倡导全民珍爱生命，远离毒品。',
#   'user: 真的是好正能量啊。',
#   'bot: 是的呢，大家都应该向他学习。',
#   'user: 是呢，我会跟着偶像周杰伦一起拒绝毒品的。'],
#  ['user: 最近有什么郭富城的新闻吗？',
#   'bot: 有的呢！前一阵还有新浪娱乐的消息说，郭富城在香港参加某杂志活动的时候，第一次公开回应了和方媛的新恋情。被问到女友的过去时，他回应说每个人都有过去，我不会去计较过去怎么样。至于未来是否有结婚打算，说目前还是先了解，至于未来是怎样，说真的还不知道。',
#   'user: 你看，之前还说不知道以后会怎么样呢，现在都结婚了，你说咋这么快啊',
#   'bot: 哈哈哈，是呢，香港媒体还拍到了方媛怀孕的照片呢。',
#   'user: 是吗，这也太神速了吧',
#   'bot: 是这样的哦。最近有媒体拍到郭富城与方媛一起逛街挑母亲节礼物，当天方媛穿着T裇与长裙，小腹已微微隆起，看得出来是怀孕了呢。',
#   'user: 那我就只能祝福歌神啰'],
#  ['user: 嗨，现在几点啦',
#   'bot: 现在是晚上22点整。',
#   'user: 好的，谢谢。',
#   'bot: 不客气哦，提醒你今天多云,无持续风向,最高气温:22℃,最低气温:12℃哦。',
#   'user: 真贴心。',
#   'bot: 我永远都是你最贴心的小可爱。',
#   'user: 爱你呦。'],
#  ['bot: 嗨，晚上好啊',
#   'user: 晚上好啊！',
#   'bot: 最近工作怎么样啊',
#   'user: 最近发奖金了，开心。',
#   'bot: 那不错啊，恭喜了，应该庆祝一下！冒昧的问一下你叫什么呢？',
#   'user: 我叫吴海宇',
#   'bot: 听名字感觉你是个男生啊，对不对？',
#   'user: 对的，我是男士。',
#   'bot: 那你今年多大啊',
#   'user: 我已经40了',
#   'bot: 好的，那您有啥爱好呢',
#   'user: 我的爱好就是追星和听音乐，打发我的空余时间',
#   'bot: 喜欢听歌，不错哦。',
#   'user: 嗯那，我喜欢听唯一',
#   'bot: 哇，很好听的一首歌呢。',
#   'user: 是呀，我还有点事，先不说咯'],
#  ['user: 今天天气还好么？',
#   'bot: 今天天气小雨转阴,无持续风向,最高气温:22℃,最低气温:18℃。',
#   'user: 速度挺快啊。',
#   'bot: 谢谢。现在到饭点了，还有点雨，吃点热的暖暖身子吧。',
#   'user: 是啊，这天真适合吃个热菜哦',
#   'bot: 小炒肉就很不错哦，',
#   'user: 听上去还不错呢。'],
#  ['user: 今天天气如何',
#   'bot: 今天阴转多云,西北风,最高气温:4℃,最低气温:-3℃。',
#   'user: 天冷了呀',
#   'bot: 今天这样的天气很适合吃口水鸡呢。',
#   'user: 这倒是不错的建议',
#   'bot: 是啊，关键是这道凉菜很美味呢。',
#   'user: 说的我好想吃啊'],
#  ['user: 那种可以给我介绍一下周杰伦吗？',
#   'bot: 周杰伦是一位演戏天才;音乐天王;家喻户晓的明星;超级人气偶像;真正的歌者。',
#   'user: 嗯嗯，你介绍的好全面呦。',
#   'bot: 谢谢夸奖，他还是两届台湾金曲奖最佳国语男歌手。',
#   'user: 我可是超级喜欢他的呢。',
#   'bot: 他还是四届世界音乐大奖最畅销中华区艺人。',
#   'user: 他的歌确实挺好听的。',
#   'bot: 是的呢，那你现在要不要听听他的歌呢?',
#   'user: 那行吧。',
#   'bot: 推荐你听听《免费教学录像带》这首歌曲，杰伦一直在进步，一直在超前。',
#   'user: 听他的歌已经是习惯成自然的事情了。'],
#  ['bot: 中午好，最近还好吗？',
#   'user: 中午好啊，最近一般，退休了没事做，感觉寂寞。',
#   'bot: 找找生活中的乐趣就不会那么无聊了，相信你可以的',
#   'user: 好的，我会的。',
#   'bot: 还不知道你叫什么名字？',
#   'user: 我叫张凡振'],
#  ['user: 我想点一首『春雨里洗过的太阳』',
#   'bot: 正在放',
#   'user: 谢谢',
#   'bot: 这是我应该做的，我再推荐你一首『你不知道的事』你不妨听听看，这首歌特别好听，唯美而深情的旋律，简单的几句歌词，就让人深深掉入爱情的漩涡里呢。',
#   'user: 这首歌我听过，换一首',
#   'bot: 好吧，那『需要人陪』这首歌也很棒呢，感觉就像是在音乐餐厅听到一个歌手潺潺诉说都市之人的寂寞，值得一听哦。',
#   'user: 这首歌是谁唱的？',
#   'bot: 王力宏唱的哦',
#   'user: 那不错呀',
#   'bot: 需要给你放吗？',
#   'user: 好的呀，我听一下'],
#  ['bot: 晚上好，郝鑫明先生，最近过得怎么样？',
#   'user: 最近真开心呀，职位晋升啦',
#   'bot: 那真的祝贺您呢！',
#   'user: 谢谢你的祝贺',
#   'bot: 正好我们可以聊聊天，说起来，你最喜欢谁的新闻？',
#   'user: 我最喜欢刘德华的新闻。',
#   'bot: 我这里正好有一天跟刘德华有关的新闻，你有兴趣吗？',
#   'user: 我很感兴趣，是什么新闻呀？',
#   'bot: 那来听听刘德华的新闻，杨丽娟自16岁起疯狂迷恋刘德华，为了能去香港寻见刘德华，父母卖房甚至卖肾筹钱多次送女儿。2007年3月25日歌迷会后当晚，杨丽娟的父亲写下遗书后跳海身亡。11年后杨丽娟谈起刘德华时，对他只有祝福。',
#   'user: 你推荐的这篇新闻，我很喜欢，谢谢你。'],
#  ['bot: 牛鑫姗女士你好，最近的学习生涯怎么样？',
#   'user: 别提了，退步了都，免不了又是一顿骂',
#   'bot: 没关系哈，努力一点就好了。放轻松',
#   'user: 是了，我得想开点，不然生活怎么继续过',
#   'bot: 不要给自己压力太大，不如我们来聊聊电影吧，不知道你喜欢哪部电影呢？',
#   'user: 我最喜欢《纵横四海》这部电影呀',
#   'bot: 这的确是部经典片子，那这部片子里面里最喜欢谁呢？',
#   'user: 必然是哥哥张国荣',
#   'bot: 说起来张国荣，那可就厉害啦，他可是台湾电影金马奖最佳男主角哦。',
#   'user: 对啊，所以才能被叫做：才华横溢的艺术家啊！太吸引人的目光了',
#   'bot: 所以很多人都喜欢他，也是源于他自己的优秀呢',
#   'user: 哇，这样看来，我喜欢对人了呢',
#   'bot: 既然喜欢，那这部由他主演的《摄氏零度·春光再现》，都是回忆，你一定不能错过了。',
#   'user: 不想看这个，感觉就不喜欢',
#   'bot: 时代的颠沛流离和枉付深情非常的打动人，那这部《霸王别姬》推荐给你。',
#   'user: 那你知道这部片子是什么类型吗？',
#   'bot: 这是一部集爱情、音乐、剧情于一体的电影噗。',
#   'user: 我要沉醉了，以后一定来看看呢，谢谢你的推荐',
#   'bot: 嘿嘿，不要太感激我哦',
#   'user: 哈哈，臭屁嘞，我先不说了哈，还有事'],
#  ['bot: 柳芳洋，下午好哈',
#   'user: 你好啊',
#   'bot: 最近学习怎么样',
#   'user: 最近学习进步了呢，嘻嘻',
#   'bot: 那你心情应该很好呢，不如来听首歌吧，你平时最喜欢什么歌呢',
#   'user: 我喜欢听可不可以爱呢'],
#  ['user: 今天天气怎么样，小管家？',
#   'bot: 好的亲，今天南昌天气是中雨~小雨,东北风,最高气温:16℃,最低气温:14℃。',
#   'user: 怎么又下雨了。',
#   'bot: 这种天气适合吃爆炒花甲哦。',
#   'user: 我都好久没吃了，喜欢吃花甲，还有菜里的大葱也喜欢'],
#  ['user: 嗨，你知道今天的天气怎么样吗？',
#   'bot: 今天天气是晴天,北风,最高气温:26℃,最低气温:19℃',
#   'user: 你真聪明，谢谢你。'],
#  ['bot: 嗨，最近怎么样呢？',
#   'user: 哎，别提了，最近心情很差。',
#   'bot: 这是怎么了呢？',
#   'user: 这不前段时间考试来着，考试成绩下来了，我考的很不好。',
#   'bot: 好了好了，别难过啦，我陪你聊会天吧。',
#   'user: 嗯呢，谢谢你啊。',
#   'bot: 没事啦，你叫什么名字呢？',
#   'user: 我啊，我叫任晓倩，是初晓的晓，可不是大小的小，别弄错哦。',
#   'bot: 很好听的名字哦，看名字就知道你是个美女呢。',
#   'user: 嘿嘿，你很聪明啊，我确实是个妹子呢。',
#   'bot: 那姑娘芳龄几何呀？',
#   'user: 也是大人了呢，刚过了19岁的生日呢。',
#   'bot: 是的呢，那你平时有什么兴趣爱好吗？',
#   'user: 哈哈，年轻人嘛，当然是喜欢听听音乐啦。'],
#  ['user: 亲爱的，你知道《思念的距离》的主唱是谁吗',
#   'bot: 是何炅哦',
#   'user: 原来是何炅啊，你好厉害啊',
#   'bot: 嘻嘻，他是第三届中国影视网络影响力颁布盛最具网络影响力的十大电视主持人呢',
#   'user: 嗯嗯，他还获得过2016年第6届豆瓣电影鑫像奖豆渣单元最渣导演(华语)(提名)',
#   'bot: 而且还是中国儿童慈善之星，很有爱心呢',
#   'user: 是的，我果然没有喜欢错人啊',
#   'bot: 那要听听『行了』嘛？副歌很奶，有点可爱哈哈哈',
#   'user: 很受欢迎吗'],
#  ['bot: 中午好', 'user: 中午好啊', 'bot: 最近怎么样啊？', 'user: 那是相当不错了，生活很开心'],
#  ['bot: 中午好，钱枫江同志。',
#   'user: 中午好啊。',
#   'bot: 在干嘛呢？',
#   'user: 在公司忙着干活了，哎任务繁重啊。',
#   'bot: 那也要注意身体呀，有时间就看看电影放松放松下，不知道你最喜欢哪部电影呢？',
#   'user: 老电影《霸王别姬》。',
#   'bot: 哪位演员你最喜欢啊？',
#   'user: 不用问，肯定是张国荣。',
#   'bot: 哈哈，张国荣确实是一位不错的艺人，很多人喜欢他呢。',
#   'user: 是呀，我就是因为他的才华才喜欢他的呢',
#   'bot: 他在音乐方面确实很有建树，还是华语唱片在韩国销量纪录保持者的。',
#   'user: 对啊，他是我心中永远的偶像！',
#   'bot: 你的偶像可不只是唱歌厉害，演技也是一流的。他主演的这部『摄氏零度·春光再现』就很好看。始于春光，终于春光，推荐给你。',
#   'user: 看过很多次了，不想看这个。',
#   'bot: 那另一部『烟飞烟灭』也很赞的，是哥哥给我们大家的一份礼物哦，推荐给你。',
#   'user: 这部电影是谁导的啊？'],
#  ['user: 今天是几号了？',
#   'bot: 现在是2018年5月6号哦',
#   'user: 你真厉害，知道的真多',
#   'bot: 你知道吗？今天正好是谢娜的生日呢！',
#   'user: 我特别喜欢她呢，她可是一向低调的明星',
#   'bot: 哈哈，说起来，谢娜不仅是中国电视金鹰奖优秀主持人，她电影演的也不错呢！',
#   'user: 我看过她的电影呢，特别不错',
#   'bot: 我这里正好有一篇她主演的电影，你有兴趣吗？',
#   'user: 是什么电影呀？'],
#  ['user: 『你好吗』音乐主唱是谁啊?',
#   'bot: 是周杰伦哦',
#   'user: 好的，谢谢',
#   'bot: 周杰伦连续7年获得IFPI香港唱片销量大奖十大销量国语唱片呢',
#   'user: 是你的，人气非常的旺，大家非常喜欢他',
#   'bot: 他是一代人的歌神，贯穿整个青春少年时期',
#   'user: 我一直都特别喜欢他'],
#  ['bot: 嗨，胡静姗',
#   'user: 嗯，你好啊',
#   'bot: 最近怎么样？',
#   'user: 不太好，生活太无聊了',
#   'bot: 我来和你聊聊天吧，你平时最喜欢哪部电影啊？',
#   'user: 我最喜欢《桃姐》了',
#   'bot: 那你欣赏里面的哪个演员呢？',
#   'user: 当然是刘德华啦',
#   'bot: 刘德华可是一个完美男艺人呢',
#   'user: 是啊，所以才喜欢他啊，中国版得尼古拉斯凯奇~',
#   'bot: 而且也是一个天生的明星，演戏太棒了',
#   'user: 那是，他可是三届香港电影金像奖最佳男主角呢',
#   'bot: 对了，他主演的《无间道》华语影坛神作，不是一部简单的靠明星堆积的影片，它的成功更在于与以往的香港警匪片相比有了很大突破。',
#   'user: 这个啊，早就看过了呢',
#   'bot: 那这个呢《奇异旅程之真心爱生命》赵良骏的诚意之作！故事有趣又有heart',
#   'user: 什么类型的电影呢？',
#   'bot: 是剧情犯罪电影哦',
#   'user: 那应该会很棒的，有空去看一下。'],
#  ['bot: 刘萍露小姐姐，你好啊。',
#   'user: 你好。',
#   'bot: 最近在忙什么呢？',
#   'user: 忙职位晋升的事呢。',
#   'bot: 那肯定忙到没空看新闻了，我可以给你讲讲呢，不知道小姐姐平时最喜欢谁的新闻？',
#   'user: 当然是刘德华的新闻啦。',
#   'bot: 那就给你说说刘德华的新闻，杨丽娟自16岁起疯狂迷恋刘德华，父母卖房甚至卖肾凑钱多次送女儿去香港寻见刘德华。2007年3月25日歌迷会后当晚，杨丽娟的父亲写下遗书后跳海身亡，11年后杨丽娟再谈刘德华，她却说祝福吧。',
#   'user: 粉丝太疯狂啦，追星要适度。',
#   'bot: 是啊，最好在自己的承受范围内追星，不要盲目追星。',
#   'user: 很同意你的观点，可以把偶像当做你的榜样，但他们毕竟不是你的一切，还是要回归现实。',
#   'bot: 是的呢，不要忽略你身边最亲近的人，',
#   'user: 我到家啦，回聊。'],
#  ['bot: 晚上好，司轩振',
#   'user: 晚上好',
#   'bot: 最近工作怎么样？',
#   'user: 挺好的，刚发了工资',
#   'bot: 那可以和朋友出去玩玩放松放松，唱K就很不错，你最喜欢哪首歌啊？',
#   'user: 我最喜欢那首《风再起时》了',
#   'bot: 我猜你一定也很喜欢张国荣那位著名的歌星吧',
#   'user: 对啊，我特别喜欢他呢，一尘不染如初见的明星',
#   'bot: 他获得过马来西亚金曲荣誉大奖呢，真厉害',
#   'user: 走出国门呢，真是替他感到骄傲',
#   'bot: 那推荐你一首他的《想你》，张国荣的歌唱部份炮制得相当出色，令其散发着浓厚的巨星魅力，颇堪一赞。',
#   'user: 这首听过了呢'],
#  ['user: 今天的天气怎么样呢？',
#   'bot: 今天小雨,东北风,最高气温27℃,最低气温19℃。',
#   'user: 今天天气还不错啊，心情也挺好的，你反应可真机灵。'],
#  ['user: 你知道张国荣的星座吗？',
#   'bot: 当然知道了，张国荣是处女座的。',
#   'user: 你知道的真清楚啊',
#   'bot: 我还知道张国荣获得过，第三十届金马奖最佳电影歌曲，他还是中国电影百年百位优秀演员之一。',
#   'user: 是啊，他可是一位完美的艺术家，堪称全民偶像啊'],
#  ['user: 你知道『叶问2：宗师传奇』这部电影的主演是谁吗?',
#   'bot: 这部电影的主演是黄晓明.',
#   'user: 你真聪明啊，什么都知道。',
#   'bot: 谢谢你的夸奖，对了，黄晓明可是第17届北京大学生电影节最受欢迎男演员呢，你喜欢他吗？',
#   'user: 黄晓明可是我的偶像',
#   'bot: 你那么喜欢他，那你喜欢看他主演的电影吗？他演技非常好，还获得过中国电影金鸡奖最佳男配角呢，他有很多经典之作，',
#   'user: 我特别喜欢看他的电影。',
#   'bot: 那可以看看他主演的『中国合伙人』，这部电影表达了70，80后的美国梦。',
#   'user: 你知道这部电影是什么类型的吗？',
#   'bot: 这部电影是剧情类型的。',
#   'user: 那我现在就去看看啦。'],
#  ['user: 你知道舒淇的生日是什么时候么？',
#   'bot: 她的生日是1976年4月16日的。',
#   'user: 这都知道，厉害诶。',
#   'bot: 一点点啦，说起来舒淇还被称为谜一样的女人。',
#   'user: 哈哈，等于说还挺神秘。那你知道她获得过的奖项吗？',
#   'bot: 知道一些，她获得过中国电影华表奖优秀女演员，香港电影金紫荆奖最佳女配角。她还是戛纳国际电影节评委会成员。',
#   'user: 成就很高啊。'],
#  ['user: 你知道何炅的星座吗？',
#   'bot: 知道啊，何炅是金牛座的。',
#   'user: 嚯，你知道的真详细',
#   'bot: 不光是这，我还知道何炅还曾获得过湖南卫视最佳主持人奖，《新周刊》2013中国电视榜15周年荣誉大奖等。',
#   'user: 他可是湖南卫视的“镇台之宝”呢',
#   'bot: 是啊，他是中国儿童慈善之星，娱乐圈的明星老师，演技也很棒。',
#   'user: 不仅演技很好，唱歌也很好听呢',
#   'bot: 那你听过他的这首《另一个自己》吗？41岁的何炅，把挑战“另一个自己”、完成导演梦的心声融进歌里，传递出“一切都来得及”的青春态度。',
#   'user: 这我倒是没听过呢',
#   'bot: 何老师唱歌真的很温暖很好听有种很神奇的抚慰人心的力量。',
#   'user: 是啊，何老师可是一位大暖男啊，有时间我一定得听一听了'],
#  ['user: 嗨，你知道王力宏的星座吗？', 'bot: 王力宏的星座啊，他可是金牛座呢。', 'user: 好的，你真是个百事通，啥也难不住你。'],
#  ['user: 能为我放『至少还有你』这首歌吗？',
#   'bot: 正在为你播放。',
#   'user: 嗯，这首歌真好听啊！',
#   'bot: 其实张国荣还有很多好听的歌，比如『有心人』这首歌。这也是张国荣最具闺阁芬芳的一首作品，你可以听听看',
#   'user: 这首歌我已经听过了，还有没有别的歌可以听啊？',
#   'bot: 『奔向未来日子』也超好听的，还是电影《英雄本色2》的主题曲呢',
#   'user: 听名字感觉挺正能量的呢',
#   'bot: 是的，非常积极向上的一首歌呢',
#   'user: 那必须要需要听听啊。'],
#  ['user: 今天是什么日子了？', 'bot: 今天是11月14日哦', 'user: 有你真好哟~总能告诉我想知道的'],
#  ['user: 你知道张柏芝的生日是什么时候吗？', 'bot: 张柏芝的生日是5月24日。', 'user: 好的知道了，谢谢。'],
#  ['user: 今天是几号啊',
#   'bot: 2018年12月21号。',
#   'user: 过得真快啊，又快月底了',
#   'bot: 是啊，提醒你今天天气阴~小雨,西北风,最高气温:12℃,最低气温:7℃注意保暖哦。',
#   'user: 谢谢提醒呢，你真贴心',
#   'bot: 不客气哦。',
#   'user: 我到学校了，拜拜啊'],
#  ['user: 『爱你等于爱自己』这首歌的主唱是谁啊？',
#   'bot: 王力宏哦',
#   'user: 哦，谢谢啊，我知道了',
#   'bot: 你喜欢王力宏吗，他可是天王级歌星',
#   'user: 喜欢啊，我很喜欢王力宏的歌呢',
#   'bot: 他还是全球流行音乐金榜年度最佳男歌手呢，你眼光不错',
#   'user: 是啊，我的偶像就是厉害',
#   'bot: 他的《一首简单的歌(Live)》推荐你，这首歌写了力宏对生活的一种态度，这个世界很复杂，也许会让人无奈，但是还是要努力把握幸福，不需要太刻意地表现爱，只要用简单的方式表达。',
#   'user: 可以啊，我好久没听王力宏的歌了',
#   'bot: 一定不会让你失望的',
#   'user: 好啊，我要听听',
#   'bot: 那为你播放这首歌可以吗',
#   'user: 播放吧',
#   'bot: 好的，正在播放',
#   'user: 嗯，这首歌真好听啊'],
#  ['user: 电影《倾城》主演是谁?',
#   'bot: 是林心如',
#   'user: 我知道了，谢谢你哦',
#   'bot: 客气了，说起来林心如可是当红影星，而且还是史上亲民的明星。',
#   'user: 我就很喜欢她，她的笑容暖的很治愈呢',
#   'bot: 是啊娃娃脸，很可爱，不过她的演技也很不错哦，还获得过第50届台湾电视金钟奖最佳戏剧节目。',
#   'user: 是啊，这些年看着她越来越多的作品，也让我更喜欢她了。'],
#  ['user: 现在几点了。',
#   'bot: 现在是中午12:00。',
#   'user: 好的，谢谢你。',
#   'bot: 不客气哦，对了今天天气多云,西北风,最高气温:8℃,最低气温:-4℃。要多穿点衣服哦。',
#   'user: 你可真贴心呀。'],
#  ['user: 几号了？',
#   'bot: 嗯，今天是2018年11月13日。',
#   'user: 好的好的，你真棒呀。',
#   'bot: 多谢夸奖啦，话说今天可是“山东省十大杰出青年”黄晓明的生日呢。',
#   'user: 呀呀呀，我男神！我男神黄晓明生日，哎哟看我这个记性啊。',
#   'bot: 哈哈，看来你是他的忠实粉丝呢。他获得过第15届中国电影华表奖优秀男演员呢',
#   'user: 是的呀，超级铁杆！忠实粉丝哈哈哈哈。',
#   'bot: 作为粉丝你一定喜欢看他的电影吧？那这个『地球四季』你肯定不能错过的，影片中不光可以看到动物间人性化的舐犊之情，更可以看到无数意想不到的差异性奇观。',
#   'user: 我知道这个啦，但是我现在更喜欢杨幂的电影诶。',
#   'bot: 我正好想起来，她有个难得的好电影『消失的子弹』呢，故事、推理，情节都不错。你一定想看。',
#   'user: 也不知道类型够不够吸引我'],
#  ['bot: 早上好哦，王霄姗，最近怎么样？',
#   'user: 不怎么样',
#   'bot: 有什么不开心的事吗？',
#   'user: 学习退步太多了，烦',
#   'bot: 没关系啦，继续努力就好，要不听听歌放松一下，你最喜欢什么歌？',
#   'user: 《芳华绝代》还蛮喜欢的',
#   'bot: 这首歌我知道，是张国荣唱的吧，他是个很厉害的人哦，获得过香港乐坛最高荣誉金针奖。',
#   'user: 想不到你这么了解他啊，他还8次获得香港电影金像奖最佳男主角提名，真是让人望尘莫及',
#   'bot: 对啊我当然了解他，而且他也真的称得上是多才多艺的艺人了。',
#   'user: 还是个有魅力的人',
#   'bot: 那不如我来为你推荐一首同样也是张国荣的歌吧，《心跳呼吸正常》，很好听的一首歌哦。挺哥哥就要听这首歌！',
#   'user: 我不太喜欢这种类型的歌',
#   'bot: 那还有一首《你这样恨我》，这首你应该会喜欢了。哥哥唱的很温柔呢',
#   'user: 听名字还挺有感觉的哈哈',
#   'bot: 是啊，有人评论说这么好的哥哥，这么温柔的歌，大概也是很动人了。',
#   'user: 哇，那我必须听听看',
#   'bot: 那我现在为你播放这首《你这样恨我》怎么样？',
#   'user: 可以啊',
#   'bot: 为你播放《你这样恨我》。',
#   'user: 可以，是我喜欢的类型'],
#  ['user: 你知道张柏芝的血型嘛？',
#   'bot: 她是A型血',
#   'user: 哇，你真棒，这都知道',
#   'bot: 还好，她是娱乐圈中为混血儿的明星，当然我很关注了。',
#   'user: 嗯嗯，我也喜欢她呢',
#   'bot: 娱乐圈中为数不多的真性情女人，确实很有人气哈',
#   'user: 是呢，而且她的演技也很好的，每次演的角色都演到我心坎儿里去了，演技太赞了',
#   'bot: 是的，说到这里那你要看看她主演的《白兰》吗，柏芝在里面很清纯哦',
#   'user: 不好意思，我现在更喜欢谢霆锋的电影呢'],
#  ['user: 你知道电影『恋爱中的城市』的主演是谁吗？',
#   'bot: 这部电影的主演是杨幂。',
#   'user: 谢谢，我知道了。',
#   'bot: 杨幂可是休斯顿国际电影节最佳女主角呢，是个很厉害的演员呢',
#   'user: 对呀，她非常努力，所以演技特别好。'],
#  ['bot: 嗨，中午好啊。',
#   'user: 中午好。',
#   'bot: 最近怎么样呀？',
#   'user: 学习挺轻松的，还不错。',
#   'bot: 那就挺好的，我们来玩个一问一答的游戏吧，现在开始，你叫什么名字呢？',
#   'user: 我叫曾琪凤。',
#   'bot: 男生还是女生啊？',
#   'user: 女生。',
#   'bot: 今年多大了？',
#   'user: 18。',
#   'bot: 平时有什么爱好呢？',
#   'user: 看电影，看新闻。'],
#  ['user: 今天的天气怎么样?',
#   'bot: 最近的天气还不错，是晴天，最高气温:21℃,最低气温:10℃',
#   'user: 确实不错，谢谢你啦',
#   'bot: 不客气，话说这样的天气，应该弄点烧烤啊，『羊肉串』怎么样？',
#   'user: 不错欸，也确实好久没吃了'],
#  ['bot: 嗨，郭芳湘',
#   'user: 哈喽',
#   'bot: 最近学习怎么样啊？',
#   'user: 不太好咯，退步了',
#   'bot: 那你需要加油喽，给你推荐一首《谁谁谁》，每次一听到小何的声音，都会平静下来',
#   'user: 暂时不想听音乐',
#   'bot: 不想听音乐，那来聊明星吧，就何炅怎么样？那个调皮的主持人',
#   'user: 这个可以啊，我挺喜欢他的，中国的人气主持人呢',
#   'bot: 而且当初还是央视的呢',
#   'user: 也特别的有爱心，是“中国儿童慈善之星”'],
#  ['user: 你知道今天的天气怎么样吗？',
#   'bot: 东莞今天小雨,东北风,最高气温:15℃,最低气温:10℃，出门的时候不要忘记带雨伞哟！',
#   'user: 谢谢你的提醒。',
#   'bot: 不客气，今天这种天气很适合吃『剁椒鱼头』呢',
#   'user: 你怎么知道我喜欢吃这个呢？真厉害'],
#  ['user: 哈喽，你能为我放一首『伯牙绝弦』吗？',
#   'bot: 好的，现在为你放《伯牙绝弦》。',
#   'user: 听完了，真的是一直听一直听不够呢。'],
#  ['user: 告诉我一下《烟飞烟灭》的主演是谁',
#   'bot: 是张国荣啊',
#   'user: 好的谢谢你',
#   'bot: 不客气，那我们聊聊张国荣吧，我知道他还被称为天皇巨星呢',
#   'user: 那你给我说说他获得的奖吧'],
#  ['user: 你知道黄渤的生日吗？',
#   'bot: 他的生日是1974年8月26日',
#   'user: 你真聪明呢！什么都知道！',
#   'bot: 你喜欢黄渤吗，他是一个实力派演员呢',
#   'user: 我很喜欢他的，他是当之无愧的中国现今影坛一哥！'],
#  ['user: 你知道张柏芝的生日是几号吗？',
#   'bot: 张柏芝的生日在5月24日。',
#   'user: 我知道了，谢谢你。',
#   'bot: 说起来张柏芝天生就该在娱乐圈混呢，真是个大美女。你是喜欢她吧。',
#   'user: 我特别喜欢她，她为人很低调而且演技特别好。',
#   'bot: 她的演技当然好啦！她可是获得过香港电影金像奖最佳女主角呢，',
#   'user: 哇，她可真优秀啊',
#   'bot: 嘿嘿，话说泡妞有一万种方法.这部由张柏芝主演的『情迷大话王』要不要看一下？',
#   'user: 这部电影的导演是谁呀？'],
#  ['bot: 晚上好，刘萍露女士！',
#   'user: 你好，我的朋友！',
#   'bot: 现在在干嘛呢？',
#   'user: 没事干，一个人在家，孙子也不在了，不免有点寂寞。',
#   'bot: 寂寞可以找我聊天呀，你最近喜欢哪部电影呢？',
#   'user: 我最喜欢《娜娜的玫瑰战争》了。',
#   'bot: 那你最喜欢哪位主演呢？',
#   'user: 我最喜欢谢娜了！她是非常努力的人。',
#   'bot: 是的呢，她主持的节目每次都能给人带来快乐，还获得过“中国电视金鹰奖优秀主持人”奖呢！',
#   'user: 她好棒啊！听你这么说我更喜欢她了呢！',
#   'bot: 哈哈，优秀的人都会有很多人喜欢的，她现在更是一位贤妻良母。',
#   'user: 对啊，结婚了就转换角色了，相信她会做的很好的！',
#   'bot: 相信他会更好，她演过一部电影『娜娜的战争』，身为制片的谢娜是“肆无忌惮”，感情刻画细腻，片中不光充满了“娜式风范”，也让人看到了另一个为爱疯狂的谢娜。。',
#   'user: 这个我已经看过了。',
#   'bot: 那『当初应该爱你』这部电影呢，也挺不错的，口碑还可以。',
#   'user: 那它是什么类型的片子呢？'],
#  ['bot: 晚上好，周玉振，一天又过去了！', 'user: 是啊，你好啊', 'bot: 近来如何啊？', 'user: 挺好的，还发了奖金'],
#  ['user: 说说张学友的新闻',
#   'bot: 那就说一个最近的新闻吧。最近在广东江门市体育中心张学友演唱会上，民警通过安检人像识别系统成功识别出一名在逃人员范某并抓获。自今年4月第一起，警方已在张学友演唱会上陆续抓捕了约60名犯罪嫌疑人或在逃人员。',
#   'user: 你好棒，啥都知道'],
#  ['bot: 晚上好，最近怎么样呢？',
#   'user: 学习是好的很呐，考试考得也很好，高兴地不得了。',
#   'bot: 那恭喜你呀，一看上课就好好听讲了，但是不能骄傲哦。',
#   'user: 放心吧，我会继续努力的！',
#   'bot: 对了，还不知道你叫什么名字？',
#   'user: 我的名字是胡霄倩。',
#   'bot: 名字很好听，是个小男孩还是小女孩呢？',
#   'user: 是个小女孩哦。',
#   'bot: 那你多大了呢？',
#   'user: 今年6岁了。',
#   'bot: 哈哈，平时喜欢干什么呢？',
#   'user: 平时喜欢和小动物们玩耍，还有看看动漫什么的。'],
#  ['user: 在呢，今天天气怎么样呢？',
#   'bot: 在的呀，今天邢台多云~晴,北风,最高气温:14℃,最低气温:2℃，注意保暖哦。',
#   'user: 哇，你好棒啊，啥都知道呢！',
#   'bot: 哈哈，我还知道这天气适合吃麻辣小龙虾呢。',
#   'user: 可以的啊，我正好没想好吃什么呢，'],
#  ['bot: 上午好，亲爱的莫超奇同学！近来如何？',
#   'user: 上午好啊，最近不咋样，考试没考好。',
#   'bot: 这次没考好没关系，好好努力，一定会取得好成绩的。',
#   'user: 谢谢你的鼓励，我会努力的。'],
#  ['user: 嗨，告诉我一下今日天气情况',
#   'bot: 好的，今日福州小雨,东北风,最高气温:21℃,最低气温:19℃',
#   'user: 谢啦，你可真棒！',
#   'bot: 不客气，这种天气适合听王力宏的『你不在(Live)』哦！这首歌曲诠释了男女之间对于爱情孤独无力的感觉，具有强有力的穿透力。超级好听的',
#   'user: 王力宏的歌曲啊，我最喜欢了！',
#   'bot: 是嘛！这首歌曲很棒哦，一定不能错过',
#   'user: 听你这么说我都心动啦！'],
#  ['user: 我想听《夕阳醉了》',
#   'bot: 为你放『夕阳醉了』',
#   'user: 好的，谢谢。',
#   'bot: 不客气呢，要不要再听一首呢？『饿狼传说』很不错哦，很多人去KTV必须要点的歌呢',
#   'user: 我已经听过了。',
#   'bot: 那『忘记你我做不到』呢？也很不错哟。是张学友于1996年推出音乐专辑《忘记你我做不到》，其中的一首歌曲。',
#   'user: 听歌名还蛮悲伤的，好听吗。',
#   'bot: 很好听呢，你应该会喜欢的',
#   'user: 听上去很赞哦。'],
#  ['user: 在吗，今天几号了？', 'bot: 好的亲，今天是2018年5月24了，月底啦，', 'user: 好的，时间过得好快啊'],
#  ['user: 能给我播放一篇关于周迅的新闻么？',
#   'bot: 马上就来。最近有媒体报道，继《如果爱》之后，每隔一段时间周迅都会“消失”一下，最近几年她似乎愈发“离群”。周迅说，在不拍戏也没通告的日子，除了发呆似乎就不知道该做些什么了，甚至连兴趣爱好都要开始寻找。这样的日子虽然并非时时快乐，但她更享受随心所欲的心境。',
#   'user: 周迅真的是很有性格的演员。我太喜欢她了。'],
#  ['user: 『公转自转』这首歌是谁演唱的？',
#   'bot: 这首歌的主唱是王力宏',
#   'user: 哦，我知道了，谢谢你啊！',
#   'bot: 他还是加拿大全国推崇男歌手呢。',
#   'user: 是啊，王力宏真的很优秀啊！超级喜欢他。',
#   'bot: 那你很有眼光啊，他还获得过全球流行音乐金榜年度最佳男歌手哦。',
#   'user: 对啊，他唱歌真的好听。',
#   'bot: 要不要来欣赏一下他的『美』这首歌，这首歌原本是电影里的轻快俏皮的配乐，在王力宏的重新编配下，变成了这样一首国际化辨识度高的作品。',
#   'user: 诶，这首好像很多人喜欢的样子我记得。',
#   'bot: 就更应该听一下啦，很好听的',
#   'user: 的确是，我还真想听听看了。',
#   'bot: 需要现在为您播放吗？',
#   'user: 播放吧。',
#   'bot: 正在为您播放',
#   'user: 真不愧是偶像的歌，真好听啊！',
#   'bot: 你喜欢就好哦。',
#   'user: 有人去喊我吃午饭了，先再见吧。'],
#  ['user: 请为我放一首《飘向北方》。',
#   'bot: 正在为你播放歌曲《飘向北方》。',
#   'user: 还是那么好听啊。',
#   'bot: 对的，那我再给你安利另一首王力宏的《你不知道的事》吧，这首歌充满浓浓的古典味儿，词曲深刻真挚，每颗音符都重击内心，没听过的话可以听听看',
#   'user: 这名字听起来就不好听，不是很感兴趣啊，算了吧。',
#   'bot: 好吧，再给你推荐一首好听的歌曲《需要人陪》。这是一首偏重内心的歌曲，王力宏写出了都市人内心孤寂的心声',
#   'user: 这个名字听起来好暖和啊。'],
#  ['bot: 你好，杨琪娜。',
#   'user: 不好，最近带孙子太累了。',
#   'bot: 那您可以适当放松心情了呢，我和你聊聊吧？',
#   'user: 好的。',
#   'bot: 你平时看电影嘛？有没有喜欢的电影呀？',
#   'user: 我最喜欢《逆战》这个片子。',
#   'bot: 那你欣赏里面的哪个演员呢？',
#   'user: 我最喜欢谢霆锋了。',
#   'bot: 谢霆锋很优秀啊，49届金马奖最佳男主角。',
#   'user: 这我还不知道呢，小伙子蛮厉害的。',
#   'bot: 是啊，而且还是好男人~好演员~好老公。',
#   'user: 哈哈对，听说还是个大孝子，家庭事业两不误啊。',
#   'bot: 既然你这么喜欢他，给你推荐一个他的电影哦，《十月围城》，难得好片，看时很震惊。',
#   'user: 这个我看过了，确实不错。',
#   'bot: 他的《线人》这个也还可以哦，相当不错的港片了。',
#   'user: 它的主演有谁呢？',
#   'bot: 主演是谢霆锋、张家辉、桂纶镁。',
#   'user: 听起来不错。'],
#  ['user: 『无限复活』主演是谁你知道么？',
#   'bot: 『无限复活』的主演是张柏芝。',
#   'user: 知道的不少啊。',
#   'bot: 谢谢夸奖，说起来张柏芝还挺励志的，是白手起家的贫民明星哦',
#   'user: 对，她一直很努力。',
#   'bot: 所以才有了现在的成就啊，她获得过第23届香港电影金像奖最佳女主角，第19届香港电影金像奖最佳新演员，香港电影评论学会最佳女演员奖。',
#   'user: 看来她的演技很强啊。',
#   'bot: 是呢，要不然不会获得这么多的成就，给您推荐个她的电影，『星愿』，这部电影也可以说是1999年前后的爱情片回潮中最好的影片',
#   'user: 那这是一部什么类型的电影啊？'],
#  ['user: 今天天气如何？',
#   'bot: 长沙今日小雨,北风,最高气温14度，最低气温9度。',
#   'user: 你知道的真多呢',
#   'bot: 这样的天气来上一份水煮鱼，岂不美哉。',
#   'user: 水煮鱼我很喜欢吃呢，里头的青菜我也爱吃，',
#   'bot: 这道菜再来一碗香喷喷的米饭，太好了',
#   'user: 这你都知道，真厉害，我好想吃啊',
#   'bot: 如果你吃水煮鱼的话，推荐你去尚煨精品湘菜，这家店做的不错，还可以预定哦。',
#   'user: 这家店的消费如何？',
#   'bot: 人均消费在40左右。',
#   'user: 评分多少呢？',
#   'bot: 评分有4.1',
#   'user: 这家店在哪呢？',
#   'bot: 地址在天心区赤岭路28号（近长沙理工大学）中国移动大厦对面',
#   'user: 那你帮我定一个今晚8点的位置吧，我们3个人',
#   'bot: 以为您预定成功。',
#   'user: 我还有事，下次再聊吧'],
#  ['bot: 你好啊，最近过得怎么样？',
#   'user: 你好，最近刚刚发了奖金很开心呐。',
#   'bot: 那不错哟，恭喜了！',
#   'user: 哈哈，谢谢你！',
#   'bot: 认识那么久了，还不知道你叫什么名字呢，你能告诉我吗？',
#   'user: 我叫胡鑫佳',
#   'bot: 那你是个男生还是女生呀？',
#   'user: 我可是个可爱的小女生哦！',
#   'bot: 那你今年多大了呀？',
#   'user: 18岁呢。'],
#  ['bot: 你好啊，姬凡林。',
#   'user: 很不好，最近学习退步了。',
#   'bot: 没关系，慢慢来会好的，现在为了舒缓你的学习压力和你聊一聊哦。',
#   'user: 好的，谢谢你。',
#   'bot: 那不知道你最喜欢谁的新闻呢？',
#   'user: 最喜欢范冰冰。',
#   'bot: 那我给你讲一个关于范冰冰的新闻，最近在华中师范大学为冯小刚导的电影《我不是潘金莲》举办宣传活动的时候，范冰冰先是被堵在学校门口一个小时，进场10分钟后又让她马上离场否则就断电，冯小刚当时就很不高兴。一起参加活动的武汉籍作家方方还说，“不敢相信这样的事发生在我所喜欢的华中师范大学”。之后武汉市公安局官方微博回应说他们“不背锅”，因为这次的活动本来也不需要公安机关审批，公安机关也不会参与安保。有人说是因为，现场的状况让安保的压力很大，校方怕范冰冰的人气高，在学校里面引发踩踏，所以才要提前结束活动』。',
#   'user: 一方面学校为学生考虑是很好的，但是没有想到冰冰的感受。'],
#  ['user: 帮我点一首《想你》吧',
#   'bot: 好的，正在为你播放呢。',
#   'user: 真好听，谢谢你呢',
#   'bot: 这是我应该做的，我再为你推荐首吴亦凡的其他歌曲吧『天地』，曲风大气、苍茫，隐隐然是承载洋洋中华长史的大河发出的千年喟叹。',
#   'user: 这首歌听过了，换一首吧',
#   'bot: 可以，那这首歌你试试听一下这首『刀剑如梦』，是《剑侠世界》手游的主题曲呢',
#   'user: 感觉很好听呢'],
#  ['bot: 嗨，在干什么呢？',
#   'user: 嗯呢，正在为考试考好了开心不已，哈哈哈。',
#   'bot: 这么厉害啊，我们交个朋友吧。',
#   'user: 好呀好呀。',
#   'bot: 首先我想知道你叫什么呢？',
#   'user: 人家叫刘萍露呢',
#   'bot: 应该是个可爱的小姐姐吧？',
#   'user: 是个小妹妹哦。',
#   'bot: 哇，那方便透露年龄吗？',
#   'user: 还不到十八呢。',
#   'bot: 你好你好，不知道这么可爱的你平时喜欢干什么？',
#   'user: 喜欢明星、电影和音乐啦。',
#   'bot: 哈哈，年轻人都比较喜欢这些。',
#   'user: 哈哈，先不说了，去洗漱啦。'],
#  ['bot: 嗨，上午怎么样呢？',
#   'user: 哎，考试没考好呢。',
#   'bot: 是不是上课不用心呢？',
#   'user: 最近没有很努力复习，所以没考好。',
#   'bot: 那接下来要努力呢，对了你叫啥啊？',
#   'user: 嗯呢，我叫金立国。'],
#  ['user: 你好，现在几点了',
#   'bot: 你好，现在是下午18点整。',
#   'user: 好的，真棒',
#   'bot: 嘿嘿，提醒你今天阴天多云,南风,最高气温20℃,最低气温11℃。',
#   'user: 还挺贴心的呀',
#   'bot: 嘿嘿，谢谢夸奖。',
#   'user: 给你好评了哦，我到家了，不说了。'],
#  ['user: 几点了?',
#   'bot: 现在是晚上八点了',
#   'user: 好的。',
#   'bot: 嘿嘿，对了上海今天多云,北风,最高气温:21℃,最低气温:14℃',
#   'user: 天气也很不错呢。',
#   'bot: 是呢，要记得多喝水哦',
#   'user: 下次聊，拜拜！'],
#  ['user: 晚上好，现在什么时间呢？',
#   'bot: 现在时间是2018年10月5日。星期五，晚上22:00整。',
#   'user: 好的呢，谢谢你了。',
#   'bot: 咱俩这关系还客气啥，对了鞍山今天晴转多云,南风,最高气温:24℃,最低气温:11℃。温差较大，小心感冒啊。',
#   'user: 好的呢，真体贴呀。',
#   'bot: 这是我的职责所在。',
#   'user: 我要忙别的事了，先不聊了。'],
#  ['bot: 你好呀，郭超航小哥哥',
#   'user: 不怎么好',
#   'bot: 怎么啦，讲讲吧',
#   'user: 最近考试没有考好',
#   'bot: 别不开心啦，慢慢会好的！咱们聊聊你喜欢的电影吧，叫什么名字啊！',
#   'user: 我最爱看『小亲亲』了呢',
#   'bot: 不错哦，那里边的哪个演员你喜欢啊？',
#   'user: 当然是郭富城啦',
#   'bot: 那你眼光好好啊！他可是被称为亚洲影帝呢！',
#   'user: 是啊，一个实力派的演员',
#   'bot: 怪不得你喜欢他呢！他还是香港十大杰出青年，很有魅力哦',
#   'user: 应该大多数人都喜欢吧哈哈'],
#  ['user: 能给我点一首，《秋意浓》么？',
#   'bot: 好的，这就为你放。',
#   'user: 好的谢谢。',
#   'bot: 这是我应该做的，同样是张学友演唱的《心如刀割》也是很好听的哦，好歌词，好曲调，极具感染力。你可以听一听。',
#   'user: 这首歌听过了。'],
#  ['bot: 下午好，最近过得怎么样？',
#   'user: 你好，最近心情不错，刚发了工资。',
#   'bot: 那真是恭喜你了。',
#   'user: 谢谢你的祝贺。',
#   'bot: 不客气，对了，可以告诉我你叫什么名字吗？',
#   'user: 我的名字叫做王芳洋',
#   'bot: 你是男士还是女士呢？',
#   'user: 我是女士',
#   'bot: 可以冒昧的问一下你今年多大了吗？',
#   'user: 我今年36岁。'],
#  ['user: 我想问问最近有周迅的新电影么。',
#   'bot: 有啊，最近出了好多，例如《李米的猜想》，都不错呢',
#   'user: 好的，谢谢。',
#   'bot: 说到周迅，她可是中国电视金鹰奖最受欢迎女演员呢，还是中国电影导演协会的最佳女演员呢',
#   'user: 哇，你不说我都不知道呀，我的女神这么厉害呀。'],
#  ['user: 在呢，给我放一下《侯斯顿之恋》吧。',
#   'bot: 好的，正在为你播放，请欣赏',
#   'user: 好的，谢谢你了。',
#   'bot: 不客气，歌曲已经放完毕了，他的《有心人》你要听一下吗，这也是张国荣最具闺阁芬芳的一首作品',
#   'user: 这首歌听过了，暂时不想听。',
#   'bot: 好的，还有《奔向未来日子》也很不错哦，是电影《英雄本色2》的主题曲',
#   'user: 嗯，好听吗？',
#   'bot: 太受欢迎了',
#   'user: 好的呢，那我得好好听了。',
#   'bot: 好的，现在要放吗',
#   'user: 嗯嗯',
#   'bot: 好的，正在放',
#   'user: 好的，我要准备睡了，拜拜。'],
#  ['user: 『爱你等于爱自己』音乐的主唱是谁呀?',
#   'bot: 这首歌的主唱是王力宏呢！',
#   'user: 谢谢你，我知道啦。你真棒呀',
#   'bot: 王力宏是1976年5月17号出生的金牛座哦！',
#   'user: 王力宏是我的偶像呢，他可是优质人气偶像',
#   'bot: 他的歌曲很棒的哦！他可是第15届全球华语榜最佳港台男歌手呢！你喜欢他的音乐吗？',
#   'user: 我特别喜欢他的音乐呢，而且他还是全球流行音乐金榜年度最佳男歌手呢',
#   'bot: 那给你推荐实力华语来说数一数二的王力宏的一首歌『心中的日月(Live)』，曲中流畅优美的曲风仿佛带听众飞越人间仙境，笛子、六弦琴、扬琴、鼓及金发等中乐，运用中国五音阶的创作方式谱出西洋音乐的旋律，这首歌非常好听！',
#   'user: 这可是我最爱的力宏的歌呢'],
#  ['user: 张国荣是什么星座的？',
#   'bot: 是处女座哦',
#   'user: 好的，谢谢',
#   'bot: 张国荣可是被称为亚洲天王的存在，获得过香港电影金像奖最佳男主角，也是华语唱片在韩国销量纪录保持者。',
#   'user: 他值得！他的努力和天赋决定了他的优秀。',
#   'bot: 而且他主演的电影《霸王别姬》荣获金棕榈大奖，这个就真的是非常厉害了。',
#   'user: 是呀，不愧是我的偶像。',
#   'bot: 正好，这部关于他的电影《记得……香蕉成熟时II：初恋情人》推荐给你，故事讲的很不错，但是节奏有些慢，倒像是艺术片的表现形式。',
#   'user: 这是个什么类型的片子呀？',
#   'bot: 这是个喜剧片哦。',
#   'user: 口碑怎么样？',
#   'bot: 口碑还好',
#   'user: 那我放学看看'],
#  ['bot: 柳晓琴女士，中午好啊！',
#   'user: 哈哈，你也好啊！',
#   'bot: 最近工作怎么样？',
#   'user: 还好吧，就是工作压力有点大。',
#   'bot: 压力大的时候你可以去听听歌啊。这首『脚踏车』是一首很好的歌呢',
#   'user: 我暂时不想听歌。',
#   'bot: 这首歌的主唱可是周杰伦呢，他可是连续7年获得IFPI香港唱片销量大奖十大销量国语唱片呢',
#   'user: 那你可真聪明啊，这都知道',
#   'bot: 我还在知道他获得过华语电影传媒大奖的最佳新演员呢',
#   'user: 没想到我偶像这么厉害啊！',
#   'bot: 那你要不要看一下他主演的『功夫熊猫3』呢',
#   'user: 这部电影我已经看过了，换一部吧。',
#   'bot: 那这部『自行我路』也很不错的，你要不要看一下？',
#   'user: 这部电影的导演是谁呀？',
#   'bot: 是杜琪峯',
#   'user: 不错哟，我有时间会去看看的。'],
#  ['user: 在吗小管家，现在几点了',
#   'bot: 嗯，我的主人，现在是中午12:00啦。',
#   'user: 嗯嗯，我知道了，你好聪明啊',
#   'bot: 不客气呢，提醒你今天天气还是多云~阴,东北风,最高气温:6℃,最低气温:0℃，注意保暖呢！',
#   'user: 好的，你好贴心哦'],
#  ['user: 晚上好，今天天气怎么样？',
#   'bot: 你好，石家庄晴,西北风,最高气温:2℃,最低气温:-6℃，气温偏低，出门注意御寒啊。',
#   'user: 谢谢，你真的好体贴呀！',
#   'bot: 不用谢，今天这个天气适合吃水煮鱼呢。',
#   'user: 你咋知道我喜欢吃水煮鱼呢',
#   'bot: 当然知道了呀，嘿嘿这道热菜确实很美味。',
#   'user: 说的我的口水都流出来了呢，明天一定要去吃去。'],
#  ['bot: 莫娇露，你好啊，在干啥呢。',
#   'user: 在公司呢，啥也没干，闲的呢。',
#   'bot: 看来不是很忙。',
#   'user: 嗯，我的工作比较轻松。',
#   'bot: 那正好我们来聊聊天吧，不知道你喜欢哪部电影呀？',
#   'user: 《大块头有大智慧》这部电影吧',
#   'bot: 这是部好片子，那你喜欢里面的哪位演员呢？',
#   'user: 最喜欢里面的张柏芝啦，演技非常的棒。',
#   'bot: 对呀，他的演技确实非常的出色，还获得过香港电影金像奖的最佳女主角哦',
#   'user: 嗯，她的演技是获得了肯定的。',
#   'bot: 此外她还获得了纽约中国电影节亚洲杰出艺人。',
#   'user: 看来我的偶像真的厉害。',
#   'bot: 是啊，对了，你有看过张柏芝演的《旺角黑夜》吗？在题材上非常新颖，在叙事上也相当流畅，不错的一部电影。',
#   'user: 看过了哦，不想看了。',
#   'bot: 那这部电影你一定会喜欢的，《左右情缘》很法式的一部短片，很优雅的哥哥',
#   'user: 主演有谁呀。',
#   'bot: 主演有邱淑贞，张国荣，张柏芝，都是很不出色的演员哦。',
#   'user: 嗯，不错哦。',
#   'bot: 相信我一定不会失望的。',
#   'user: 那可以看看哟。'],
#  ['bot: 晚上好呀，最近怎么样呢？',
#   'user: 你好啊，最近学的知识有点难啊，都有点听不懂了。',
#   'bot: 哈哈，听不懂的要问同学或老师，可不能不懂装懂哦。',
#   'user: 嗯嗯，我会尽量去学习的。',
#   'bot: 对了，我还不知道你叫什么名字呢？',
#   'user: 我的名字是姬轩超。',
#   'bot: 是一位小男生还是小女生呢？',
#   'user: 是个小男子汉！'],
#  ['user: 你知道张柏芝的生日是什么时候吗？',
#   'bot: 张柏芝的生日在5月24日。',
#   'user: 好的知道了，谢谢',
#   'bot: 不用客气，说起来张柏芝还是“时尚辣妈”呢',
#   'user: 对啊，我特别喜欢她',
#   'bot: 她还是香港电影评论学会最佳女演员呢，演技很好的',
#   'user: 我最喜欢看她的电影了，感觉看她的电影就是一种享受。',
#   'bot: 你好有眼光啊，这部张柏芝主演的《喜剧之王》是当之无愧的经典之作，您要不要看一下？',
#   'user: 这部电影的主演还有谁呀？',
#   'bot: 主演还有周星驰、莫文蔚等',
#   'user: 阵容很强大呢，我要去看',
#   'bot: 你一定会喜欢的。',
#   'user: 我到家了，先不聊了，咱们下次有空再聊吧。'],
#  ['user: 张国荣哪里出生的？',
#   'bot: 是香港九龙哦~',
#   'user: 你真厉害，什么都难不倒你哈哈',
#   'bot: 那当然啦，他获得过香港电影金像奖最佳男主角哟',
#   'user: 真是个优秀的男人，我喜欢的没错！',
#   'bot: 你可太有眼光啦，这名亚洲巨星可是无数少女的梦呢',
#   'user: 哈哈，我记得他还是第三十届金马奖最佳电影歌曲奖的获得者呢'],
#  ['bot: 下午好呀，最近怎么样啊？',
#   'user: 最近刚发了工资，心情不错呢。',
#   'bot: 那恭喜你呀。',
#   'user: 嗯呐，谢谢你。',
#   'bot: 没事啦，还不知道你叫什么名字呢？',
#   'user: 我叫柳芳洋。',
#   'bot: 那你是男士还是女士呢？',
#   'user: 我是可爱的女孩子呢。',
#   'bot: 那你多大了呀？',
#   'user: 我18了呀，还年轻呢哈哈。',
#   'bot: 是啊，你平时都有什么爱好呢？',
#   'user: 我喜欢看看电影听听歌还有我最爱的美食毛血旺，哈哈。',
#   'bot: 你的爱好还挺多呢。',
#   'user: 还好啦，我到家了，不说了。'],
#  ['user: 你知道今天是几号吗？',
#   'bot: 今天是2018年1月6日',
#   'user: 谢谢啊，我知道了',
#   'bot: 今天还是吴亦凡的生日哦，他可是亚洲人气男神呢',
#   'user: 是么？这位粉丝的我居然不知道，我太失败了',
#   'bot: 嘿嘿，他还是新浪娱乐15周年庆典杰出青年呢',
#   'user: 果然，偶像是最棒的',
#   'bot: 推荐你偶像的歌《大碗宽面》挺好听的，该曲包含浓烈的中国元素，旋律、歌词将东西方音乐融合，用说唱的方式传递出唱作人潇洒江湖行的无畏',
#   'user: 这是吴亦凡的新歌吗？我还没听呢',
#   'bot: 你一定会喜欢的',
#   'user: 那必须的，'],
#  ['user: 你好啊，请问电影『江湖龙女』的主演是谁?',
#   'bot: 主演是林心如。',
#   'user: 知道啦，谢谢哦，有你真好',
#   'bot: 过奖了，话说林心如被称为娱乐圈才貌双全的女明星了呢。',
#   'user: 我也很喜欢她呢，是我心目中的标准美女！希望美人迟暮来得晚一些~',
#   'bot: 而且她的演技很赞，获得过第5届首尔国际电视节中国最受欢迎演员呢。',
#   'user: 好棒啊，获得过这么多成就，也是对她实力的一种肯定啦，她的作品要多欣赏欣赏咯',
#   'bot: 那这部由她主演，讲述小城故事的『倾城』推荐给你呀。',
#   'user: 这部电影的导演是谁啊？',
#   'bot: 导演是黄宏',
#   'user: 看起来还不错，抽时间我会去看看的'],
#  ['user: 嗨，现在几点啦？',
#   'bot: 现在是中午12点整。',
#   'user: 真棒！',
#   'bot: 嘿嘿，提醒你今天多云,西南风,最高气温:0℃,最低气温:-11℃，注意保暖哦。',
#   'user: 真贴心。',
#   'bot: 我永远是您最贴心的小宝贝。',
#   'user: 爱你哦。'],
#  ['bot: 中午好呀，最近怎么样呢？',
#   'user: 中午好。最近学习退步了，我都不知道怎么才能跟得上。',
#   'bot: 学习不能心急，要知道自己哪部分比较弱，才能有进步。',
#   'user: 嗯嗯，我会加倍努力的。',
#   'bot: 对了，还不知道你叫啥呢？',
#   'user: 我叫胡静君，安静的静，君子的君。',
#   'bot: 名字挺好听呀，是个帅哥还是美女呢？',
#   'user: 嘻嘻，是个美女啦。',
#   'bot: 那敢问美女芳龄多少呢？',
#   'user: 今年27了。'],
#  ['bot: 中午好啊，陈霄洋',
#   'user: 你好呀',
#   'bot: 干嘛呢？',
#   'user: 在公司，现在在休息',
#   'bot: 有时间的话要不要看看《最爱》啊，电影讲述了一场无惧命运、超越世俗的“生死绝恋”。',
#   'user: 我现在不想看电影',
#   'bot: 那我们来聊聊别的，他的主演是国际巨星郭富城哦',
#   'user: 哇哦，我永远的偶像',
#   'bot: 是吗，他还是十大中文金曲全球华人最受欢迎男歌手呢，唱歌很好听的',
#   'user: 是的，会演戏，会唱歌，真是全能艺人',
#   'bot: 哈哈，那推荐你听一下他的这首《最好的声音》，很牛逼的一首歌呢',
#   'user: 我不想听这首歌，换一首吧',
#   'bot: 那《爱你》呢？是郭富城的经典歌曲呢',
#   'user: 听着不错，好听嘛？',
#   'bot: 你会喜欢的。',
#   'user: 好的，我听听',
#   'bot: 是否给你播放呢？',
#   'user: 行'],
#  ['user: 电影『巴尔扎克和小裁缝』主演是谁，你知道不？',
#   'bot: 它的主演是周迅',
#   'user: 嗯嗯，你知道的真多，真棒',
#   'bot: 周迅可是台湾电影金马奖的最佳女主角，还获得了亚洲电影大奖最佳女演员奖，我对她有点了解也是很正常的呢',
#   'user: 是啊，她很优秀，她还获得过哪些奖项，你可以告诉我吗？',
#   'bot: 她还获得了台湾电影金马奖最佳女主角奖、中国电影金鸡奖最佳女配角奖、还是中国电影金鸡奖的最佳女主角',
#   'user: 这么多啊，真厉害，不愧是我喜欢的爱豆',
#   'bot: 那你要不要来看看她的电影啊，《风声》怎么样？国内很不错的一部悬疑片，周迅收放自如的演技很受人喜欢呢',
#   'user: 可现在更喜欢刘若英的电影',
#   'bot: 刘若英的话，《候鸟》就很好看，是很有意思的一部电影，推荐你去看看',
#   'user: 评分怎么样？'],
#  ['user: 今天几号啦？',
#   'bot: 2018年5月17日',
#   'user: 好的，谢谢',
#   'bot: 今天还是王力宏的生日哦',
#   'user: 我知道，就是确定今天是不是'],
#  ['user: 电影『线人』主演是谁?',
#   'bot: 主演是谢霆锋哦。',
#   'user: 好的，谢谢。',
#   'bot: 没事啦，谢霆锋也算得上是个全才。',
#   'user: 对，我非常喜欢他',
#   'bot: 那你很有眼光啊，他在很多方面都获得过奖项的，例如他是香港电影金像奖最佳男主角呢。',
#   'user: 是啊，他还是香港杂志封面年龄最小纪录保持者。',
#   'bot: 对，谈到谢霆锋就不得不提起他的这部《半支烟》，有人说正是这部电影让我喜欢上谢霆锋',
#   'user: 是吗，谁导演的呢？',
#   'bot: 导演是叶锦鸿',
#   'user: 口碑还可以吧？',
#   'bot: 口碑还好',
#   'user: 好的，我看看去',
#   'bot: 祝你观影愉快',
#   'user: 再见'],
#  ['user: 你好，今天天气怎么样呢？',
#   'bot: 今天天气阴转多云,东风,最高气温:22℃,最低气温:12℃',
#   'user: 好的，谢谢哦。',
#   'bot: 这种天气温适合吃『烤鱼』呢',
#   'user: 好久没吃这道热菜了呢，这么一说都想吃了。',
#   'bot: 正好今天可以去回味回味呢',
#   'user: 好的。',
#   'bot: 给你推荐一家烤鱼特别好的店『蜀江烤鱼（天鹅湖万达店）』他家的很不错，还可以预定哦',
#   'user: 它的人均价格和评分怎么样呢？',
#   'bot: 人均68，评分3.7',
#   'user: 好的，地址在哪呢？',
#   'bot: 在蜀山区南二环路3818号天鹅湖万达广场3楼',
#   'user: 一会21：00就过去哟和我一个朋友。',
#   'bot: 好的，这就为你预定',
#   'user: 谢谢，再见。'],
#  ['user: 今天天气怎么样呀？',
#   'bot: 今天广州:多云,东北风,最高气温:22℃,最低气温:12℃哦！',
#   'user: 你好厉害，知道的好多。',
#   'bot: 这种天气温适合吃糖醋排骨了呢',
#   'user: 糖醋排骨是我最喜欢吃的美食呢。',
#   'bot: 糖醋排骨非常美味呢，还是一道家喻户晓的热菜呢。',
#   'user: 我现在就好想吃糖醋排骨呀！',
#   'bot: 我正好知道有一家店，推荐你在『品蜀国精品川菜（科学城店）』订糖醋排骨',
#   'user: 这家店的人均价格是多少？',
#   'bot: 人均价格是58哦。',
#   'user: 地址在哪里？',
#   'bot: 地址在:黄埔区科学城科学大道193号高德汇购物中心3楼',
#   'user: 评分是多少？',
#   'bot: 评分是4.2。',
#   'user: 好的，晚上八点半我一个人去吃，帮我预定一下吧。'],
#  ['user: 能告我一下吴亦凡的星座么。', 'bot: 你好，吴亦凡的星座为天蝎座。', 'user: 哇，你真好。'],
#  ['bot: 嗨，柳鑫彬，最近怎么样呢？',
#   'user: 最近挺好的呢',
#   'bot: 感觉你很开心啊，能分享下吗？',
#   'user: 也没啥，就是最近学习挺轻松的，压力小了不少'],
#  ['user: 哈喽，现在是几点啦？',
#   'bot: 现在是晚上22点了。',
#   'user: 你可真聪明呢，棒棒的',
#   'bot: 嘿嘿，提醒你今天天气晴,南风,最高气温:24℃,最低气温:16℃。',
#   'user: 我正好想知道呢，你可太贴心了',
#   'bot: 不客气哟。',
#   'user: 不早了，我该睡觉了，改天聊，拜拜'],
#  ['user: 今天天气如何？',
#   'bot: 今天武汉的天气为晴转多云，有东北风，最高气温9摄氏度，最低气温0摄氏度',
#   'user: 你真厉害啊，什么都知道',
#   'bot: 这样的天气，来份热乎乎的剁椒鱼头，真是再美妙不过了',
#   'user: 我爱吃剁椒鱼头这你都知道',
#   'bot: 当然，关键这道热菜，吃完心里也暖暖的。',
#   'user: 让你这么一说，忽然想吃了',
#   'bot: 推荐你去如家川菜馆尝尝，他家的特色菜就是剁椒鱼头，还能预定哦',
#   'user: 这家店的人均价格多少？',
#   'bot: 人均价格大概是15',
#   'user: 这家店的评分多少呢？'],
#  ['bot: 牛帅洲，中午好啊，最近学习怎么样呢？',
#   'user: 还可以，刚刚有进步了一点。',
#   'bot: 那确实挺好的呀，证明你挺努力的。',
#   'user: 是啊，真的是尽力了。',
#   'bot: 这都中午了，该休息一会了，来聊点轻松的吧，那你最喜欢看什么电影呢？',
#   'user: 嗯啊，我最喜欢看《消失的子弹》。',
#   'bot: 那你喜欢这部电影里的谁呀？',
#   'user: 当然是杨幂啦。',
#   'bot: 想不到你喜欢杨幂啊，她可是名副其实的收视率女王呢',
#   'user: 对的，她的人气确实很高',
#   'bot: 那可不嘛，人家可是获得过上海电视节白玉兰奖最具人气女演员呢',
#   'user: 哈哈，她身材又好长得又漂亮又有演技，谁不喜欢啊。',
#   'bot: 是呢，那有一部她主演的很有特点的国产科幻电影《逆时营救》你就可以看看，电影中不乏紧张刺激的动作戏码，高速公路追逐、实验室危险大爆炸、高空铁架近身搏斗、废校激烈枪战，让人看得目不接暇。',
#   'user: 不好意思，这部电影我已经看过了。',
#   'bot: 好吧，还有一部《新天生一对》，电影还蛮有爱的，你也可以看看。',
#   'user: 那听起来还挺不错的呢，那你可以告诉我他的导演是谁吗？'],
#  ['bot: 晚上好啊。',
#   'user: 你好呀。',
#   'bot: 最近怎么样啊？',
#   'user: 发奖金了呢，开心啊。',
#   'bot: 哈哈，那可不错，你叫什么来着？',
#   'user: 我叫柳琪琴。',
#   'bot: 看名字应该是个美女哦。',
#   'user: 哈哈，谢谢夸奖了。',
#   'bot: 那不知道美女多大了呢？',
#   'user: 36岁了。'],
#  ['bot: 下午好，朋友。',
#   'user: 你好啊。',
#   'bot: 近来如何啊?',
#   'user: 学习进步了，不错',
#   'bot: 真是恭喜你！还不知道你叫什么名字呢？',
#   'user: 我叫胡霄凤',
#   'bot: 很好听的名字，你是女士吗？',
#   'user: 当然啦，聪明.'],
#  ['user: 你好，我想看关于吴亦凡的新闻',
#   'bot: 好嘞，最近啊，一夜之间，吴亦凡的一些聊天记录、截图、音频纷纷被爆出，一下子吴亦凡成了网友八卦的新话题！“小g娜”还发微博自说是吴亦凡的女友，质问吴就算分手也要给一句话。后来吴亦凡工作室发表声明说网传女友之事纯属虚构。',
#   'user: 谢啦，确实是凡凡的新闻呢，你还挺聪明的',
#   'bot: 多谢夸奖。嘿嘿，吴亦凡最近的糟心事可不止这一件呢，他的新专辑好像也出了点问题。',
#   'user: 恩？新专辑又怎么了呢'],
#  ['bot: 早上好啊，曾枫超老先生。',
#   'user: 你好呀。',
#   'bot: 最近怎么样啊？有没有啥不顺心的地方？',
#   'user: 没啥，就是带孙子挺累的。'],
#  ['user: 给我推送些王力宏的新闻吧！',
#   'bot: 好的，前不久，钢琴王子李云迪和音乐创作才子王力宏同台演奏了哦，据说现场非常火爆，两位在舞台上斗琴演奏了《金蛇狂舞》和《龙的传人》。',
#   'user: 你真不错，还能读新闻呢。哈哈，我太小瞧你了',
#   'bot: 哈哈哈，告诉你吧，我还知道更多新闻呢，听说了吗，最近水果姐的MV被很多网友说是模仿王力宏之前的《AI爱》呢.',
#   'user: 是吗，那王力宏知道吗',
#   'bot: 对此，王力宏有回应哦，他说呀，被模仿是最高的说赞。',
#   'user: 二哥也太会说话了吧，这说话技巧，够我学一辈子了'],
#  ['user: 哈喽，今天是几号呢？',
#   'bot: 不好，今天是2018年5月17日。',
#   'user: 好的，有你真是方便呀。',
#   'bot: 谢谢夸奖咯，今天也是华语实力歌星王力宏的生日呢。',
#   'user: 是吗？我可喜欢王力宏了，他可是很完美呢。',
#   'bot: 是呀，他可是被称为金曲歌王呢，曾是第15届全球华语榜最佳港台男歌手哦。',
#   'user: 真的好棒呀，他可是一位天王呢。',
#   'bot: 他的歌也挺好听的，《BridgeofFaith》这首歌作为他的代表作吸引了一大批的粉丝呢，这首歌作为片尾曲也很好听，推荐给你听一听。',
#   'user: 我咋不知道这首歌呢，好听吗？'],
#  ['user: 你知道黄晓明是属什么的吗',
#   'bot: 属蛇的哦。',
#   'user: 你居然真的知道，你好棒啊',
#   'bot: 嘿嘿，看你挺关注他的，你应该是他的粉丝吧。',
#   'user: 是的呢，他是我最喜欢的演员呢',
#   'bot: 不光演技好，他还是联合国艾滋病规划署中国亲善大使。',
#   'user: 优秀啊，这么一说我更喜欢他了',
#   'bot: 这么喜欢他，他的电影『大上海』非常的好看哦，影片重现了20-30年代上海滩的繁华盛景，你一定会喜欢的。',
#   'user: 那电影的导演是谁呢',
#   'bot: 是王晶。',
#   'user: 那应该挺好看，我有时间要看看',
#   'bot: 好的，你一定会喜欢的。',
#   'user: 我现在要去吃饭了，不能和你聊天了，拜拜'],
#  ['bot: 你好啊，中午休息时间到了哦。',
#   'user: 嗯嗯，是啊。',
#   'bot: 最近学习怎么样呀？',
#   'user: 学习压力好大啊。',
#   'bot: 那要劳逸结合哈，我陪你聊会天吧，对了，你叫什么名字呀？',
#   'user: 我叫胡玉振。',
#   'bot: 听名字应该是个男孩子吧？不知道我猜对了没有？',
#   'user: 你好聪明，猜对啦。',
#   'bot: 嘿嘿，你今年多大了？',
#   'user: 我二十六岁了。',
#   'bot: 那你平时有什么爱好呀？',
#   'user: 喜欢看看新闻'],
#  ['user: 今天几号啊？',
#   'bot: 今天是2018年12月13日',
#   'user: 真快呢，谢谢你哦',
#   'bot: 不客气哦，对了东莞今天多云,东北风,最高气温14℃,最低气温11℃，出门要注意保暖哟。',
#   'user: 谢谢你的关心，你真贴心。'],
#  ['user: 你知道吴亦凡的身高吗？',
#   'bot: 你好，吴亦凡的身高是187cm。',
#   'user: 好的，谢谢。',
#   'bot: 不用谢，我还知道他是出生于1990年的大帅哥哦。',
#   'user: 知道的真的多呀，真的是一位人气男星啊，我很喜欢他呢。',
#   'bot: 而且他还获得东京国际电影节·中国电影周”最佳男主角这样的大奖哦。',
#   'user: 是的呢，还是首位90后艺人蜡像入驻上海杜莎夫人蜡像馆的人呢。',
#   'bot: 《Deserve(LidoRemix)》这首是他演唱的优秀作品，推荐给你，凡凡声音好苏。',
#   'user: 真是他唱的吗?怎么没有听过呀。',
#   'bot: 是吴亦凡演唱的，绝对好听。',
#   'user: 那我的得听听了。'],
#  ['bot: 金立国晚上好啊',
#   'user: 嘻嘻，晚上好啊',
#   'bot: 最近工作怎么样啊',
#   'user: 最近工作挺好，还发了工资呢',
#   'bot: 那正好可以看看电影犒劳一下自己，《活该你单身》怎么样？电影情节很新颖，值得一看哦',
#   'user: 我现在暂时不想聊电影',
#   'bot: 那我们来聊聊这个电影的主演林心如吧，你喜欢她吗，她是笑容暖心女星',
#   'user: 是啊，她还是古装戏美艳的女星',
#   'bot: 她还是第18届华鼎奖中国最佳电视剧女演员，足以见得她非常的棒',
#   'user: 是啊，演技好，还漂亮',
#   'bot: 你这么喜欢她，她的歌《海洋》不错哦，歌曲还表达了都市女子的爱情新主张，送给你',
#   'user: 我听过了',
#   'bot: 那她的《想着你》呢？还是电视剧《半生缘》的原声带哦',
#   'user: 听名字不错',
#   'bot: 那一定不会失望的，相信我',
#   'user: 好的，那我听听',
#   'bot: 那现在就给你播放《想着你》可以吗',
#   'user: 好的，播放吧',
#   'bot: 好的，这就给你放',
#   'user: 听完了，不错，我有事要忙'],
#  ['user: 今天的天气啥情况啊？',
#   'bot: 今天是晴~多云,西南风,最高气温:13℃,最低气温:-2℃，会稍微有点冷呢',
#   'user: 是啊，我也是觉得好像挺冷呢，你真好呢，都告诉我啦',
#   'bot: 那是肯定的啦，不过今天的天气要是听上一首『中国魂(Live)』感觉都热血沸腾了呢，表达了主唱身为华人的骄傲以及高度的文化自信。',
#   'user: 也不知道是谁唱的啊？',
#   'bot: 是我们的音乐才子吴亦凡唱的哦',
#   'user: 我很看好这个小伙子呢，可以听听看',
#   'bot: 那还不如我现在就给你播放一下呢',
#   'user: 行，现在就能播放'],
#  ['bot: 早上好啊！',
#   'user: 你也好啊',
#   'bot: 最近过得怎么样？',
#   'user: 还行吧，就是工作有点忙',
#   'bot: 那你要合理安排一下时间喽。',
#   'user: 嗯，我会的，谢谢你哟',
#   'bot: 我可以知道一下你的名字吗？',
#   'user: 我叫雷晓君',
#   'bot: 那您一定是个女生吧？',
#   'user: 是啊，我是个女生哟',
#   'bot: 那我可以冒昧的问一下您的年龄吗？',
#   'user: 我今年37了'],
#  ['user: 你好，请问电影『二次曝光』主演是谁?',
#   'bot: 是范冰冰哦！',
#   'user: 好的，知道了，多谢，你可真厉害',
#   'bot: 范冰冰可是娱乐圈老牌女星哦！',
#   'user: 我最喜欢她了',
#   'bot: 那你眼光不错哦！她曾获得台湾电影金马奖最佳女主角奖呢！',
#   'user: 那是自然，我喜欢的明星必然是最优秀的！'],
#  ['user: 今天的天气怎么样？',
#   'bot: 合肥2018年11月19日，多云,东南风,最高气温14度，最低气温5度',
#   'user: 你知道的可真多呢',
#   'bot: 这种天气，适合吃玉米饼了',
#   'user: 玉米饼，很有营养哦，不错',
#   'bot: 是啊，玉米粉是对胃好的粗粮哦',
#   'user: 感觉挺不错的，改天去尝尝吧',
#   'bot: 玉米饼的话推荐你去蜀江烤鱼（天鹅湖万达店）这家店，这家店可以提前预定的。',
#   'user: 这家店的人均价格怎么样呢？',
#   'bot: 蜀江烤鱼（天鹅湖万达店）人均价格是68',
#   'user: 这家店的地址是在哪呢？'],
#  ['user: 今天天气怎么样',
#   'bot: 今天晴,无持续风向,最高气温:28℃,最低气温:12℃',
#   'user: 很好，你很棒',
#   'bot: 嘻嘻，这样的天气适合吃剁椒鱼头',
#   'user: 剁椒鱼头我爱吃，要是辣一些我会更喜欢了'],
#  ['bot: 邢琪佳，中午好',
#   'user: 中午好',
#   'bot: 最近如何？',
#   'user: 工作压力老大了，难受死',
#   'bot: 和我聊天缓解缓解吧，你最喜欢谁的新闻',
#   'user: 王力宏',
#   'bot: 那给你说说他的新闻，好嘛？',
#   'user: 好的呀',
#   'bot: 最近啊，电影《无问西东》大热，饰演沈光耀的王力宏演技受到好评。谈到自己的本职工作——音乐，王力宏说自己一直初心未变。13年前创作《我就喜欢》嘻哈版，如今嘻哈再次席卷中国；看中人气，邀请TFBOYS组合参与新专辑…面对流行的快速更迭，他说“各种潮流包装都在变，但我的本质没有变，我还是热爱音乐，热爱电影，热爱创作”',
#   'user: 他一直是我心目中的全能男神呢，希望他能一直这样下去'],
#  ['bot: 晚上好呀，最近过得怎么样呢？',
#   'user: 你好啊，今天公司给我发工资了很高兴啊。',
#   'bot: 那很好呀，又可以好好潇洒几天了。',
#   'user: 是呀，先去犒劳自己一顿哈哈哈。',
#   'bot: 聊了这么多还不知道你叫啥呢？',
#   'user: 我叫任萍。',
#   'bot: 一听名字就是一位美女吧？',
#   'user: 哈哈，你猜对了。',
#   'bot: 哈哈，我猜的很准呀，不知道美女多大了呢？',
#   'user: 23啦。'],
#  ['bot: 早上好，徐利。', 'user: 早上好啊', 'bot: 最近怎么样呢？', 'user: 最近工作压力好大啊'],
#  ['user: 你知道电影『我是证人』的主演是谁吗?',
#   'bot: 这部电影的主演是杨幂',
#   'user: 我知道了，谢谢',
#   'bot: 不客气，你喜欢杨幂吗？她可是华语电影传媒大奖观众票选最受瞩目女演员呢',
#   'user: 当然喜欢啦，她可是电视小红人。'],
#  ['user: 今天天气怎么样啊？',
#   'bot: 你好，海口今天夜间到明天白天雷阵雨,无持续风向,最高气温:29℃,最低气温:24℃，出门注意带伞啊。',
#   'user: 谢谢提醒，我会注意的。',
#   'bot: 不要客气，今天这个天气很适合吃毛血旺了哟。',
#   'user: 真的嘛，我最喜欢的就是这道菜了',
#   'bot: 那你太有眼光了，鸭血牛肚都是这道菜的精髓呢',
#   'user: 有时间了一定会去好好吃一顿。'],
#  ['user: 你知道王力宏多高吗？',
#   'bot: 当然知道，一米八呢',
#   'user: 这都知道，厉害',
#   'bot: 嘿嘿，说起王力宏，他演戏还不吃，还获得了香港电影金像奖最佳新演员，华语电影传媒大奖观众票选最受瞩目男演员等',
#   'user: 是的呢，他真优秀'],
#  ['user: 今天几号了啊？',
#   'bot: 今天是2018年1月18日',
#   'user: 你可真棒，什么都知道呢。',
#   'bot: 过奖啦，话说今天也是歌星周杰伦的生日哦！',
#   'user: 好巧，竟然是我喜欢的明星的生日。',
#   'bot: 是啊是啊，他很优秀呢，获得十五座金曲奖，还是两届MTV亚洲大奖最受欢迎艺人，真的很棒！',
#   'user: 很喜欢听他的歌，从未改变的喜欢。',
#   'bot: 那么这首好听的『海盗』，佛朗明哥”加“嘻哈”曲风的舞曲，你一定要试一试哦~',
#   'user: 歌名听起来很有意思。'],
#  ['user: 谢霆锋啥血型来着？',
#   'bot: 他是A型血。',
#   'user: 聪明啊',
#   'bot: 必须的，或许你喜欢谢霆锋吗？他是个不折不扣的好男人！',
#   'user: 喜欢啊，我的偶像，可以说是史上亲民的明星',
#   'bot: 不仅如此，他在演戏上也很拼，还曾经获得过台湾电影金马奖最佳男主角奖',
#   'user: 不错，太优秀了',
#   'bot: 你如此喜欢他，可以看看他的《恋爱行星》这部电影，看得出林超贤拍这部电影很用心，从开始的谢、林因相识而初萌爱意，到中间谢霆锋帮助林嘉欣了却心愿，再到最后穿梭阴阳两界“将爱情进行到底”，都能演绎得有声有色，部分画面做得美轮美奂，给人感觉极佳。',
#   'user: 但是我现在更喜欢张柏芝的电影',
#   'bot: 那张柏芝的这部《辣手回春》你就不要错过啦，很搞笑的一部电影哦',
#   'user: 喜剧吗',
#   'bot: 是部喜剧呢，希望你喜欢！',
#   'user: 还不错，那我回家看看吧',
#   'bot: 嗯呢，不容错过哦。',
#   'user: 我马上到家了，先不说了，再见'],
#  ['bot: 刘萍露晚上好啊，今天心情怎么样？',
#   'user: 很高兴，我发奖金了',
#   'bot: 高兴的时候再听首歌吧，『这些年来』这首歌好好听哦，要不要听？',
#   'user: 暂时不想听音乐',
#   'bot: 它可是全能明星张国荣唱的哦',
#   'user: 他可是天皇巨星',
#   'bot: 还是十大劲歌金曲最受欢迎男歌星呢',
#   'user: 是的，他还是华语唱片在韩国销量纪录保持者',
#   'bot: 推荐你看『枪王』这个电影，还不错哦',
#   'user: 我看过了，有其他的吗',
#   'bot: 那『男生女相：中国电影之性别』呢，是个很不错的纪录片',
#   'user: 他的评分怎么样',
#   'bot: 评分7.8呢',
#   'user: 那我要看看'],
#  ['user: 现在几点了',
#   'bot: 在的亲，现在是2018年12月15日，中午12:00啦。',
#   'user: 谢谢了，这么详细',
#   'bot: 嘿嘿，另外今天邢台的天气是多云~晴,东南风,最高气温:6℃,最低气温:-1℃，注意保暖。',
#   'user: 好的，你好贴心'],
#  ['user: 今天是几号？',
#   'bot: 今天是:2018年4月28日',
#   'user: 你真聪明！什么都知道.',
#   'bot: 对啦，今天还是娱乐圈里的明星教师何炅老师的生日呢',
#   'user: 我很喜欢何炅老师的！他是我的偶像呢！',
#   'bot: 他不仅主持节目特别棒，唱歌也超级好听呢',
#   'user: 我也喜欢他的音乐呢！',
#   'bot: 他的『另一个自己』这首歌你听过吗，41岁的何炅，把挑战“另一个自己”、完成导演梦的心声融进歌里，传递出“一切都来得及”的青春态度。',
#   'user: 我喜欢这首歌呢！',
#   'bot: 这首歌很适合单曲循环呢',
#   'user: 我超想听这首歌呢！',
#   'bot: 那要我为你播放这首歌吗？',
#   'user: 好的'],
#  ['user: 放首『超人不会飞』',
#   'bot: 正在放！',
#   'user: 好好听，有你真好',
#   'bot: 应该的，还有一首他的《自导自演》也很棒，是一首R&B曲风的歌曲，你要听听吗',
#   'user: 对这首歌不感兴趣',
#   'bot: 那你听听《花海》怎么样？是一首充满岛国风情的歌曲，周杰伦以海岛唱腔演唱，有种抚慰人心的力量。',
#   'user: 这首我还没听过呢',
#   'bot: 可以听听看，相信你会喜欢的',
#   'user: 那我就得听听',
#   'bot: 需要为你放吗？',
#   'user: 放吧'],
#  ['user: 今天几号了？', 'bot: 今天是2018年7月10日', 'user: 时间过得可真快，半年就过去了。'],
#  ['user: 天气怎么样？', 'bot: 今天多云,西北风,最高气温25℃,最低气温13℃', 'user: 真棒，谢谢'],
#  ['user: 你知道『太平轮（上）』的主演是谁吗？',
#   'bot: 这部电影的主演是黄晓明。',
#   'user: 哦我知道了，谢谢啊',
#   'bot: 不客气，像黄晓明这样很帅很帅很帅的帅哥，我记忆犹新呢',
#   'user: 是吧！我也觉得他非常帅气',
#   'bot: 他的人气很高吧，还获得过第17届北京大学生电影节最受欢迎男演员呢',
#   'user: 哈哈，因为他演技又好长得又帅，自然讨人喜欢啰',
#   'bot: 那你要不要看下他主演的『风声』？这是一部很优秀的作品呢，电影很残酷，比其他那些犹如神助的片子现实。',
#   'user: 这部电影我已经看过了，而且我现在更想看杨幂演的电影'],
#  ['bot: 中午好啊曾娇菲，最近怎么样啊？',
#   'user: 中午好，考试没有考好，不开心。',
#   'bot: 没事的，只是一次考试而已，下次加油喽。',
#   'user: 嗯，我要振作我自己。',
#   'bot: 对的！我们来换个开心点的话题吧，你爱看哪部电影啊？',
#   'user: 我喜欢『新边缘人』这部电影。',
#   'bot: 很棒的电影啊，你是喜欢哪一位演员呢?',
#   'user: 肯定是张学友了。',
#   'bot: 是他啊，那你知道张学友还有香港歌王的称号吗。',
#   'user: 当然了，只要看过他演唱会的人都会说他是最棒的。',
#   'bot: 哈哈，确实，说他是黄金巨星也不为过',
#   'user: 他就是我心中的巨星！',
#   'bot: 那你一定也很喜欢看他演的其他的电影吧，『1:99电影行动』就很不错，电影有些场面还很震撼哦。',
#   'user: 我对这电影不感兴趣，不是很想看。',
#   'bot: 那他的这部看完每次都会心动的『真的爱你』推荐给你。',
#   'user: 主演是谁啊？',
#   'bot: 主演是张学友，吴君如，张曼玉。',
#   'user: 哇，阵容很强大啊。我会去看看的，口碑怎么样啊？',
#   'bot: 口碑还是挺好的值得一看。',
#   'user: 嗯好的，我会去看的，我要去学习喽。'],
#  ['user: 中午好，今天天气怎么样呀？',
#   'bot: 今天的天气晴，多云，东北风，最高气温，3℃，最低气温，-1℃，出门记得多穿衣服哟。',
#   'user: 好的，谢谢，真的是好冷呀！',
#   'bot: 对呀，但是今天的天气适合吃水煮鱼热腾腾，可以暖身体。',
#   'user: 是哦，你真是聪明呀，知道我爱吃鱼',
#   'bot: 吃鱼好啊既有营养，又不长肉，相信我绝对没错。',
#   'user: 你说的我现在已经在流口水了。',
#   'bot: 你可以去旺池川菜（青岛万象城店）哪里的特殊就是，水煮鱼。',
#   'user: 这你都知道，它那人均价格是多少呢，地址在哪呢？评分怎么样呢？',
#   'bot: 人均价格67，地址是市南区山东路10号万象城L543（香港中路），评分3.3非常好吃哦。',
#   'user: 好的，离我们学校还挺近的，晚上18点我要和我的4个朋友去大吃一顿，谢谢你的推荐！'],
#  ['user: 你好，你知道现在是什么时间吗？',
#   'bot: 现在是2018年12月9日星期日晚上八点整哦~',
#   'user: 不错嘛，知道的挺多。',
#   'bot: 谢谢夸奖哦，对了今日晴~多云,西南风,最高气温:-3℃,最低气温:-11℃，早晚温差大，注意防寒保暖哦~',
#   'user: 真贴心呢。',
#   'bot: 我永远是您贴心的小棉袄喔~',
#   'user: 跟你聊天很开心，但我现在要出去了，下次再聊啊，再见。'],
#  ['user: 福州今天的天气怎么样呢？',
#   'bot: 福州今天的天气为多云转小雨，有东北风，最高气温21摄氏度，最低气温15摄氏度',
#   'user: 真棒，为你点赞。',
#   'bot: 这种天气，来份好吃的烤鱼真的是太完美了',
#   'user: 我挺喜欢吃石斑鱼的',
#   'bot: 很有营养的，也适合阴雨天吃',
#   'user: 看起来感觉不错，有时间一定要去尝尝。'],
#  ['bot: 嗨，刘萍露',
#   'user: 早上好',
#   'bot: 最近怎么样？',
#   'user: 有点寂寞呢',
#   'bot: 聊点别的，你最喜欢谁的新闻呢？',
#   'user: 我最喜欢郭富城的了',
#   'bot: 给你说说一条关于他的新闻吧，郭富城和方媛交往3个多月以来，常送方媛一些贵重的首饰、巧克力等，方媛之前还抱怨城城不肯送她10万元的爱马仕包，还说方媛一直在上海租房她看中两千万的豪宅，郭富城却老找借口不陪方媛看房。',
#   'user: 真不知道是人吸引她呢，还是钱吸引',
#   'bot: 这个不好说呢，可能都有吧',
#   'user: 到底怎么样也不知道，不随便说他们'],
#  ['bot: 上午好啊，亲爱的张凡振，近来状态如何？',
#   'user: 上午好，刚退休没事做，比较寂寞。',
#   'bot: 这样啊，还是要找些事情来排忧解闷的呀。',
#   'user: 好啊，我会尝试的。',
#   'bot: 不如来听会歌吧，这首百花齐放百家争鸣的『最好的声音』很不错。',
#   'user: 不好意思，暂时不想听音乐。',
#   'bot: 那么来聊聊这首歌有参与演唱的张学友吧，他可是当之无愧的巨星！',
#   'user: 我很喜欢他，舞台经验丰富的歌神。'],
#  ['user: 今天几号了啊？',
#   'bot: 你好，今天是2018年9月27日。',
#   'user: 谢谢了啊！真快啊，这转眼就到月底了。',
#   'bot: 今天也是一个好日子哦，你知道么，今天是刘德华的生日呢。',
#   'user: 是嘛，今天还是我偶像的生日呢？话说回来，他是几几年出生的啊？'],
#  ['user: 在么，能给我说一下张学友的新闻么。',
#   'bot: 好的呢。张学友在广东办的演唱会，算是非常引人注目了，在安检通道检票时，民警通过人像识别系统成功识别出一名在逃人员范某并抓获。据粗略统计，自今年4月第一起，警方已在张学友演唱会上陆续抓捕了约60名犯罪嫌疑人或在逃人员。',
#   'user: 哇，真是天网恢恢疏而不漏呀。',
#   'bot: 是的呢，罪犯是逃不过警察叔叔的眼睛的。这不，在洛阳，又有一个遭殃的。',
#   'user: 是嘛，是什么新闻，',
#   'bot: 是这样的，平安洛阳7月8日报道，民警在张学友演唱会现场附近执勤时发现一车辆交通违法，后来调查之后才知道，原来这个开车的人是从563公里远的武汉赶到洛阳，冒用他人信息无证驾驶，就是为看张学友演唱会。',
#   'user: 哈哈，天王真是罪犯的克星呀。'],
#  ['bot: 你好啊',
#   'user: 你好。',
#   'bot: 最近生活怎么样',
#   'user: 最近生活挺无聊的',
#   'bot: 嘻嘻，那就聊聊其他的，对了，你叫啥了？',
#   'user: 我叫李静佳。',
#   'bot: 你是女生吗',
#   'user: 对的呀，你好聪明！',
#   'bot: 那你今年多大了，嘻嘻',
#   'user: 我已经50多了。',
#   'bot: 那你有啥爱好呢',
#   'user: 人老了，就喜欢追星和听音乐，打发时间。',
#   'bot: 不错不错，挺好的',
#   'user: 哈哈，我要去吃饭了，咱们下次聊吧！'],
#  ['user: 你知道现在什么天气吗？',
#   'bot: 现在晴~多云,无持续风向,最高气温22℃,最低气温12℃。',
#   'user: 那还挺热的呢，你回答的也挺快的呢。',
#   'bot: 还可以吧，在路上听首《从此以后》吧，整首歌曲风清新流畅，旋律温暖抒情，朗朗上口',
#   'user: 是谁的歌啊？',
#   'bot: 是吴亦凡的歌哦。',
#   'user: 听起来还不错。'],
#  ['bot: 最近如何？',
#   'user: 心情不错呢。',
#   'bot: 什么事情这么开心啊？',
#   'user: 学习进步了呢。',
#   'bot: 那可真棒，对了，你叫啥啊?',
#   'user: 我姓莫叫鑫文，你叫我小文就好啦。',
#   'bot: 听这个名字，你一定是个大美女吧？',
#   'user: 还好啦，我也就是个长相普通的女生、',
#   'bot: 那你今年多大了呀？',
#   'user: 二十八周岁。',
#   'bot: 你平常都喜欢干嘛呢？',
#   'user: 除了上课时间，就是看看电影，了解了解喜欢明星的新闻了。',
#   'bot: 哈哈，年轻人都很喜欢呢。',
#   'user: 是啊，我有一点事，下次再找你聊天吧。'],
#  ['user: 今天天气情况如何呢？',
#   'bot: 扬州今日有小雨,东北风,最高气温:16℃,最低气温:11℃',
#   'user: 嗯，知道了，你真是个百事通哦',
#   'bot: 这种天气适合吃烤鱼哦',
#   'user: 听起来不错，今儿确实冷'],
#  ['bot: 嗨，近来可好？',
#   'user: 哈喽，最近可开心了呢！今天发奖金了，要好好犒劳犒劳自己呢。',
#   'bot: 哈哈，那可不真不错呀，我们交个朋友吧。',
#   'user: 可以呀！',
#   'bot: 你叫什么名字呢？',
#   'user: 我叫李明铮。',
#   'bot: 听名字就是一位男士，我说的没错吧？',
#   'user: 是的呢，你可真聪明，这都知道。',
#   'bot: 那你多大了呢？',
#   'user: 我52啦，已经是一位中年大叔了。',
#   'bot: 那你平时有什么兴趣爱好吗？',
#   'user: 我平时就喜欢听听音乐看看电影，不怎么喜欢运动。',
#   'bot: 你应该注意养生，得坚持运动啊。',
#   'user: 好的，谢谢你的建议哦，我到家了，下次再聊！'],
#  ['user: 今天几号',
#   'bot: 今天是2018年10月7日',
#   'user: 好贴心啊你，好喜欢',
#   'bot: 谢谢你的喜欢。九江今天晴转多云,北风,最高气温:27℃,最低气温:17℃',
#   'user: 你真聪明，太棒了',
#   'bot: 嘻嘻，谢谢你的夸奖',
#   'user: 不客气，洗漱去了，再见'],
#  ['user: 知道林心如的星座吗？',
#   'bot: 当然知道了，林心如是水瓶座的。',
#   'user: 好的，谢谢你。',
#   'bot: 说到林心如，她是两岸三地人气明星呢。',
#   'user: 我觉得林心如是真正的美人，我很喜欢她的娃娃脸。'],
#  ['user: 今天的天气情况怎么样？',
#   'bot: 今天秦皇岛晴,无持续风向,最高气温:13℃,最低气温:1℃',
#   'user: 哦，知道了，谢谢你啊！',
#   'bot: 今天这种天气非常适合吃宫保鸡丁呦',
#   'user: 是吗？你知道这道热菜是我的最爱么',
#   'bot: 当然了，这道菜营养丰富很不错呢',
#   'user: 哇，说的我都想吃了'],
#  ['bot: 中午好，陈娜君，近来生活怎么样？',
#   'user: 最近不太开心，考试都考的不好。',
#   'bot: 不要灰心，听听音乐放松一下，调整好心态继续努力',
#   'user: 谢谢你的鼓励，我一定会努力的。',
#   'bot: 吴亦凡在rap上还是有实力的，推荐你听听他的『刀剑如梦』',
#   'user: 不好意思，我暂时不想聊音乐。'],
#  ['user: 我来问问今天的天气',
#   'bot: 晴,南风,最高气温:16℃,最低气温:8℃，有点冷呢',
#   'user: 知道了，你好聪明啊，真棒呢',
#   'bot: 这种天气，吃个『水煮肉片』暖暖身体，简直太美了呀！',
#   'user: 你可说我心坎上了，我最爱吃牛肉',
#   'bot: 那太合适了啊，你可以尝尝去呀',
#   'user: 好呀好呀，改天去吃一下'],
#  ['user: 你好，我想点播《当爱已成往事》这首歌',
#   'bot: 正在为你播放《当爱已成往事》',
#   'user: 真的很好听呢，谢谢',
#   'bot: 客气了，你知道你听过『怪你过份美丽』吗，这首歌哥哥诠释得很好呢，推荐给你听听吧',
#   'user: 不好意思，我不想听这首歌，不太喜欢这首歌的内容',
#   'bot: 那『似水流年』呢？这首歌还获得过1985的白金唱片十大劲歌金曲奖呢',
#   'user: 这首歌名字听起来不错'],
#  ['user: 中午好，现在是什么时间呢？',
#   'bot: 你好，现在是2018年12月18日，星期二，中午12:00。',
#   'user: 好的，知道了。',
#   'bot: 还有厦门今日晴,东北风,最高气温:20℃,最低气温:11℃。温差较大，小心感冒。',
#   'user: 好的，我记住了，有你真好。',
#   'bot: 这都是我应该做的。',
#   'user: 我先去吃饭了，完了再找你。'],
#  ['user: 点一首『淡水海边』',
#   'bot: 好的，为你放',
#   'user: 歌好听，但是你更好',
#   'bot: 我都害羞了。还有一首《迷魂曲》，是周杰伦首次尝试电子舞曲。这歌吊不吊就不用说了，关键真的很容易抖腿。',
#   'user: 对这首歌不感兴趣',
#   'bot: 好吧，那你可以听听《骑士精神》，很经典的一首歌呢',
#   'user: 这个歌感觉不错',
#   'bot: 对，感觉你会喜欢的。',
#   'user: 听上去不错哦'],
#  ['user: 嗨，你知道『爱你等于爱自己』的音乐主唱是谁吗？',
#   'bot: 我知道呢,是王力宏呢!',
#   'user: 好的，有你真是方便呀。',
#   'bot: 嘿嘿,他可是当红明星呢,我怎么可能不知道呢!',
#   'user: 真的超喜欢他呢，真的是亚洲天王呢。',
#   'bot: 是的呢，而且他很有才华，还获得了全球流行音乐金榜年度最佳男歌手奖呢。',
#   'user: 他的音乐的确很优秀',
#   'bot: 嗯,那为您推荐一首他唱的《心中的日月(Live)》,曲中流畅优美的曲风仿佛带听众飞越人间仙境，笛子、六弦琴、扬琴、鼓及金发等中乐，运用中国五音阶的创作方式谱出西洋音乐的旋律。',
#   'user: 听名字好有诗意呀，听起来不知道怎么样？',
#   'bot: 唱的非常好听呢!',
#   'user: 你说的我真的好想听一听呀。',
#   'bot: 那现在是否为您播放一下呢?',
#   'user: 好的呀，播放吧。'],
#  ['user: 你好啊，今天天气还好吗？',
#   'bot: 济南今日晴,东南风,最高气温:15℃,最低气温:6℃。',
#   'user: 好的呢，谢谢咯，你可真棒',
#   'bot: 还好还好，晚上在家还蛮适合听这首『十八般武艺』哦。以多种民族乐器的演奏，伴随着西洋的节奏，既是多元化音乐风格的结合，又能带给人们一种欢快的心情哦。',
#   'user: 这首歌是谁唱的啊？',
#   'bot: 是王力宏唱的哦。',
#   'user: 是我最喜欢的明星了，那一定不能错过咯',
#   'bot: 现在可以为您播放这首歌曲吗？',
#   'user: 好啊，帮我播放吧'],
#  ['user: 今天天气咋样？',
#   'bot: 太原今日阴转小雨,西风,最高气温15度最低气温5度。',
#   'user: 真棒，给你点个赞。',
#   'bot: 这样的天气，来上一份烤鱼岂不美哉。',
#   'user: 呦呵，连我的最爱你都知道？',
#   'bot: 关键这道热菜吃了它心里暖暖的呢。',
#   'user: 可以啊，你啥也知道，说的我好想吃啊',
#   'bot: 你想吃烤鱼的话推荐你去真知味烤鱼，这家店可以预定哦。',
#   'user: 这家店的消费咋样？',
#   'bot: 人均消费在42左右。',
#   'user: 这家店的评分怎么样？',
#   'bot: 评分不错，有4.4呢。',
#   'user: 那这家店在哪？'],
#  ['user: 今天是几号？',
#   'bot: 今天是2018年11月13日',
#   'user: 真棒，你知道的可真多啊。',
#   'bot: 嘿嘿，说起来今天还是黄晓明的生日呢。',
#   'user: 可以啊，连黄晓明的生日你都能知道！',
#   'bot: 我还知道黄晓明是“山东省十大杰出青年”，曾获第4届英国万像国际华语电影节男主角奖呢。',
#   'user: 确实优秀啊，人长得帅不说，演技也是无可挑剔的。',
#   'bot: 是的呢，推荐你看看他主演的《城市猎人》，无论是华丽的武打场面还是动人的爱情故事都颇值得回味呢。',
#   'user: 相对来说，我现在更喜欢杨幂的电影。',
#   'bot: 那你可以看看杨幂主演的《八星抱喜》，网友评论说心情不好的时候看喜剧片挺好的。',
#   'user: 这是什么类型的电影？口碑咋样',
#   'bot: 这是一部喜剧爱情片，口碑还可以',
#   'user: 感觉不错，有时间去看看。',
#   'bot: 相信它不会让你失望的',
#   'user: 嗯呢，我还有事，下次再聊。'],
#  ['user: 今天几号了？', 'bot: 今天是2018年4月16日。', 'user: 好的，谢谢'],
#  ['user: 何炅的生日是哪一天？',
#   'bot: 何炅的生日是4月28号。',
#   'user: 你真聪明，知道的真多。',
#   'bot: 我还知道何炅曾获得过二十五届中国电视金鹰奖优秀主持人奖呢！',
#   'user: 我特别喜欢何炅，他是一个有爱心的明星'],
#  ['user: 《眼泪成诗(Live)》这首歌的主唱是谁呀？',
#   'bot: 是周杰伦',
#   'user: 嗯，你懂得真多，优秀',
#   'bot: 说到周杰伦，他可算是个音乐鬼才”了呢',
#   'user: 嗯，是的呢，它可是《FastCompany》全球百大创意人物呢',
#   'bot: 是啊，他还获得了好多奖呢，四届世界音乐大奖最畅销中华区艺人，大中华区8次年度唱片销量冠军',
#   'user: 不愧是我爱豆',
#   'bot: 他这首《雨下一整晚》你听过吗？推荐给你哦，是一首抒情情歌，在歌曲进行一半时转为中国风，有耳目一新的感觉',
#   'user: 听着感觉这首歌似乎有点悲伤呢',
#   'bot: 每首歌都有自己的故事，听过之后就会发现它的奇妙之处',
#   'user: 嗯呢，爱豆的歌必须捧场',
#   'bot: 现在要为你播放吗？',
#   'user: 好啊，赶紧放吧',
#   'bot: 好的呢，正在为你播放~',
#   'user: 先不说了，要吃饭了，下次聊，拜'],
#  ['user: 我想知道周迅是星座的，你知道不',
#   'bot: 她是天秤座的',
#   'user: 哇，你这都知道，真厉害',
#   'bot: 当然啦，周迅可是一位大美女呢，还获得了中国电影金鸡奖的最佳女主角奖',
# ...
#   'bot: 报告，深圳今天多云,无持续风向,最高气温:27℃,最低气温:21℃',
#   'user: 好的，你好棒啊',
#   'bot: 嘿嘿，过奖过奖。今天推荐你吃剁椒鱼头，很合适今天吃哦！',
#   'user: 感觉起来不错啊',
#   'bot: 是的，这道热菜会给你带来温暖',
#   'user: 那就吃这个吧',
#   'bot: 您可以去宅宅湘菜订剁椒鱼头，这是他家的招牌菜。',
#   'user: 人均价格多少啊',
#   'bot: 人均价格50',
#   'user: 地址在哪',
#   'bot: 在龙岗区较场尾较三西六巷内',
#   'user: 评分怎么呀啊',
#   'bot: 评分4.4',
#   'user: 那还不错，那我吃吃吧',
#   'bot: 好的呀，去这家你不会失望的',
#   'user: 好的，那就明天中午十二点三人去',
#   'bot: 嗯，到时候为您安排好。',
#   'user: 好的，再见'],
#  ['user: 今天几号？', 'bot: 今天是2018年10月5日哦', 'user: 嗯，我知道了，谢谢啊'],
#  ['bot: 哈喽',
#   'user: 你好啊',
#   'bot: 最近生活愉快吗？',
#   'user: 不错呢，我最近升职了呢',
#   'bot: 那么恭喜你了哦，还不知道你叫什么呢？',
#   'user: 我叫陈芳玲哦',
#   'bot: 光看你名字都知道你一定是一位漂亮的女孩',
#   'user: 对呢，真聪明',
#   'bot: 你多大了啊',
#   'user: 我今年才18哦'],
#  ['user: 成龙是什么星座呀？',
#   'bot: 白羊座',
#   'user: 好的，知道啦，优秀！',
#   'bot: 说到成龙，他可是香港浸会大学社会科学荣誉博士',
#   'user: 是啊，他还有法国骑士勋章呢',
#   'bot: 是的呢，他还是香港电影金像奖最佳动作指导的获得者呢',
#   'user: 不愧是我喜欢的明星'],
#  ['user: 今天几号了？',
#   'bot: 2018年10月26日',
#   'user: 谢谢',
#   'bot: 今天还是老艺术家郭富城的生日哦',
#   'user: 真的吗，真是巧呢，居然是偶像的生日。',
#   'bot: 是呀，说起郭富城，他可是完美主义者。',
#   'user: 当然啊，在舞蹈上获得过香港舞蹈年奖，音乐上又获得过三届十大劲歌金曲最受欢迎男歌星。多才多艺。',
#   'bot: 他的演技也不错哦，由他主演的《踏血寻梅》就是一部很用心的电影，你可以看看',
#   'user: 这个电影的导演是谁啊？',
#   'bot: 导演是翁子光',
#   'user: 电影的口碑怎么样啊？',
#   'bot: 口碑还好哦',
#   'user: 好的，有时间我去看看'],
#  ['user: 你知道范冰冰的生日吗？',
#   'bot: 嗯，知道，她是1981年9月16题出生的。',
#   'user: 你知道的还挺多的啊。',
#   'bot: 哈哈过奖过奖，我还知道她的其他信息呢，你都可以问我呢。',
#   'user: 那你知道她有多高吗？',
#   'bot: 她的身高是168cm。',
#   'user: 嗯，还挺高的，168cm可是我羡慕的理想身高呢。',
#   'bot: 除了身材，她的作品也值得称道啊，她有一部电影名字叫做《手机》，是一部能让人在笑过之后感到浑身发冷，进而进行思考的作品，很值得你看看。',
#   'user: 手机可是每个人每天都不离手的东西啊，真的很想看看，那这部电影的主演还有谁呢？',
#   'bot: 这部电影的主演除了范冰冰，还有葛优、徐帆、张国立哦。',
#   'user: 那我抽时间看看。',
#   'bot: 好的，你一定会喜欢的。',
#   'user: 好了我要休息了，下次聊。'],
#  ['bot: 姬琪振先生，最近怎么样？',
#   'user: 一般般，有点寂寞',
#   'bot: 寂寞啊？建议您听听音乐，音乐可以让人变得心情好呢',
#   'user: 这个建议不错',
#   'bot: 嗯呢，您可以听听《还有我》这首歌，听这首歌，有种淡淡的忧伤，像是在回忆，又不知在回忆什么',
#   'user: 建议不错，不过现在暂时不想听音乐',
#   'bot: 好的吧，那我们聊聊他的主唱何炅吧，您对他了解吗？',
#   'user: 了解的不多，不过我知道他是金牛座的小伙子',
#   'bot: 是的呢，他还是位很优秀的主持人呢，新周刊2013中国电视榜15周年荣誉大奖他可是获得者哦。',
#   'user: 嗯，不愧是我喜欢的明星',
#   'bot: 嗯呢，再推荐您一个他的电影《快乐奔跑》吧，快乐家族心血演绎，难得的动画佳作。',
#   'user: 对这个电影不感兴趣',
#   'bot: 好的吧，那要不要看看这个《爱宠大机密》呢？铲屎官必看',
#   'user: 听起来不错，这部片导演是谁呀？',
#   'bot: 是亚罗·切尼克里斯·雷纳德导演',
#   'user: 嗯，还是外国的导演',
#   'bot: 是的呢，不会让您失望的呢',
#   'user: 嗯，先这样吧，我要遛弯去了'],
#  ['bot: 晚上好呀亲。',
#   'user: 晚上好，小可爱',
#   'bot: 嗯，您最近还好吗？',
#   'user: 最近学习压力有点大啊',
#   'bot: 要加油哦，还不知道您叫什么呢？',
#   'user: 我叫郑鑫姗'],
#  ['bot: 韩琪玲小姐姐，中午好呀！', 'user: 你好啊', 'bot: 最近工作怎么样呀？', 'user: 工作太忙'],
#  ['user: 你能告诉我今天天气怎么样吗？',
#   'bot: 南昌今天晴,东北风,最高气温:23℃,最低气温:13℃',
#   'user: 你真棒！',
#   'bot: 谢谢夸奖，今天这种天气很适合听『今夜我属于爱情』呢，这首歌还斩获了当年的奥斯卡最佳原创歌曲呢。',
#   'user: 这首歌是谁唱的？',
#   'bot: 这首歌的演唱者是张学友。',
#   'user: 那我要听一下。'],
#  ['user: 嗨，请问电影『小王子』的主演是谁啊？',
#   'bot: 小王子的主演是『黄渤』哦。',
#   'user: 是我最喜欢的明星主演的哦，谢谢你啦，你好厉害',
#   'bot: 也还好啦，说起黄渤他可是华语电影传媒大奖的观众票选最受瞩目男演员呢。',
#   'user: 这么厉害呢，整天说喜欢他，确实还没具体了解过他呢，你能把他的身高及星座告诉我吗？'],
#  ['bot: 郑枫超，晚上好',
#   'user: 你好。',
#   'bot: 最近怎么样？',
#   'user: 挺轻松的。',
#   'bot: 轻松了就听会歌吧，你最喜欢什么歌？',
#   'user: 最好的幸福',
#   'bot: 是何炅唱的呀，说起来他可是内地热门综艺的主持人呢',
#   'user: 对，他的节目经常给人带来欢乐，我很喜欢',
#   'bot: 他还是中国大学生电视节最受大学生喜爱电视节目男主持人呢，人气确实很高',
#   'user: 对的，他确实很厉害',
#   'bot: 既然你之前说喜欢他的歌，那给你推荐他的『还有我』，该歌曲还是电影《合约情人》的插曲。要不要听？',
#   'user: 我听过了。'],
#  ['bot: 早上好啊，李静玲，最近学习怎么样啊',
#   'user: 早上好，学习很有状态，略有进步',
#   'bot: 那你要保持状态喽',
#   'user: 那是一定的',
#   'bot: 那就好，还没上课，我们聊会电影吧，你平时喜欢看哪部电影啊',
#   'user: 就数『钟无艳』了，这部我最喜欢了',
#   'bot: 那你是最喜欢里边哪个演员啊',
#   'user: 最喜欢女神张柏芝哈哈',
#   'bot: 她可是娱乐圈超亲民明星，很受大家的欢迎',
#   'user: 是啊是啊每次演的角色都演到我心坎儿里去了',
#   'bot: 难道她能获得过金太阳电影大赏最佳女演员呢',
#   'user: 哈哈，实至名归！',
#   'bot: 那你应该很喜欢她演的电影啰，那这部她演的尔冬升的救世之作『旺角黑夜』推荐给你看看，在题材上非常新颖，在叙事上也相当流畅。',
#   'user: 之前看过这部电影了',
#   'bot: 我还有其他的，也是她主演的很法式的一部短片『左右情缘』你也可以看看',
#   'user: 主演是谁啊',
#   'bot: 主演是邱淑贞，张国荣，张柏芝',
#   'user: 还有哥哥啊，更喜欢了'],
#  ['bot: 李明铮,好久没联系，最近怎么样啊？',
#   'user: 最近工作有点无聊',
#   'bot: 那为什么不找点事情来放松放松呢？',
#   'user: 你说的好像有点道理'],
#  ['bot: 晚上好呀，最近怎么样？',
#   'user: 感觉不太好，今天又被批评了，老师说我学习退步了很多呢',
#   'bot: 咱不难过哈，下次继续努力也是可以的，乖',
#   'user: 好的，我会加油的，学好给他们看',
#   'bot: 嗯，你最棒了，对了，你叫什么呀？',
#   'user: 我的名字是张娇菲',
#   'bot: 好可爱的名字，你是个小女生吧？',
#   'user: 对呀，我是个女孩子呢',
#   'bot: 小可爱呢，几岁了呀？',
#   'user: 我今年6岁啦',
#   'bot: 哇哦，好亲哦，你有什么爱好吗？',
#   'user: 我喜欢看动物动漫听儿歌哦~嘻嘻！'],
#  ['bot: 晚上好，最近怎么样？',
#   'user: 我最近学习进步了呢！',
#   'bot: 那你真是太棒了，继续努力哦！',
#   'user: 我会努力加油的！',
#   'bot: 聊了这么多，还不知道你叫什么名字呢？',
#   'user: 我的名字叫王轩航',
#   'bot: 你是男孩子还是女孩子呀？',
#   'user: 我是个男孩子',
#   'bot: 你今年几岁啦？',
#   'user: 我今年6岁了',
#   'bot: 你有什么爱好吗？',
#   'user: 我喜欢小动物还有看动漫和听儿歌'],
#  ['bot: 晚上好呢，郭鑫菲女士，在干啥呢？',
#   'user: 在家里呢。',
#   'bot: 最近咋样啊？',
#   'user: 最近挺好的，还发奖金了。',
#   'bot: 那你很棒棒啊，可以稍微放松一下，看看电影。你最喜欢的电影是啥呢？',
#   'user: 我啊，最喜欢《柔道龙虎榜》',
#   'bot: 里面最喜欢哪个演员了？',
#   'user: 最喜欢郭富城。',
#   'bot: 郭富城啊，他很厉害呢，还获得过中国电影金鸡奖最佳男主角',
#   'user: 嗯，他的电影拍的越来越好了！',
#   'bot: 所以才能获得内华达州国际杰出艺人奖这样的国际大奖',
#   'user: 作为他的粉丝真的为他骄傲呢'],
#  ['bot: 郝宇宇，最近怎么样？',
#   'user: 挺好的啊。',
#   'bot: 工作怎么样呢？',
#   'user: 也挺好的啊，工作轻松。',
#   'bot: 推荐你听听《谁谁谁》，网友评价：最近一首首把我何的宝藏歌曲拾起来……这首也是沧海遗珠之一……爱这声音一万年。',
#   'user: 我暂时不想听音乐。',
#   'bot: 那我们聊聊这首歌的主唱何炅怎么样？',
#   'user: 可以啊，何炅可是我最喜欢的明星呢。',
#   'bot: 何炅，湖南卫视当家主持人，第三届中国影视网络影响力颁布盛最具网络影响力的十大电视主持人。',
#   'user: 何老师还真是优秀啊，会主持，还会唱歌，演技也不错。',
#   'bot: 推荐你看看《快乐奔跑》，快乐家族心血演绎，难得的动画佳作。',
#   'user: 看过、对这个电影不感兴趣。',
#   'bot: 那你可以看看《爱宠大机密》，兔子为什么仇视人类？没有大反派的意思可能是，人类就是大反派',
#   'user: 这部电影的口碑怎么样？评分是多少呢？'],
#  ['bot: 晚上好邢轩杰，最近怎么样啊？',
#   'user: 最近还不错啊，还升职了呢',
#   'bot: 那不错呀，提前祝你升职快乐哦',
#   'user: 好的，谢谢。',
#   'bot: 可以放首歌来庆祝一下嘛，你最喜欢的歌曲是什么？',
#   'user: 最喜欢的一首歌是“好心分手”。',
#   'bot: 那你一定挺喜欢王力宏的吧，他可是个非常不错的艺人',
#   'user: 是啊，很喜欢听他的歌。',
#   'bot: 他还获得过两届金曲奖国语男演唱人奖，非常优秀呢',
#   'user: 没错，我会永远支持他的。'],
#  ['user: 你好，现在几点了呢？',
#   'bot: 现在是晚上20：00哦。',
#   'user: 嗯嗯，知道了，谢谢你。',
#   'bot: 不客气哦，对了今天天气不太好小雨~多云,北风,最高气温:19℃,最低气温:10℃，注意保暖哦。',
#   'user: 好的，你真贴心谢谢啦。'],
#  ['user: 你好，今天天气如何呢？',
#   'bot: 呼和浩特今日小雨,东南风,最高气温:11℃,最低气温:4℃，请记得带伞哦。',
#   'user: 好的，多谢你的提醒，真棒。',
#   'bot: 还好还好，像这种天气还蛮适合听这首旋律不错的『你不在(Live)』哟。这首歌曲诠释了男女之间对于爱情孤独无力的感觉，具有强有力的穿透力。',
#   'user: 这首歌是谁唱的啊，好耳熟。'],
#  ['user: 你知道吴亦凡的生日吗？', 'bot: 11月6日哦', 'user: 我知道了，谢谢啊'],
#  ['user: 你知道谢霆锋是什么星座的吗？', 'bot: 谢霆锋是处女座哟', 'user: 不错不错，你厉害哦'],
#  ['user: 来一首《玻璃之情》听听。', 'bot: 正在为你播放，请欣赏', 'user: 真好听啊，谢谢你。'],
#  ['bot: 中午好呀亲。',
#   'user: 中午好啊小可爱',
#   'bot: 在做什么呢？',
#   'user: 在学校了，刚下课',
#   'bot: 嗯，好好学习，给你加油，还不知道您叫什么呢？',
#   'user: 我叫韩晓君',
#   'bot: 嗯呐，一听就是个美女吧！',
#   'user: 是的，你好聪明'],
#  ['user: 你好啊，今天天气怎么样？',
#   'bot: 今天南通多云,东北风,最高气温:26℃,最低气温:17℃，温差较大，注意保暖。',
#   'user: 嗯嗯，我会的。你真的好贴心啊。',
#   'bot: 嘿嘿，我还知道这种天气适合吃麻辣豆腐。',
#   'user: 是嘛，可以啊',
#   'bot: 这道热菜很出名的呦。',
#   'user: 听着这菜名就很辣，很想去吃一吃啊。'],
#  ['bot: 晚上好呀，周玲姗小姐姐。最近怎么样啊？',
#   'user: 晚上好，最近还不错，马上要发工资了。',
#   'bot: 那还蛮好的，发工资后就可以买买买了。',
#   'user: 还好，主要再不发工资就要吃土了。',
#   'bot: 哈哈，聊点其他的，你最喜欢听哪首歌啊？',
#   'user: 我最喜欢听『雨夜的浪漫』。很好听的。',
#   'bot: 张学友的歌哦，他是香港著名歌星呢',
#   'user: 是啊，多年一直喜欢的歌手就是学友。'],
#  ['user: 『你好吗』音乐主唱是谁啊',
#   'bot: 这首歌的主唱是周杰伦哦。',
#   'user: 真聪明，是嘛都知道。',
#   'bot: 你喜欢周杰伦吗？他可是四届新加坡金曲奖最受欢迎男歌手，还是两届MTV亚洲大奖最受欢迎艺人',
#   'user: 很喜欢呢。',
#   'bot: 你真有眼光，周杰伦是四届世界音乐大奖最畅销中华区艺人呢。',
#   'user: 是啊，很喜欢周杰伦的歌。',
#   'bot: 给你推荐一首周杰伦主唱的歌“蛇舞”，整首歌曲以嘻哈混合埃及与中东民族乐风，以及诱惑般的吟唱，创造出嘻哈对唱独特、魅惑的歌曲，真不错哦。',
#   'user: 是嘛，没听过呢。',
#   'bot: 那你可以试试哦，真的很棒。',
#   'user: 那就给你个面子。'],
#  ['user: 我要听『花房姑娘』',
#   'bot: 好的，正在放《花房姑娘》',
#   'user: 嗯，这是真好听啊',
#   'bot: 是的，对了，还有他的《LikeThat》这首歌那种梦幻缥缈的感觉真的绝，我也不会表达，我只能说，很棒，你也听听哦',
#   'user: 这首歌我已经听过了',
#   'bot: 行吧，他的另一首《NovemberRain》也还不错哦，蛮喜欢这首歌，推荐你听听',
#   'user: 是吗，这首歌的名字看起来不错呢',
#   'bot: 你一定会喜欢听的',
#   'user: 那可以啊',
#   'bot: 需要现在放吗？',
#   'user: 放吧，',
#   'bot: 好的，正在放哦。',
#   'user: 好的，谢谢你啦',
#   'bot: 嘿嘿，应该的呀',
#   'user: 我要入睡了，拜拜了。'],
#  ['user: 可以播放『至少还有你』吗？',
#   'bot: 可以，正在为您播放『至少还有你』',
#   'user: 非常感谢你能播放这首歌',
#   'bot: 不客气啊，张国荣唱的『共同渡过』这首歌很不错哦，这首歌再一次展现了他驾驭歌曲的本领，您要不要听一下？',
#   'user: 这首歌听过了，暂时不想听',
#   'bot: 这首『愿你决定』怎么样？好听到总想一直循环的一首歌，你想听一下吗？',
#   'user: 这首歌是谁唱的？',
#   'bot: 这首歌的演唱者是张国荣。',
#   'user: 他的歌挺不错的',
#   'bot: 需要现在为您播放这首歌吗？',
#   'user: 可以啊',
#   'bot: 好的，正在为您播放『愿你决定』',
#   'user: 这首歌很好听，我很喜欢，谢谢你啊'],
#  ['bot: 周琪林先生，你好啊',
#   'user: 你好啊',
#   'bot: 最近过得怎么样？',
#   'user: 工作轻松，心情舒畅',
#   'bot: 你有什么喜欢的音乐吗？',
#   'user: 我最喜欢『手牵手』',
#   'bot: 这是亚洲人气偶像王力宏的歌，你很喜欢听他的歌吗？',
#   'user: 对呀，他唱歌很好听'],
#  ['bot: 晚上好啊，李明铮',
#   'user: 晚上好。',
#   'bot: 今天过得还愉快吗',
#   'user: 开心，我升职了。',
#   'bot: 这个喜庆的号子不如来首歌助助兴，《想你》推荐给你，张国荣的歌唱部份炮制得相当出色，令其散发着浓厚的巨星魅力，颇堪一赞。',
#   'user: 不是很想听歌的。',
#   'bot: 那我们来聊聊这首歌的主唱张国荣吧，一尘不染如初见的明星',
#   'user: 他也是完美的化身。',
#   'bot: 还是首位享誉韩国乐坛的华人歌手呢，了不起',
#   'user: 他还3次入围戛纳国际电影节最佳男演员奖，棒棒哒！',
#   'bot: 有一条关于他的新闻说，4月1号是哥哥张国荣逝世十五周年。他的歌迷会和义工团为他在香港举办了一连两天的悼念活动。很多歌迷说自已从没有见过哥哥本人，但都被他所吸引，很难得。',
#   'user: 我也没有见过本人，真的好遗憾啊！',
#   'bot: 但都过去这么久了还有这么多人喜欢他，可见哥哥的魅力有多大',
#   'user: 对啊，我们都很喜欢他的，一直都很怀念。'],
#  ['user: 今天几号了？', 'bot: 今天是2018年8月29日。', 'user: 好的，你真聪明'],
#  ['bot: 嗨，在干嘛呢',
#   'user: 在上学的路上呢呀',
#   'bot: 那你最近的怎么样吧？',
#   'user: 很好啊，最近考试考得老好啦',
#   'bot: 那挺棒的呢，对了，你叫什么呢',
#   'user: 我叫蔡帅宇',
#   'bot: 一听名字就是一个帅气的小男孩',
#   'user: 你可真聪明呀',
#   'bot: 那你几岁了呢',
#   'user: 今年7岁啦',
#   'bot: 那你有什么爱好吗',
#   'user: 我喜欢小动物，动漫和儿歌',
#   'bot: 喜欢小动物哇，你很有爱心哦。',
#   'user: 嘿嘿，我觉得它们很可爱。',
#   'bot: 是的，毛茸茸的。',
#   'user: 我先不跟你说了，我要去学校去了。'],
#  ['user: 现在几点了？',
#   'bot: 现在是2018年11月24日，中午12点。',
#   'user: 速度挺快的啊。给你点个赞。',
#   'bot: 谢谢，提醒你今天天气晴,西南风,最高气温:11℃,最低气温:-4℃。',
#   'user: 恩，知道了，天气不错的啊。'],
#  ['user: 你知道周杰伦的生日啥会不？',
#   'bot: 他是1979年1月18日出生的',
#   'user: 嗯嗯，知道了，你真优秀，啥也知道',
#   'bot: 是啊，毕竟他可是一个才华横溢的全民偶像呢',
#   'user: 那是，我爱豆可是个人才',
#   'bot: 嗯嗯，他确实很棒，他是大众电影百花奖的最佳男配角还，而且获得了香港电影金像奖的最佳原创电影歌曲奖',
#   'user: 哈哈，我爱豆超厉害，他的歌曲不止好听，而且获奖了不少呢',
#   'bot: 《路小雨》这首歌是周杰伦创作钢琴曲听众最爱的一首，在电影《不能说的秘密》中，有两处出现了钢琴曲《路小雨》。推荐给你哦',
#   'user: 这歌没听过，不知道唱的怎么样？',
#   'bot: 当然很棒啦，听过以后你一定会喜欢的',
#   'user: 好的呢，真期待这首歌~',
#   'bot: 需要我为你播放这首歌曲嘛？',
#   'user: 好的呀，那你播放吧'],
#  ['bot: 嗨，司轩振',
#   'user: 嗨',
#   'bot: 最近怎么样？',
#   'user: 挺好的，我升职了',
#   'bot: 推荐你一首音乐哦《月亮代表我的心》很好听的一首歌',
#   'user: 暂时不想听歌呢',
#   'bot: 那聊聊张国荣怎么样？天生的艺人',
#   'user: 当然可以啊，他可是我最喜欢的明星呢，英俊潇洒而且优雅'],
#  ['user: 你知道林志颖属什么吗？',
#   'bot: 他是属虎的。',
#   'user: 谢谢你告诉我这些。',
#   'bot: 不客气，我还知道他获得过华鼎奖偶像励志类最佳男演员呢。',
#   'user: 你可真聪明啊，知道那么多。',
#   'bot: 我还知道他是2001年台湾超级跑车赛年度冠军呢，他是一个特别全能的艺人。',
#   'user: 真不愧是我看中的偶像，就是优秀啊！',
#   'bot: 既然你这么喜欢林志颖，那要不要看一下他主演的电影啊？这部『祖孙情』戳中泪点！真的很感人。你可以看一下',
#   'user: 这部电影的评分怎么样啊？',
#   'bot: 这部电影7.3分呢。',
#   'user: 那不错哟！有时间我会去看看的。',
#   'bot: 我相信你一定不会失望的。',
#   'user: 我到公司了，先不聊了，下次有空再聊吧，再见！'],
#  ['user: 你好，现在几点了呀？',
#   'bot: 现在是晚上20点',
#   'user: 好的，谢谢',
#   'bot: 不客气哦，对了今天天气有小雨,东北风,最高气温:10℃,最低气温:1℃，出门要注意呢',
#   'user: 好的，我知道啦，谢谢',
#   'bot: 不客气呢',
#   'user: 还有事先不聊了，再见'],
#  ['user: 电影『真的爱你』主演是谁啊？',
#   'bot: 是张学友',
#   'user: 真是谢谢你呢，愿意告诉我',
#   'bot: 当然愿意啦！说起来张学友，不得不说他是个伟大的天王级歌星啊',
#   'user: 是啊，不瞒你说，我也算是他的小迷妹呢',
#   'bot: 哈哈，其实张学友不仅唱歌好听，电影更是演的不错呢，还获得过华语电影传媒大奖最佳男演员，非常厉害的一个奖项了',
#   'user: 真的好优秀啊，不愧是我喜欢的人',
#   'bot: 没错哦，那他的电影『笑傲江湖』你绝对不要错过，这部以金庸原著的武侠小说为蓝本，加入胡金铨式的东厂太监陷害忠良故事，同时又兼具徐克式冷嘲热讽的政治批判，以及程小东夺目武术设计场面的《笑傲江湖》，在面世后得到了绝大多数影迷的认可，更是被各路影评家称为是“新武侠电影”的典范。很不错呢',
#   'user: 哇，听起来就不错呢，主演还有些谁啊',
#   'bot: 还有许冠杰、张敏和叶童',
#   'user: 那我就很期待了',
#   'bot: 哈哈，这么说的话就太好啦',
#   'user: 嗯呢，我先敷面膜呀，就不说了啊，拜'],
#  ['user: 中午好，能帮我放一首『思念的距离』吗？',
#   'bot: 好的，现在为您播放这首歌。',
#   'user: 好的，谢谢你呀。',
#   'bot: 不用谢，何炅唱的《心火烧》也是很逗很耐听的一首歌推荐给你哟。',
#   'user: 这首歌已经听过了，暂时不想听这首歌呢。',
#   'bot: 那《和影子对话》这首歌就别错过了，唱得很有感情，很温暖，很治愈。可以试着听一下。',
#   'user: 也是他唱的吗？没有听过唉。',
#   'bot: 对，也是何老师演唱的，这首老歌不仅仅是好听，承载的是很多人大学时光。',
#   'user: 很不错啊',
#   'bot: 需要现在播放这首音乐么？',
#   'user: 好的呀，播放吧。',
#   'bot: 为您播放《和影子对话》',
#   'user: 好嘞，谢啦。'],
#  ['bot: 在干啥呢？',
#   'user: 去上班的路上呗。',
#   'bot: 最近的工作怎么样啊？',
#   'user: 最近还挺清闲的，没啥事做，有点无聊。',
#   'bot: 那我陪你聊会天吧，还不知道你的名字呢？',
#   'user: 我叫张山宇。',
#   'bot: 看你的名字感觉你是一个男生？',
#   'user: 对呀，这还用猜么。',
#   'bot: 你今年多大呀？',
#   'user: 今年26。',
#   'bot: 那你有应该不少的爱好吧。',
#   'user: 还好吧，也就听听音乐啥的。'],
#  ['user: 我要点一首歌“疗伤烧肉粽”。',
#   'bot: 歌曲”疗伤烧肉粽“正在为你播放。',
#   'user: 你真好，真棒！',
#   'bot: 我应该做的呀，再给你推荐一首周杰伦唱的”迷魂曲“他改变中文韵脚来适应嘻哈音乐节奏的手法真是太棒啦，可以听听看。',
#   'user: 确实很不错，但是我已经听过啦。'],
#  ['bot: 你好啊！',
#   'user: 你也好呀',
#   'bot: 最近工作怎么样？',
#   'user: 最近工作很忙，不过很充实',
#   'bot: 再忙也要多注意休息哦，对了，你叫什么名字啊？',
#   'user: 我叫周琪林',
#   'bot: 看你的名字应该是个男生吧？',
#   'user: 你真聪明',
#   'bot: 您今年多大了？',
#   'user: 我今年39岁了都',
#   'bot: 您有什么兴趣爱好吗？',
#   'user: 我平时喜欢听一听歌',
#   'bot: 真的是很好的兴趣爱好啊！',
#   'user: 哈哈，就是打发一下时间啦'],
#  ['user: 你知道现在几点了吗？',
#   'bot: 中午12:00哦',
#   'user: 你真好，什么都知道！',
#   'bot: 嘿嘿，提醒你今天天气是小雨转阴,东风,最高气温:20℃,最低气温:15℃，记得带伞啊',
#   'user: 谢谢你的提醒，真是太贴心啦！'],
#  ['bot: 小朋友你好呀！',
#   'user: 你也好啊！',
#   'bot: 最近怎么样？',
#   'user: 不错呢，昨天的考试考的特别好。',
#   'bot: 那你可真厉害啊！对了，我能知道你的名字吗？',
#   'user: 我叫郭晓湘'],
#  ['user: 嗨，今天的天气怎么样？',
#   'bot: 今天的天气小雪~多云,无持续风向,最高气温:6℃,最低气温:-4℃，请注意保暖哦！',
#   'user: 好的呢，你真贴心。',
#   'bot: 是的呢，这种天气就适合吃红烧排骨，有没有想法呢？',
#   'user: 我正想着中午吃啥呢，你就推荐了',
#   'bot: 那巧了，这道菜尤其精排做出来的更很美味！',
#   'user: 好的呢，一定要尝一尝。',
#   'bot: 嗯，那你可以去馅老大饺子馆去预定呦。',
#   'user: 它那人均价格是多少呢？地址在哪？评分怎么样呢？'],
#  ['user: 你知道周迅的血型吗？', 'bot: 周迅是O型血。', 'user: 我知道了，谢谢你。'],
#  ['bot: 晚上好呀，王轩宇先生。',
#   'user: 晚上好',
#   'bot: 最近怎么样啊？',
#   'user: 挺好的，今天还发工资了。',
#   'bot: 嗯，恭喜了，您最喜欢谁的新闻？',
#   'user: 喜欢王力宏的新闻'],
#  ['bot: 嗨，晚上好。',
#   'user: 晚上好。',
#   'bot: 最近在忙什么呢？',
#   'user: 在想什么时候发工资呢。',
#   'bot: 应该快了吧。',
#   'user: 但愿吧。',
#   'bot: 不要担心啦，我陪你聊天吧，你叫什么啊？',
#   'user: 好啊，我叫于鑫倩。',
#   'bot: 名字很好听，想必是位姑娘吧？',
#   'user: 是的哦。',
#   'bot: 敢问姑娘芳龄几许？',
#   'user: 38了。',
#   'bot: 姑娘平时喜欢什么美食啊？',
#   'user: 我平时喜欢吃烤鱼。',
#   'bot: 烤鱼确实是不错的选择呢。',
#   'user: 是啊，我要睡觉了，不聊了。'],
#  ['user: 现在几点了',
#   'bot: 晚上22:00',
#   'user: 谢谢',
#   'bot: 不客气哦，提醒你晴~多云,东南风,最高气温:5℃,最低气温:-3℃',
#   'user: 天凉了呀'],
#  ['user: 电影『人再囧途之泰囧』主演是谁?',
#   'bot: 主演是黄渤。',
#   'user: 好的，谢谢',
#   'bot: 不客气啊，他可是娱乐圈真正的好男人呢。',
#   'user: 是的呢，我非常喜欢他啊，他特别幽默。',
#   'bot: 很有眼光啊，他还获得过台湾电影金马奖最佳男主角呢。',
#   'user: 哇，真正的平民影帝，他的幽默是写在脸上的。',
#   'bot: 看你这么喜欢他，推荐你看看黄渤主演的电影《杀生》，是一部能给你带来一定思索的好电影。',
#   'user: 这部电影的导演是谁啊？',
#   'bot: 导演是管虎。',
#   'user: 这部电影的口碑怎么样？'],
#  ['user: 可以告诉我一下黄渤的身高吗？',
#   'bot: 好的，黄渤身高172厘米。',
#   'user: 好嘞，我晓得啦，你咋啥都知道啊，真厉害。',
#   'bot: 不用夸奖我啦！这是我该做的。另外再告诉你哦，黄渤他可是娱乐圈的男神，',
#   'user: 名副其实！哈哈，我对黄渤还挺有好感的，尤其是他的演技吸引了我。',
#   'bot: 你眼光不错呢！黄渤的演技确实没得说，获得过中国电影表演艺术学会金凤凰奖这样的大奖呢',
#   'user: 那可不，我喜欢他就是因为他可是绝对的演技派！',
#   'bot: 那他的电影你就绝对不能错过啦，《寻龙诀》就是黄渤主演的，里面他。陈坤和舒淇都演得不错，你可以看看',
#   'user: 咦，听这个名字感觉很新颖呢，这部电影是什么类型的呀？'],
#  ['user: 播首『天地』',
#   'bot: 好嘞，正在为你播放。',
#   'user: 不错',
#   'bot: 那还有一首《花房姑娘》也很好听，听上去是一种粗野与温情、狂躁与哀伤的奇妙的混合物你要听听吗？',
#   'user: 这首歌不感兴趣',
#   'bot: 那为你换一首《有一个地方remix》，是那种朴实的歌词讲述真实青涩的爱情，很特别的一首歌，你可以听听看。',
#   'user: 歌名是我喜欢的耶',
#   'bot: 那就不要错过这首歌喽！',
#   'user: 很不错哦',
#   'bot: 现在为你播放好吗？',
#   'user: 播放吧',
#   'bot: 嗯呢，播放中，请欣赏。',
#   'user: 不错，果然是我喜欢的，你好聪明'],
#  ['user: 今天几号呀',
#   'bot: 今天是2018年7月10日',
#   'user: 谢谢，你真聪明',
#   'bot: 谢谢夸奖，对了，你知道今天是张学友的生日吗',
#   'user: 他可是我的偶像呀，我老喜欢他啦',
#   'bot: 那你眼光真好啊，他可是粤语歌王呢',
#   'user: 对呀，要不他能是四大天王之一么',
#   'bot: 嗯啊，那我给你推荐一部他主演的大时代背景下的人性电影《喋血街头》，你可以看看哦',
#   'user: 导演是谁呀',
#   'bot: 导演是吴宇森',
#   'user: 嗯，不错看来可以看看',
#   'bot: 嗯嗯，相信我没有错',
#   'user: 好的，我还有事回聊'],
#  ['user: 今天天气怎么样？',
#   'bot: 多云,无持续风向,最高气温:22℃,最低气温:12℃',
#   'user: 谢谢',
#   'bot: 这种天气适合听《兰亭序》呢，这首歌词韵味悠长，令人品味再三。',
#   'user: 这首歌是谁唱的啊？',
#   'bot: 是周杰伦哦，方文山的作词，非常有中国风特色',
#   'user: 不错不错，方文山的词确实写得好',
#   'bot: 是否播放『兰亭序』',
#   'user: 播放',
#   'bot: 正在播放『兰亭序』',
#   'user: 好的，我先听歌了，再见'],
#  ['bot: 李明铮早上好！',
#   'user: 早上好啊。',
#   'bot: 起这么早是有什么聚会要参加吗',
#   'user: 没有呢，今天闲着呢。',
#   'bot: 那来看新闻吧，不知道你最喜欢谁的新闻呀',
#   'user: 我偶像刘德华！我最喜欢刘德华的新闻啦。',
#   'bot: 我这里正好有关于刘德华的新闻，杨丽娟自16岁起疯狂迷恋刘德华，父母卖房甚至卖肾凑钱多次送女儿去香港寻见刘德华。2007年3月25日歌迷会后当晚，杨丽娟的父亲写下遗书后跳海身亡，11年后杨丽娟再谈刘德华，她却说祝福吧。',
#   'user: 看来追星还是要理智啊。',
#   'bot: 追星追到家破人亡，也挺让人唏嘘的',
#   'user: 是啊，害人又害己，真是不可取。'],
#  ['user: 我想看看王力宏的新闻',
#   'bot: 好的亲，最近在春晚节目上，王力宏与李云迪一起合作，共同演奏《金蛇狂舞》和《龙德传人》。整个春晚现场的气氛都被他们的表演点燃了。',
#   'user: 谢谢你哦，但是我也看了，确实很震撼',
#   'bot: 看你对王力宏挺关注的，我这里还有一条呢，你要听听看嘛',
#   'user: 可以呀，我可喜欢王力宏了呢',
#   'bot: 最近，水果姐”凯蒂·佩里发布了新歌《365》的MV，结果不少网友指出其MV风格与王力宏《A.I.爱》MV很相似，甚至许多拍摄场景概念都有重合。对与这一事件，王力宏回应说，被模仿是最高的说赞。',
#   'user: 说得对，这说明得到了国际的认可。'],
#  ['bot: 亲爱的，在干嘛呢？',
#   'user: 我正在上班的路上呢。',
#   'bot: 那最近工作情况怎么样呢？',
#   'user: 有些事情很棘手，压力有点大啊',
#   'bot: 那你可找点时间好好放松放松了，这都多少天了，一直都叫你亲爱的，都不知道你叫什么名字。',
#   'user: 我叫徐山男。',
#   'bot: 山男啊，一听就是一个帅气的小伙。',
#   'user: 多谢夸奖呢，不过我已经不是一个小伙了。'],
#  ['user: 现在几点了',
#   'bot: 现在是晚上22点整。',
#   'user: 谢谢',
#   'bot: 嘿嘿，对了今天多云,无持续风向,最高气温:28℃,最低气温:21℃哦。',
#   'user: 天气不错呀',
#   'bot: 是的呢，让人的心情也很好。',
#   'user: 看来可以出门溜溜去',
#   'bot: 可以的。',
#   'user: 拜拜'],
#  ['user: 你知道郭富城的星座吗？',
#   'bot: 当然知道啊，他的星座是天蝎座呢。',
#   'user: 哇，你好棒啊。',
#   'bot: 嘿嘿，他可是让人心肝乱颤的古装美男之一呢，很帅气呢。',
#   'user: 是啊，也是我的偶像，娱乐圈天王的存在呢。',
#   'bot: 是呀，他是很优秀，还获得过三届十大劲歌金曲最受欢迎男歌星。',
#   'user: 哈哈，我喜欢听他的歌，我也喜欢看他的电影。他还是两届台湾电影金马奖最佳男主角奖的得主，果然是天王啊。',
#   'bot: 喜欢看他的电影啊，那为您推荐一部他主演的《浮城大亨》，很好的題材，郭富城演技很好。',
#   'user: 导演是谁呢？',
#   'bot: 导演是严浩呢。',
#   'user: 那我要看看啦。',
#   'bot: 嗯嗯，相信值得一看。',
#   'user: 好的，我去看啦，拜拜！'],
#  ['bot: 牛丽倩晚上好啊',
#   'user: 晚上好呀!',
#   'bot: 今天工作怎么样啊',
#   'user: 今天发奖金了，很开心。',
#   'bot: 那恭喜你了，正好推荐你《栀子花开》这首歌不错啊，轻轻的音乐淡淡的描述着离别的心情，简单的音乐节奏，让人在聆听时能感受到空气中轻盈地飘出栀子花带来的阵阵清香',
#   'user: 暂时不想听歌哦。',
#   'bot: 那我们聊聊明星吧，说起这首歌的主唱何炅，他可是湖南卫视最佳主持人奖获得者哦。',
#   'user: 我很喜欢他的节目来着'],
#  ...]

# %%
## Evaluate dataset, which is a conversation before the last bot response
eval_test_set = []

## Evaluate dataset reference, which is the last bot response in a conversation
eval_reference = []

# %%
## Data Preprocessing for spliting evaluation conversation and reference
for conversations in conversation_list:
    eval_data = conversations[:-2]
    reference = conversations[-2]
    
    ## Label the last user inquiry for Llama2(Knowledge Tree) inquiry approach
    eval_data[-1] = eval_data[-1].split(':')[0] + ':' + '##@' + eval_data[-1].split(':')[1] + '@##'
    
    ## Formatted the whole data for BART inquiry approach
    formatted_eval_data = ''.join(eval_data_conv.replace('user:', '\nInstruction:\n').replace('bot:','\nResponse:\n').replace(' ','') for eval_data_conv in eval_data)
    
    ## Append into eval_test_set list 
    eval_test_set.append(formatted_eval_data.lstrip('\n'))
    
    ## Append into eval_reference list 
    eval_reference.append(reference)

# %%
## Check that all references are responded to by "bot"
sum_bot_res = 0

for reference in eval_reference:
    if reference.__contains__('bot: '):
        sum_bot_res = sum_bot_res + 1
    
print('bot count' ,sum_bot_res)
# Out:
# bot count 2626

# %%
## Remove irrelevant string in eval_reference
eval_reference = [s.replace("bot: ", "").replace(" ", "") for s in eval_reference]

# %%
## Generate candidate on the eval_test_set(test.txt)
candidate_result = []

for con in eval_test_set:
    con_result = generate_text(con)
    candidate_result.append(con_result)

# %%
# Create a new list to store the modified candidate results
# candidate_result contains list element, needs to convert into string for Evaluation

modified_candidate_result = []

# Iterate through candidate_result and convert inner lists to strings
for item in candidate_result:
    if isinstance(item, list):
        modified_candidate_result.append(' '.join(item).replace(' ',''))
    else:
        modified_candidate_result.append(item.replace(' ',''))

# %%
## Store into dataframe
df_eval_reference = pd.DataFrame(eval_reference, columns=['Reference'])

## Store into dataframe
df_eval_candidate = pd.DataFrame(modified_candidate_result, columns=['Candidate'])

## Generate Candidate csv
df_eval_candidate['Candidate'].to_csv('eval_candidate.txt', index=False, header=False)

# %%
# Calculate BLEU individual scores
bleu_individual_1_gram = [sentence_bleu(ref, cand, weights=(1, 0, 0, 0)) for ref, cand in  zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]
bleu_individual_2_gram = [sentence_bleu(ref, cand, weights=(0, 1, 0, 0)) for ref, cand in  zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]
bleu_individual_3_gram = [sentence_bleu(ref, cand, weights=(0, 0, 1, 0)) for ref, cand in  zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]
bleu_individual_4_gram = [sentence_bleu(ref, cand, weights=(0, 0, 0, 1)) for ref, cand in  zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]

# %%
## Get bleu individual avg for all record
bleu_individual_1_gram_avg = sum(bleu_individual_1_gram) / len(bleu_individual_1_gram)
bleu_individual_2_gram_avg = sum(bleu_individual_2_gram) / len(bleu_individual_2_gram)
bleu_individual_3_gram_avg = sum(bleu_individual_3_gram) / len(bleu_individual_3_gram)
bleu_individual_4_gram_avg = sum(bleu_individual_4_gram) / len(bleu_individual_4_gram)

# Print bleu reslut
print("bleu_individual_1_gram_avg: ", bleu_individual_1_gram_avg)
print("bleu_individual_2_gram_avg: ", bleu_individual_2_gram_avg)
print("bleu_individual_3_gram_avg: ", bleu_individual_3_gram_avg)
print("bleu_individual_4_gram_avg: ", bleu_individual_4_gram_avg)
# Out:
# bleu_individual_1_gram_avg:  0.32041782779910594
# bleu_individual_2_gram_avg:  0.9345011424219345
# bleu_individual_3_gram_avg:  0.9345011424219345
# bleu_individual_4_gram_avg:  0.9345011424219345

# %%
# bleu individual avge result
bleu_individual_avg = (bleu_individual_1_gram_avg+bleu_individual_2_gram_avg+bleu_individual_3_gram_avg+bleu_individual_4_gram_avg) / 4
print("bleu_individual_avg: ", bleu_individual_avg)
# Out:
# bleu_individual_avg:  0.7809803137662275

# %%
# Calculate BLEU cumulative scores
bleu_cumulative_1_gram = [sentence_bleu(ref, cand, weights=(1, 0, 0, 0)) for ref, cand in  zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]
bleu_cumulative_2_gram = [sentence_bleu(ref, cand, weights=(0.5, 0.5, 0, 0)) for ref, cand in  zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]
bleu_cumulative_3_gram = [sentence_bleu(ref, cand, weights=(0.33, 0.33, 0.33, 0)) for ref, cand in  zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]
bleu_cumulative_4_gram = [sentence_bleu(ref, cand, weights=(0.25, 0.25, 0.25, 0.25)) for ref, cand in  zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]

# %%
## Get bleu avg for all record
bleu_cumulative_1_gram_avg = sum(bleu_cumulative_1_gram) / len(bleu_cumulative_1_gram)
bleu_cumulative_2_gram_avg = sum(bleu_cumulative_2_gram) / len(bleu_cumulative_2_gram)
bleu_cumulative_3_gram_avg = sum(bleu_cumulative_3_gram) / len(bleu_cumulative_3_gram)
bleu_cumulative_4_gram_avg = sum(bleu_cumulative_4_gram) / len(bleu_cumulative_4_gram)

# Print bleu reslut
print("bleu_cumulative_1_gram_avg: ", bleu_cumulative_1_gram_avg)
print("bleu_cumulative_2_gram_avg: ", bleu_cumulative_2_gram_avg)
print("bleu_cumulative_3_gram_avg: ", bleu_cumulative_3_gram_avg)
print("bleu_cumulative_4_gram_avg: ", bleu_cumulative_4_gram_avg)
# Out:
# bleu_cumulative_1_gram_avg:  0.32041782779910594
# bleu_cumulative_2_gram_avg:  0.5095262131966574
# bleu_cumulative_3_gram_avg:  0.614697667159339
# bleu_cumulative_4_gram_avg:  0.6756516714181057

# %%
# bleu avge result
bleu_avg = (bleu_cumulative_1_gram_avg+bleu_cumulative_2_gram_avg+bleu_cumulative_3_gram_avg+bleu_cumulative_4_gram_avg) / 4
print("bleu_avg: ", bleu_avg)
# Out:
# bleu_avg:  0.530073344893302

# %%
## Evaluation using rouge
# !pip install rouge-chinese
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting rouge-chinese
#   Downloading rouge_chinese-1.0.3-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from rouge-chinese) (1.16.0)
# Downloading rouge_chinese-1.0.3-py3-none-any.whl (21 kB)
# Installing collected packages: rouge-chinese
# Successfully installed rouge-chinese-1.0.3

# %%
## Split by char

from rouge import Rouge

rouge = Rouge()

## rouge.get_scores(hyps=' '.join(df_eval_candidate['Candidate'][3]) , refs=' '.join(df_eval_reference['Reference'][3]) )

# Calculate rouge F1 scores
rouge_1_f1 = [rouge.get_scores(hyps=' '.join(cand) , refs=' '.join(ref) )[0]['rouge-1']['f'] for ref, cand in zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]
rouge_2_f1 = [rouge.get_scores(hyps=' '.join(cand) , refs=' '.join(ref) )[0]['rouge-2']['f'] for ref, cand in zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]
rouge_l_f1 = [rouge.get_scores(hyps=' '.join(cand) , refs=' '.join(ref) )[0]['rouge-l']['f'] for ref, cand in zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]

## Get rouge F1  avg for all record
rouge_1_f1_avg = sum(rouge_1_f1) / len(rouge_1_f1)
rouge_2_f1_avg = sum(rouge_2_f1) / len(rouge_2_f1)
rouge_l_f1_avg = sum(rouge_l_f1) / len(rouge_l_f1)

# Print rouge F1  reslut
print("rouge_1_f1_avg: ", rouge_1_f1_avg)
print("rouge_2_f1_avg: ", rouge_2_f1_avg)
print("rouge_l_f1_avg: ", rouge_l_f1_avg)
# Out:
# rouge_1_f1_avg:  0.30251087144514777
# rouge_2_f1_avg:  0.14826409383097866
# rouge_l_f1_avg:  0.27428766825521295

# %%
## Split by word

from rouge import Rouge
import jieba

rouge = Rouge()

## rouge.get_scores(hyps=' '.join(df_eval_candidate['Candidate'][3]) , refs=' '.join(df_eval_reference['Reference'][3]) )

# Calculate rouge F1 scores
rouge_1_word_f1 = [rouge.get_scores(hyps=' '.join(jieba.cut(cand, HMM=False)) , refs=' '.join(jieba.cut(ref, HMM=False)) )[0]['rouge-1']['f'] for ref, cand in zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]
rouge_2_word_f1 = [rouge.get_scores(hyps=' '.join(jieba.cut(cand, HMM=False)) , refs=' '.join(jieba.cut(ref, HMM=False)) )[0]['rouge-2']['f'] for ref, cand in zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]
rouge_l_word_f1 = [rouge.get_scores(hyps=' '.join(jieba.cut(cand, HMM=False)) , refs=' '.join(jieba.cut(ref, HMM=False)) )[0]['rouge-l']['f'] for ref, cand in zip(df_eval_reference['Reference'], df_eval_candidate['Candidate'] )]

         
## Get rouge F1  avg for all record
rouge_1_word_f1_avg = sum(rouge_1_word_f1) / len(rouge_1_word_f1)
rouge_2_word_f1_avg = sum(rouge_2_word_f1) / len(rouge_2_word_f1)
rouge_l_word_f1_avg = sum(rouge_l_word_f1) / len(rouge_l_word_f1)

# Print rouge F1  reslut
print("rouge_1_word_f1_avg: ", rouge_1_word_f1_avg)
print("rouge_2_word_f1_avg: ", rouge_2_word_f1_avg)
print("rouge_l_word_f1_avg: ", rouge_l_word_f1_avg)
# Out:
# rouge_1_word_f1_avg:  0.2735797823796772
# rouge_2_word_f1_avg:  0.10356798766268521
# rouge_l_word_f1_avg:  0.25414763256277284

# %% [markdown]
# **## ROUGE and BLEU Metric**

# %%
# Print bleu reslut
print("bleu_individual_1_gram_avg: ", bleu_individual_1_gram_avg)
print("bleu_individual_2_gram_avg: ", bleu_individual_2_gram_avg)
print("bleu_individual_3_gram_avg: ", bleu_individual_3_gram_avg)
print("bleu_individual_4_gram_avg: ", bleu_individual_4_gram_avg)

# Print bleu reslut
print("bleu_cumulative_1_gram_avg: ", bleu_cumulative_1_gram_avg)
print("bleu_cumulative_2_gram_avg: ", bleu_cumulative_2_gram_avg)
print("bleu_cumulative_3_gram_avg: ", bleu_cumulative_3_gram_avg)
print("bleu_cumulative_4_gram_avg: ", bleu_cumulative_4_gram_avg)

# Print bleu reslut
print("rouge_1_f1_avg (Char): ", rouge_1_f1_avg)
print("rouge_2_f1_avg (Char): ", rouge_2_f1_avg)
print("rouge_l_f1_avg (Char): ", rouge_l_f1_avg)

# Print bleu reslut
print("rouge_1_word_f1_avg: ", rouge_1_word_f1_avg)
print("rouge_2_word_f1_avg: ", rouge_2_word_f1_avg)
print("rouge_l_word_f1_avg: ", rouge_l_word_f1_avg)
# Out:
# bleu_individual_1_gram_avg:  0.32041782779910594
# bleu_individual_2_gram_avg:  0.9345011424219345
# bleu_individual_3_gram_avg:  0.9345011424219345
# bleu_individual_4_gram_avg:  0.9345011424219345
# bleu_cumulative_1_gram_avg:  0.32041782779910594
# bleu_cumulative_2_gram_avg:  0.5095262131966574
# bleu_cumulative_3_gram_avg:  0.614697667159339
# bleu_cumulative_4_gram_avg:  0.6756516714181057
# rouge_1_f1_avg (Char):  0.30251087144514777
# rouge_2_f1_avg (Char):  0.14826409383097866
# rouge_l_f1_avg (Char):  0.27428766825521295
# rouge_1_word_f1_avg:  0.2735797823796772
# rouge_2_word_f1_avg:  0.10356798766268521
# rouge_l_word_f1_avg:  0.25414763256277284

# %%
# Create a dictionary with the results and output eval_Llama2_BART.csv
eval_results = {
    "Metric": ["bleu_individual_1_gram_avg", "bleu_individual_2_gram_avg", "bleu_individual_3_gram_avg", "bleu_individual_4_gram_avg",
               "bleu_cumulative_1_gram_avg", "bleu_cumulative_2_gram_avg", "bleu_cumulative_3_gram_avg", "bleu_cumulative_4_gram_avg",
               "rouge_1_f1_avg (Char)", "rouge_2_f1_avg (Char)", "rouge_l_f1_avg (Char)",
               "rouge_1_word_f1_avg", "rouge_2_word_f1_avg", "rouge_l_word_f1_avg"],
    
    "Value": [bleu_individual_1_gram_avg, bleu_individual_2_gram_avg, bleu_individual_3_gram_avg, bleu_individual_4_gram_avg,
              bleu_cumulative_1_gram_avg, bleu_cumulative_2_gram_avg, bleu_cumulative_3_gram_avg, bleu_cumulative_4_gram_avg,
              rouge_1_f1_avg, rouge_2_f1_avg, rouge_l_f1_avg,
              rouge_1_word_f1_avg, rouge_2_word_f1_avg, rouge_l_word_f1_avg]
}


eval_df = pd.DataFrame([eval_results['Value']], columns=eval_results['Metric'])

eval_df.to_csv('eval_Llama2_BART.csv', index=False, header=True)
